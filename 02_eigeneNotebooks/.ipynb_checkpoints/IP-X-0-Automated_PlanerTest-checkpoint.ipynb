# %% [markdown]
# Introduction
# ============
#
# This is interactive notebook regarding "Introduction to path planning". (Author: Björn Hein)
#
# License is based on Creative Commons: Attribution-NonCommercial 4.0 International (CC BY-NC 4.0) (pls. check: http://creativecommons.org/licenses/by-nc/4.0/)
#
# This notebook imports all discussed algorithms and does a comparison
#
# **Attention**: This worksheet has external dependencies
#
# * to the files "InnoKonz2dEnv.py" or "InnoKonzShapelyEnv.py". These files contain simple 2D environments based on numpy arrays or the shapely library with an interface for the use as collision checking in the algorithms.
# * to all modules like "**Algorithm**.py", which contains the corresponding algorithms
#
# Important links are:
#
# * General Info: http://www.python.org
# * Python tutorial http://www.python.org/doc/tut/
# * NetworkX http://networkx.github.io/
# * NumPy and SciPy Guide http://docs.scipy.org/
# * Matplotlib gallery http://matplotlib.sourceforge.net/gallery.html
#
#
# Remember that:
#
# * you have to press ctrl-return or shift-return, to execute the code in the code sections, only then the variables are "generated" and can be used
# * you can execute the whole notebook by Cell->runAll

# %% [markdown]
# Änderungen BasicPRM
#
# - Automated Planner Test:
#   - IPBasicPRM_Roundtrip eingefügt
#   - Eigene Methode für Planer erstellt
#   - PlanRoundPath bei Visualisierung eingefügt
# - IPBasicPRM_Roundtrip
#   - erstellt aus IPBasicPRM
#   - "Break" in "Continue" geändert bei "_learnRoadmapNearestNeighbour"
#   - Funktion "PlanRoundPath" aus "PlanPath" erstellt
#   - "InterimGoal" entsprechend "Start" und "Goal" eingefügt
#   - InterimGoal in Lösungspfad eingebaut
# - IPBenchmark
#   - "InterimGoalList" eingefügt
# - IPPlanerBase
#   - "InterimGoalList" eingefügt
# - IPTestSuite
#   - Koordinate von InterimGoal hinzugefügt
# - IPVISBasicPRM
#   - Darstellung von Interim hinzugefügt

# %% [markdown]
# Adding all planners
# ===========

# %%
import sys
import HelperClass
sys.path.append("templates")
# %load_ext autoreload
# %autoreload 2

# %%
from IPPerfMonitor import IPPerfMonitor

import IPVISBasicPRM
import IPBasicPRM_Roundtrip

import IPVisibilityPRM_Roundtrip
import IPVISVisibilityPRM
import Optimized_IPVisibilityPRM_Roundtrip

import IPLazyPRM_Roundtrip
import IPVISLazyPRM

# %% [markdown]
# Set-up of the test scenario and the configuration for all planner
# ===================================
#
# Following a procedure to compare all discussed planners are shown:
#
# 1. Configuration for every planner is defined
# 2. The configuration and the planner is stored in the variable setup, a Python dict()
# 3. the variable setup is then used to uniformly call the planning calls

# %%
plannerFactory = dict()

#basicConfig = dict()
#basicConfig["radius"] = 3
#basicConfig["numNodes"] = 200
#plannerFactory["basePRM"] = [IPBasicPRM_Roundtrip.BasicPRM, basicConfig, IPVISBasicPRM.basicPRMVisualize]

'''
visbilityConfig = dict()
visbilityConfig["ntry"] = 300
plannerFactory["visibilityPRM"] = [IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]
'''

visbilityConfig = dict()
visbilityConfig["ntry"] = 300
plannerFactory["visibilityPRM"] = [Optimized_IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]


#lazyConfig = dict()
#lazyConfig["initialRoadmapSize"] = 10
#lazyConfig["updateRoadmapSize"]  = 5
#lazyConfig["kNearest"] = 5
#plannerFactory["lazyPRM"] = [IPLazyPRM_Roundtrip.LazyPRM, lazyConfig, IPVISLazyPRM.lazyPRMVisualize]

# %%
class ResultCollection (object):
    
    def __init__(self, plannerFactoryName, planner, benchmark, solution, perfDataFrame):
        self.plannerFactoryName = plannerFactoryName
        self.planner = planner
        self.benchmark = benchmark
        self.solution = solution
        self.perfDataFrame = perfDataFrame

# %%
import IPTestSuite
import importlib

# %%
importlib.reload(IPTestSuite)
# Out:
# <module 'IPTestSuite' from '/home/maurice/Dokumente/Projekt_Roboterprogrammierung/09_01_24_NeuerStand/RKIM23RobotProgramDS/02_eigeneNotebooks/IPTestSuite.py'>

# %%
fullBenchList = IPTestSuite.benchList

for benchmark in fullBenchList:
    print(benchmark.name)
# Out:
# Trap
# Bottleneck
# Fat bottleneck
# B_rush
# circle od death

# %%
resultList = list()
testList = fullBenchList[:1]

for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')
    #print(key, producer)
    for benchmark in testList:
        HelperClass.HelperClass.printInColor("Planning: " + key + " - " + benchmark.name, 'yellow')
        #planner = IPBasicPRM.BasicPRM(benchmark.collisionChecker)
        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        

        try:
            resultList.append(ResultCollection(key,
                                        planner, 
                                        benchmark, 
                                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                                        IPPerfMonitor.dataFrame()),)
            #a = planner.planPath(benchmark.startList,benchmark.goalList,producer[1])
            # print("")


        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            import traceback
            HelperClass.HelperClass.printInColor(traceback.print_exc(), 'red')

            pass
# Out:
# <font color='yellow'>visibilityPRM [<class 'Optimized_IPVisibilityPRM_Roundtrip.VisPRM'>, {'ntry': 300}, <function visibilityPRMVisualize at 0x7f132d5dafc0>]</font>
# <font color='yellow'>Planning: visibilityPRM - Trap</font>
# node added  interim0
# node added  interim1
# node added  interim2
# node added  interim3
# node added  interim4
# while schleife beginnt  0
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 0
# Scahue ob qpos und g sich sehen können, qpos und g : [8.375077445413304, 15.654518682857297]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# is Guard
# nodenumber 0
# Scahue ob qpos und g sich sehen können, qpos und g : [8.375077445413304, 15.654518682857297]   interim0   [3, 10]
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# is Guard
# nodenumber 0
# Scahue ob qpos und g sich sehen können, qpos und g : [8.375077445413304, 15.654518682857297]   interim1   [22, 8]
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# is Guard
# nodenumber 0
# Scahue ob qpos und g sich sehen können, qpos und g : [8.375077445413304, 15.654518682857297]   interim2   [3, 3]
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# is Guard
# nodenumber 0
# Scahue ob qpos und g sich sehen können, qpos und g : [8.375077445413304, 15.654518682857297]   interim3   [20, 15]
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# is Guard
# nodenumber 0
# Scahue ob qpos und g sich sehen können, qpos und g : [8.375077445413304, 15.654518682857297]   interim4   [10, 1]
# while schleife beginnt  1
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 1
# Scahue ob qpos und g sich sehen können, qpos und g : [4.107836803701381, 2.1953582049847804]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  0
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 2
# Scahue ob qpos und g sich sehen können, qpos und g : [9.219852859700692, 1.203564947927829]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 2
# Scahue ob qpos und g sich sehen können, qpos und g : [9.219852859700692, 1.203564947927829]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
# while schleife beginnt  1
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 3
# Scahue ob qpos und g sich sehen können, qpos und g : [2.773773618982033, 0.5323505754299225]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 3
# Scahue ob qpos und g sich sehen können, qpos und g : [2.773773618982033, 0.5323505754299225]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
# while schleife beginnt  2
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 4
# Scahue ob qpos und g sich sehen können, qpos und g : [14.812162815396269, 1.5127551615725383]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 4
# Scahue ob qpos und g sich sehen können, qpos und g : [14.812162815396269, 1.5127551615725383]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
# while schleife beginnt  3
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 5
# Scahue ob qpos und g sich sehen können, qpos und g : [10.041678511634391, 0.866778294901277]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 5
# Scahue ob qpos und g sich sehen können, qpos und g : [10.041678511634391, 0.866778294901277]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
# while schleife beginnt  4
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 6
# Scahue ob qpos und g sich sehen können, qpos und g : [12.37269424822915, 10.93963553145185]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 6
# Scahue ob qpos und g sich sehen können, qpos und g : [12.37269424822915, 10.93963553145185]   1   [4.107836803701381, 2.1953582049847804]
# while schleife beginnt  5
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 7
# Scahue ob qpos und g sich sehen können, qpos und g : [13.187898810496291, 4.516019517510385]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 7
# Scahue ob qpos und g sich sehen können, qpos und g : [13.187898810496291, 4.516019517510385]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
# while schleife beginnt  6
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 8
# Scahue ob qpos und g sich sehen können, qpos und g : [5.878620810779921, 3.1435882843588585]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 8
# Scahue ob qpos und g sich sehen können, qpos und g : [5.878620810779921, 3.1435882843588585]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
# while schleife beginnt  7
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 9
# Scahue ob qpos und g sich sehen können, qpos und g : [12.731128735172021, 16.901079931702178]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 9
# Scahue ob qpos und g sich sehen können, qpos und g : [12.731128735172021, 16.901079931702178]   1   [4.107836803701381, 2.1953582049847804]
# while schleife beginnt  8
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 10
# Scahue ob qpos und g sich sehen können, qpos und g : [13.73033111606908, 12.96020701932605]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 10
# Scahue ob qpos und g sich sehen können, qpos und g : [13.73033111606908, 12.96020701932605]   1   [4.107836803701381, 2.1953582049847804]
# while schleife beginnt  9
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 11
# Scahue ob qpos und g sich sehen können, qpos und g : [9.276194677981291, 19.347520187000615]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 11
# Scahue ob qpos und g sich sehen können, qpos und g : [9.276194677981291, 19.347520187000615]   1   [4.107836803701381, 2.1953582049847804]
# while schleife beginnt  10
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 12
# Scahue ob qpos und g sich sehen können, qpos und g : [10.744373380816615, 16.759585339549467]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 12
# Scahue ob qpos und g sich sehen können, qpos und g : [10.744373380816615, 16.759585339549467]   1   [4.107836803701381, 2.1953582049847804]
# while schleife beginnt  11
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 13
# Scahue ob qpos und g sich sehen können, qpos und g : [9.348996727356202, 1.0115749187369218]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 13
# Scahue ob qpos und g sich sehen können, qpos und g : [9.348996727356202, 1.0115749187369218]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
# while schleife beginnt  12
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 14
# Scahue ob qpos und g sich sehen können, qpos und g : [12.984062821883787, 18.500651092730276]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 14
# Scahue ob qpos und g sich sehen können, qpos und g : [12.984062821883787, 18.500651092730276]   1   [4.107836803701381, 2.1953582049847804]
# while schleife beginnt  13
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 15
# Scahue ob qpos und g sich sehen können, qpos und g : [17.25634764803374, 18.168781810803132]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 15
# Scahue ob qpos und g sich sehen können, qpos und g : [17.25634764803374, 18.168781810803132]   1   [4.107836803701381, 2.1953582049847804]
# while schleife beginnt  0
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 16
# Scahue ob qpos und g sich sehen können, qpos und g : [7.2572646933896445, 19.550804235124396]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 16
# Scahue ob qpos und g sich sehen können, qpos und g : [7.2572646933896445, 19.550804235124396]   1   [4.107836803701381, 2.1953582049847804]
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 16
# Scahue ob qpos und g sich sehen können, qpos und g : [7.2572646933896445, 19.550804235124396]   15   [17.25634764803374, 18.168781810803132]
# while schleife beginnt  1
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 17
# Scahue ob qpos und g sich sehen können, qpos und g : [4.617999236641863, 4.030948275332767]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 17
# Scahue ob qpos und g sich sehen können, qpos und g : [4.617999236641863, 4.030948275332767]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 17
# Scahue ob qpos und g sich sehen können, qpos und g : [4.617999236641863, 4.030948275332767]   15   [17.25634764803374, 18.168781810803132]
# while schleife beginnt  2
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 18
# Scahue ob qpos und g sich sehen können, qpos und g : [3.433169690688294, 17.513230844770355]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 18
# Scahue ob qpos und g sich sehen können, qpos und g : [3.433169690688294, 17.513230844770355]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 18
# Scahue ob qpos und g sich sehen können, qpos und g : [3.433169690688294, 17.513230844770355]   15   [17.25634764803374, 18.168781810803132]
# while schleife beginnt  3
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 19
# Scahue ob qpos und g sich sehen können, qpos und g : [14.658400739553716, 17.838708698320165]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 19
# Scahue ob qpos und g sich sehen können, qpos und g : [14.658400739553716, 17.838708698320165]   1   [4.107836803701381, 2.1953582049847804]
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 19
# Scahue ob qpos und g sich sehen können, qpos und g : [14.658400739553716, 17.838708698320165]   15   [17.25634764803374, 18.168781810803132]
# while schleife beginnt  4
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 20
# Scahue ob qpos und g sich sehen können, qpos und g : [8.94601926588002, 2.8282177209117907]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 20
# Scahue ob qpos und g sich sehen können, qpos und g : [8.94601926588002, 2.8282177209117907]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 20
# Scahue ob qpos und g sich sehen können, qpos und g : [8.94601926588002, 2.8282177209117907]   15   [17.25634764803374, 18.168781810803132]
# while schleife beginnt  5
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 21
# Scahue ob qpos und g sich sehen können, qpos und g : [14.805791648333802, 15.992274417032712]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 21
# Scahue ob qpos und g sich sehen können, qpos und g : [14.805791648333802, 15.992274417032712]   1   [4.107836803701381, 2.1953582049847804]
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 21
# Scahue ob qpos und g sich sehen können, qpos und g : [14.805791648333802, 15.992274417032712]   15   [17.25634764803374, 18.168781810803132]
# while schleife beginnt  6
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 22
# Scahue ob qpos und g sich sehen können, qpos und g : [19.18302567467302, 13.937192424553814]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 22
# Scahue ob qpos und g sich sehen können, qpos und g : [19.18302567467302, 13.937192424553814]   1   [4.107836803701381, 2.1953582049847804]
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 22
# Scahue ob qpos und g sich sehen können, qpos und g : [19.18302567467302, 13.937192424553814]   15   [17.25634764803374, 18.168781810803132]
# is visible
# found
# while schleife beginnt  7
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 23
# Scahue ob qpos und g sich sehen können, qpos und g : [19.511688462799977, 20.66088256957787]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 23
# Scahue ob qpos und g sich sehen können, qpos und g : [19.511688462799977, 20.66088256957787]   1   [4.107836803701381, 2.1953582049847804]
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 23
# Scahue ob qpos und g sich sehen können, qpos und g : [19.511688462799977, 20.66088256957787]   15   [17.25634764803374, 18.168781810803132]
# is visible
# found
# while schleife beginnt  8
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 24
# Scahue ob qpos und g sich sehen können, qpos und g : [14.394838932451794, 1.613209097257521]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 24
# Scahue ob qpos und g sich sehen können, qpos und g : [14.394838932451794, 1.613209097257521]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 24
# Scahue ob qpos und g sich sehen können, qpos und g : [14.394838932451794, 1.613209097257521]   15   [17.25634764803374, 18.168781810803132]
# while schleife beginnt  9
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 25
# Scahue ob qpos und g sich sehen können, qpos und g : [8.239638248542292, 14.958425537028493]   start   [9, 15]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 25
# Scahue ob qpos und g sich sehen können, qpos und g : [8.239638248542292, 14.958425537028493]   1   [4.107836803701381, 2.1953582049847804]
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 25
# Scahue ob qpos und g sich sehen können, qpos und g : [8.239638248542292, 14.958425537028493]   15   [17.25634764803374, 18.168781810803132]
# while schleife beginnt  10
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 26
# Scahue ob qpos und g sich sehen können, qpos und g : [20.264351239809127, 20.871341833974704]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 26
# Scahue ob qpos und g sich sehen können, qpos und g : [20.264351239809127, 20.871341833974704]   1   [4.107836803701381, 2.1953582049847804]
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 26
# Scahue ob qpos und g sich sehen können, qpos und g : [20.264351239809127, 20.871341833974704]   15   [17.25634764803374, 18.168781810803132]
# is visible
# found
# while schleife beginnt  11
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 27
# Scahue ob qpos und g sich sehen können, qpos und g : [17.08173530001857, 5.8783324491184725]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 27
# Scahue ob qpos und g sich sehen können, qpos und g : [17.08173530001857, 5.8783324491184725]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {15}
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 27
# Scahue ob qpos und g sich sehen können, qpos und g : [17.08173530001857, 5.8783324491184725]   15   [17.25634764803374, 18.168781810803132]
# is visible
# not visible
# Kante wird hinzugefügt
# found
# Merged = trure
# while schleife beginnt  12
#
# for schleife beginnt comp:  {'start'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 28
# Scahue ob qpos und g sich sehen können, qpos und g : [0.7655450610264383, 10.528548077942178]   start   [9, 15]
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {1, 27, 15}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# ...
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  290
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 626
# Scahue ob qpos und g sich sehen können, qpos und g : [10.412207618644384, 21.740469543825057]   1   [4.107836803701381, 2.1953582049847804]
# Eigenschaften von G  67   {'pos': [6.001286293895816, 19.51128680709237], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 626
# Scahue ob qpos und g sich sehen können, qpos und g : [10.412207618644384, 21.740469543825057]   67   [6.001286293895816, 19.51128680709237]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  291
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 627
# Scahue ob qpos und g sich sehen können, qpos und g : [1.2728555166473263, 10.153400898619736]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  292
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 628
# Scahue ob qpos und g sich sehen können, qpos und g : [1.1766006258830985, 7.057214912269636]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  293
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 629
# Scahue ob qpos und g sich sehen können, qpos und g : [9.964142793764202, 2.0397004944453174]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  294
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 630
# Scahue ob qpos und g sich sehen können, qpos und g : [12.9058498047574, 19.253670856396887]   1   [4.107836803701381, 2.1953582049847804]
# Eigenschaften von G  67   {'pos': [6.001286293895816, 19.51128680709237], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 630
# Scahue ob qpos und g sich sehen können, qpos und g : [12.9058498047574, 19.253670856396887]   67   [6.001286293895816, 19.51128680709237]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  295
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 631
# Scahue ob qpos und g sich sehen können, qpos und g : [12.187339146895395, 21.280179125132843]   1   [4.107836803701381, 2.1953582049847804]
# Eigenschaften von G  67   {'pos': [6.001286293895816, 19.51128680709237], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 631
# Scahue ob qpos und g sich sehen können, qpos und g : [12.187339146895395, 21.280179125132843]   67   [6.001286293895816, 19.51128680709237]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  296
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 632
# Scahue ob qpos und g sich sehen können, qpos und g : [8.544826257676718, 2.362221333553708]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  297
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 633
# Scahue ob qpos und g sich sehen können, qpos und g : [13.596508644420885, 20.27719057675965]   1   [4.107836803701381, 2.1953582049847804]
# Eigenschaften von G  67   {'pos': [6.001286293895816, 19.51128680709237], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 633
# Scahue ob qpos und g sich sehen können, qpos und g : [13.596508644420885, 20.27719057675965]   67   [6.001286293895816, 19.51128680709237]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  298
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 634
# Scahue ob qpos und g sich sehen können, qpos und g : [17.876600237392758, 15.962290388708492]   1   [4.107836803701381, 2.1953582049847804]
# Eigenschaften von G  67   {'pos': [6.001286293895816, 19.51128680709237], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 634
# Scahue ob qpos und g sich sehen können, qpos und g : [17.876600237392758, 15.962290388708492]   67   [6.001286293895816, 19.51128680709237]
# Eigenschaften von G  68   {'pos': [3.4316008246310306, 21.61430724729614], 'color': 'lightblue', 'nodeType': 'Connection'}
# Eigenschaften von G  39   {'pos': [16.801728242126632, 21.123305726615193], 'color': 'lightblue', 'nodeType': 'Connection'}
# Eigenschaften von G  start   {'pos': [9, 15], 'color': 'lawngreen', 'nodeType': 'Guard'}
# is Guard
# nodenumber 634
# Scahue ob qpos und g sich sehen können, qpos und g : [17.876600237392758, 15.962290388708492]   start   [9, 15]
# Eigenschaften von G  15   {'pos': [17.25634764803374, 18.168781810803132], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 634
# Scahue ob qpos und g sich sehen können, qpos und g : [17.876600237392758, 15.962290388708492]   15   [17.25634764803374, 18.168781810803132]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# while schleife beginnt  299
#
# for schleife beginnt comp:  {1, 67, 68, 39, 'start', 15, 335, 339, 27}
# Eigenschaften von G  1   {'pos': [4.107836803701381, 2.1953582049847804], 'color': 'red', 'nodeType': 'Guard'}
# is Guard
# nodenumber 635
# Scahue ob qpos und g sich sehen können, qpos und g : [0.4839656261745833, 12.419198002597875]   1   [4.107836803701381, 2.1953582049847804]
# is visible
# found
#
# for schleife beginnt comp:  {'interim0'}
# Eigenschaften von G  interim0   {'pos': [3, 10], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim1'}
# Eigenschaften von G  interim1   {'pos': [22, 8], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim2'}
# Eigenschaften von G  interim2   {'pos': [3, 3], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim3'}
# Eigenschaften von G  interim3   {'pos': [20, 15], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
#
# for schleife beginnt comp:  {'interim4'}
# Eigenschaften von G  interim4   {'pos': [10, 1], 'color': 'Dodgerblue', 'nodeType': 'Guard'}
# Interim bereits hinzugefügt, daher nicht wieder
# -------
# Build Roadmap abgeschlossen
# Edges  [('start', 39), (1, 27), (1, 68), (1, 339), (15, 27), (15, 39), (67, 68), (335, 339)]
# Nodes  ['start', 'interim0', 'interim1', 'interim2', 'interim3', 'interim4', 1, 15, 27, 39, 67, 68, 335, 339]

# %%
import matplotlib.pyplot as plt

for result in resultList:
    fig_local = plt.figure(figsize=(10,10))
    ax = fig_local.add_subplot(1,1,1)
    title = result.plannerFactoryName + " - " + result.benchmark.name
    if result.solution == []:
        title += " (No path found!)"
    title += "\n Assumed complexity level " + str(result.benchmark.level)
    ax.set_title(title)

    ax.grid(True)
    
    try:
        #IPVISBasicsPRM.basicPRMVisualize(result.planner, result.solution, ax=ax, nodeSize=100))
        plannerFactory[result.plannerFactoryName][2](result.planner, result.solution, ax=ax, nodeSize=100)
        print("")
        print("Planner: "+ str(result.planner))
        print("Solution" + str(result.solution))

    except Exception as e:
        print ("Error")
        print(e)
        pass
# Out:
# <__main__.ResultCollection object at 0x7f132c365950>
#  plannerFactoryName  <function visibilityPRMVisualize at 0x7f132d5dafc0>
# Error
# Node 'start' has no position.

# %%
import numpy as np
for bench in testList:
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    
    try:
        for result in resultList:
            if result.benchmark.name == bench.name:
                #print result.benchmark.name  + " - " +  result.plannerFactoryName, len(result.solution)
                pathLength[result.plannerFactoryName] = len(result.solution)
                planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
                roadmapSize[result.plannerFactoryName] = result.planner.graph.size()


        fig, ax = plt.subplots()

        width = 0.2

        ax.bar(np.arange(len(pathLength.keys())), pathLength.values(),width, color="blue")
        ax.set_ylabel(title + " Path length (number of nodes!)", color="blue")
        ax.set_xticks(np.arange(len(pathLength.keys())) + width)
        ax.set_xticklabels(pathLength.keys())

        ax2 = ax.twinx()
        bar = ax2.bar(np.arange(len(pathLength.keys()))+width, planningTime.values(),width, color="red")
        ax2.set_ylabel(title + " Planning time", color="y")

        # Add coloring and patterns on axis two
        hatches = ['x' if length==0 else '' for length in pathLength.values()]
        color   = ['red' if length==0 else 'yellow' for length in pathLength.values()]
        for i,thisbar in enumerate(bar.patches):
            thisbar.set_facecolor(color[i])
            thisbar.set_hatch(hatches[i])

        # Multiple axes 
        ax3 = ax.twinx()
        ax3.bar(np.arange(len(pathLength.keys()))+2*width, roadmapSize.values(),width, color="purple")
        ax3.set_ylabel(title + " Roadmap size",  color="purple")
        ax3.spines['right'].set_position(('axes', 1.15))
        ax3.spines['right'].set_color("purple")
    except:
        pass

# %% [markdown]
# result.perfDataFrame.groupby(["name"]).sum()

# %%
result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)
# Out:
#                             time
# name
# _getRandomFreePosition  0.022175
# _learnRoadmap           1.039881
# lineInCollision         0.841309
# planRoundPath           1.040407
# pointInCollision        0.660535

# %%
result.perfDataFrame[result.perfDataFrame["name"]=="planRoundPath"]
# Out:
#               name                                               args kwargs  \
# 637  planRoundPath  (<Optimized_IPVisibilityPRM_Roundtrip.VisPRM o...     {}
#
#     retVal      time
# 637     []  1.040407

# %%
result.perfDataFrame[result.perfDataFrame["name"]=="planRoundPath"][result.perfDataFrame["retVal"]==False]["time"].sum(numeric_only=True)
# Out:
# /tmp/ipykernel_39205/2940436852.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result.perfDataFrame[result.perfDataFrame["name"]=="planRoundPath"][result.perfDataFrame["retVal"]==False]["time"].sum(numeric_only=True)
# 0.0
