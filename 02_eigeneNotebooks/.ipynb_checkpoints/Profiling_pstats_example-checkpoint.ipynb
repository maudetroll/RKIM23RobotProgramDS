# %% [markdown]
# Example Profiling
# ==============================
#
#
#
# Example using cProfile/pstats
# -----------------------------
#
# Following an example how to profile the algorithm using https://docs.python.org/3/library/profile.html

# %%
import IPTestSuite
import IPLazyPRM_Roundtrip
import IPVisibilityPRM_Roundtrip
import IPBasicPRM_Roundtrip
import IPVISVisibilityPRM
import HelperClass
from IPPerfMonitor import IPPerfMonitor



from __future__ import print_function
import sys

from IPython.utils import io

from matplotlib import pylab as plt

benchList = IPTestSuite.benchList
print(benchList)


start = benchList[0].startList
goal = benchList[0].goalList

plannerFactory = dict()

# basicConfig = dict()
# basicConfig["radius"] = 3
# basicConfig["numNodes"] = 200
# plannerFactory["basePRM"] = [IPBasicPRM_Roundtrip.BasicPRM, basicConfig, IPVISBasicPRM.basicPRMVisualize]

visbilityConfig = dict()
visbilityConfig["ntry"] = 300
plannerFactory["visibilityPRM"] = [IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]

# lazyConfig = dict()
# lazyConfig["initialRoadmapSize"] = 50
# lazyConfig["updateRoadmapSize"]  = 2
# lazyConfig["kNearest"] = 10
# plannerFactory["lazyPRM"] = [IPLazyPRM_Roundtrip.LazyPRM, lazyConfig, IPVISLazyPRM.lazyPRMVisualize]
# Out:
# [<IPBenchmark.Benchmark object at 0x7f3b624f3710>, <IPBenchmark.Benchmark object at 0x7f3b6213ebd0>, <IPBenchmark.Benchmark object at 0x7f3b6213efd0>, <IPBenchmark.Benchmark object at 0x7f3b6213f750>, <IPBenchmark.Benchmark object at 0x7f3b62154390>]

# %%
class ResultCollection (object):
    
    def __init__(self, plannerFactoryName, planner, benchmark, solution, perfDataFrame):
        self.plannerFactoryName = plannerFactoryName
        self.planner = planner
        self.benchmark = benchmark
        self.solution = solution
        self.perfDataFrame = perfDataFrame

# %%
resultList = list()
testList = benchList[:1]

for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')
    #print(key, producer)
    for benchmark in testList:
        #HelperClass.HelperClass.printInColor("Planning: " + key + " - " + benchmark.name, 'yellow')
        #planner = IPBasicPRM.BasicPRM(benchmark.collisionChecker)
        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        

        try:
            with io.capture_output() as captured:
                resultList.append(ResultCollection(key,
                                        planner, 
                                        benchmark, 
                                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                                        IPPerfMonitor.dataFrame()),)
            #a = planner.planPath(benchmark.startList,benchmark.goalList,producer[1])
            # print("")


        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            pass
# Out:
# <font color='yellow'>visibilityPRM [<class 'IPVisibilityPRM_Roundtrip.VisPRM'>, {'ntry': 300}, <function visibilityPRMVisualize at 0x7f3b5fe3e840>]</font>

# %%
# Executing the planning. Stats data will be saved in astarstats
import cProfile
from IPPRMBase import PRMBase

print(benchList)

planner = producer[0](benchmark.collisionChecker)

with io.capture_output() as captured:
    cProfile.run('solution =planner.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,producer[1])','visibilitystats') # will save astartstats to current directory
# Out:
# [<IPBenchmark.Benchmark object at 0x7f3b624f3710>, <IPBenchmark.Benchmark object at 0x7f3b6213ebd0>, <IPBenchmark.Benchmark object at 0x7f3b6213efd0>, <IPBenchmark.Benchmark object at 0x7f3b6213f750>, <IPBenchmark.Benchmark object at 0x7f3b62154390>]

# %%
# utility functions to read and access data in astartstats
import pstats
from pstats import SortKey

p = pstats.Stats('visibilitystats')
p.strip_dirs().sort_stats(SortKey.CALLS).print_stats()
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p.sort_stats(SortKey.CALLS).print_stats(15)
p.sort_stats(SortKey.TIME).print_stats(15)

fig_local = plt.figure(figsize=(10,10))
ax = fig_local.add_subplot(1,1,1)
  
for bench, result in zip(testList, resultList):
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    if result.benchmark.name == bench.name:
        #print result.benchmark.name  + " - " +  result.plannerFactoryName, len(result.solution)
        pathLength[result.plannerFactoryName] = len(result.solution)
        planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
        roadmapSize[result.plannerFactoryName] = result.planner.graph.size()

    IPVISVisibilityPRM.visibilityPRMVisualize(result.planner, result.solution, ax=ax, nodeSize=100)
# Out:
# Tue Jan  9 12:12:54 2024    visibilitystats
#
#          659032 function calls (643398 primitive calls) in 1.093 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    118456    0.101    0.000    0.101    0.000 base.py:245(__setattr__)
#     75224    0.013    0.000    0.013    0.000 {built-in method builtins.len}
#     59228    0.014    0.000    0.014    0.000 base.py:228(_geom)
#     31286    0.012    0.000    0.012    0.000 {built-in method builtins.isinstance}
#     31270    0.008    0.000    0.008    0.000 {built-in method time.time}
#     30139    0.009    0.000    0.009    0.000 {built-in method builtins.hasattr}
#     29614    0.025    0.000    0.037    0.000 topology.py:18(_validate)
#     29614    0.070    0.000    0.126    0.000 base.py:191(_empty)
#     16941    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#     15819    0.003    0.000    0.003    0.000 IPEnvironment.py:23(getDim)
#     15635    0.054    0.000    0.054    0.000 IPPerfMonitor.py:38(__get__)
#   15635/1    0.050    0.000    1.093    1.093 IPPerfMonitor.py:24(__call__)
#     14910    0.003    0.000    0.003    0.000 {method 'items' of 'dict' objects}
#     14807    0.162    0.000    0.181    0.000 point.py:244(geos_point_from_py)
#     14807    0.059    0.000    0.359    0.000 point.py:38(__init__)
#     14807    0.026    0.000    0.243    0.000 base.py:803(intersects)
#     14807    0.005    0.000    0.005    0.000 geos.py:607(errcheck_predicate)
#     14807    0.005    0.000    0.005    0.000 impl.py:56(__getitem__)
#     14807    0.016    0.000    0.099    0.000 base.py:208(__del__)
#     14807    0.164    0.000    0.212    0.000 predicates.py:11(__call__)
#     14807    0.025    0.000    0.101    0.000 base.py:240(_set_geom)
#     14807    0.082    0.000    0.794    0.000 IPEnvironment.py:31(pointInCollision)
#      2270    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      2144    0.001    0.000    0.001    0.000 traitlets.py:651(get)
#      2144    0.001    0.000    0.002    0.000 traitlets.py:689(__get__)
#      2144    0.000    0.000    0.000    0.000 inspect.py:2751(kind)
#      2092    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      1806    0.001    0.000    0.002    0.000 {method 'update' of 'set' objects}
#      1505    0.000    0.000    0.000    0.000 coreviews.py:43(__init__)
#      1504    0.001    0.000    0.001    0.000 coreviews.py:49(__iter__)
#      1504    0.002    0.000    0.002    0.000 coreviews.py:80(__getitem__)
#      1476    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#      1184    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#      1082    0.000    0.000    0.000    0.000 reportviews.py:205(__call__)
#      1041    0.001    0.000    0.001    0.000 reportviews.py:188(__getitem__)
#      1008    0.002    0.000    0.002    0.000 {built-in method numpy.array}
#       822    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       816    0.000    0.000    0.000    0.000 inspect.py:2739(name)
#       768    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#       704    0.001    0.000    0.002    0.000 formatters.py:552(_in_deferred_types)
#       690    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       690    0.001    0.000    0.001    0.000 random.py:520(uniform)
#       633    0.002    0.000    0.010    0.000 connected.py:15(connected_components)
#       576    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#       557    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       507    0.002    0.000    0.002    0.000 graph.py:893(add_edge)
#       503    0.125    0.000    1.005    0.002 IPEnvironment.py:42(lineInCollision)
#       496    0.001    0.000    0.003    0.000 IPVisibilityPRM_Roundtrip.py:26(addVisTest)
#       496    0.001    0.000    0.990    0.002 IPVisibilityPRM_Roundtrip.py:38(_isVisible)
#       345    0.001    0.000    0.002    0.000 IPPRMBase.py:25(<listcomp>)
#       345    0.001    0.000    0.003    0.000 IPPRMBase.py:23(_getRandomPosition)
#       345    0.000    0.000    0.000    0.000 IPEnvironment.py:27(getEnvironmentLimits)
#       330    0.004    0.000    0.008    0.000 connected.py:191(_plain_bfs)
#       317    0.001    0.000    0.002    0.000 backends.py:129(wrapper)
#       317    0.000    0.000    0.000    0.000 graph.py:1557(is_directed)
#       315    0.001    0.000    0.001    0.000 graph.py:515(add_node)
#       303    0.001    0.000    0.001    0.000 <class 'networkx.utils.decorators.argmap'> compilation 4:1(argmap_connected_components_1)
#       303    0.000    0.000    0.000    0.000 graph.py:435(__iter__)
#       303    0.000    0.000    0.000    0.000 decorators.py:82(_not_implemented_for)
#       303    0.001    0.000    0.002    0.000 IPVisibilityPRM_Roundtrip.py:22(addNodeAtPos)
#       303    0.001    0.000    0.026    0.000 IPPRMBase.py:28(_getRandomFreePosition)
#       244    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       224    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       192    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       192    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       192    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       192    0.001    0.000    0.001    0.000 inspect.py:2839(args)
#       192    0.001    0.000    0.001    0.000 inspect.py:2892(apply_defaults)
#       192    0.002    0.000    0.003    0.000 inspect.py:3076(_bind)
#       192    0.000    0.000    0.010    0.000 formatters.py:219(catch_format_error)
#       192    0.001    0.000    0.018    0.000 decorator.py:229(fun)
#       192    0.001    0.000    0.007    0.000 decorator.py:199(fix)
#       192    0.000    0.000    0.000    0.000 pretty.py:321(_get_mro)
#       192    0.001    0.000    0.001    0.000 inspect.py:2862(kwargs)
#       192    0.000    0.000    0.004    0.000 inspect.py:3207(bind)
#       192    0.000    0.000    0.000    0.000 inspect.py:2831(__init__)
#       176    0.001    0.000    0.004    0.000 formatters.py:396(lookup_by_type)
#       176    0.000    0.000    0.005    0.000 formatters.py:373(lookup)
#       176    0.000    0.000    0.000    0.000 formatters.py:273(_get_type)
#       176    0.000    0.000    0.000    0.000 formatters.py:358(_check_return)
#       176    0.000    0.000    0.001    0.000 dir2.py:54(get_real_method)
#       176    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#       144    0.001    0.000    0.006    0.000 formatters.py:330(__call__)
#       135    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       130    0.000    0.000    0.000    0.000 distance.py:313(_validate_vector)
#       112    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#        78    0.000    0.000    0.000    0.000 reportviews.py:311(__init__)
#        78    0.000    0.000    0.000    0.000 reportviews.py:329(__iter__)
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        67    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        65    0.000    0.000    0.002    0.000 _misc.py:17(norm)
#        65    0.000    0.000    0.002    0.000 distance.py:429(minkowski)
#        65    0.000    0.000    0.003    0.000 distance.py:500(euclidean)
#        65    0.000    0.000    0.000    0.000 function_base.py:562(asarray_chkfinite)
#        61    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        48    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        48    0.000    0.000    0.000    0.000 pretty.py:495(enq)
#        48    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#        48    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#        47    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        38    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#        36    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        35    0.000    0.000    0.001    0.000 linalg.py:2342(norm)
#        35    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(norm)
#        35    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#        35    0.000    0.000    0.000    0.000 linalg.py:2338(_norm_dispatcher)
#        32    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        32    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        32    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        32    0.000    0.000    0.000    0.000 pretty.py:304(end_group)
#        32    0.000    0.000    0.000    0.000 pretty.py:512(remove)
#        32    0.000    0.000    0.000    0.000 pretty.py:184(group)
#        32    0.000    0.000    0.000    0.000 pretty.py:280(begin_group)
#        32    0.000    0.000    0.000    0.000 configurable.py:522(instance)
#        30    0.000    0.000    0.000    0.000 blas.py:384(getter)
#        30    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        28    0.000    0.000    0.000    0.000 graph.py:453(__contains__)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        20    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        20    0.001    0.000    0.004    0.000 IPVisibilityPRM_Roundtrip.py:58(_nearestInterim)
#        16    0.000    0.000    0.000    0.000 <frozen genericpath>:16(exists)
#        16    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        16    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        16    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        16    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        16    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#        16    0.000    0.000    0.019    0.001 display_functions.py:105(display)
#        16    0.000    0.000    0.001    0.000 display.py:281(__init__)
#        16    0.000    0.000    0.000    0.000 display.py:349(reload)
#        16    0.000    0.000    0.000    0.000 pretty.py:232(text)
#        16    0.000    0.000    0.001    0.000 pretty.py:372(pretty)
#        16    0.000    0.000    0.019    0.001 formatters.py:90(format)
#        16    0.000    0.000    0.020    0.001 HelperClass.py:9(printInColor)
#        16    0.000    0.000    0.001    0.000 formatters.py:907(__call__)
#        16    0.000    0.000    0.001    0.000 formatters.py:953(__call__)
#        16    0.000    0.000    0.000    0.000 formatters.py:944(_check_return)
#        16    0.000    0.000    0.000    0.000 displaypub.py:130(publish)
#        16    0.000    0.000    0.002    0.000 formatters.py:695(__call__)
#        16    0.000    0.000    0.000    0.000 display.py:342(_data_and_metadata)
#        16    0.000    0.000    0.000    0.000 display.py:418(warn)
#        16    0.000    0.000    0.000    0.000 pretty.py:201(__init__)
#        16    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#        16    0.000    0.000    0.000    0.000 display_functions.py:45(publish_display_data)
#        16    0.000    0.000    0.000    0.000 display.py:434(_repr_html_)
#        16    0.000    0.000    0.000    0.000 pretty.py:355(__init__)
#        16    0.000    0.000    0.001    0.000 pretty.py:775(_repr_pprint)
#        16    0.000    0.000    0.000    0.000 display.py:57(_safe_exists)
#        16    0.000    0.000    0.000    0.000 pretty.py:490(__init__)
#        16    0.000    0.000    0.000    0.000 display.py:405(_check_data)
#        16    0.000    0.000    0.000    0.000 pretty.py:313(flush)
#        16    0.000    0.000    0.000    0.000 display.py:330(__repr__)
#        16    0.000    0.000    0.001    0.000 display.py:417(__init__)
#        16    0.000    0.000    0.000    0.000 configurable.py:566(initialized)
#        16    0.000    0.000    0.000    0.000 contextlib.py:287(helper)
#        16    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#        16    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#        14    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        14    0.000    0.000    0.000    0.000 unweighted.py:259(_bidirectional_pred_succ)
#        14    0.000    0.000    0.001    0.000 generic.py:41(shortest_path)
#        14    0.000    0.000    0.000    0.000 unweighted.py:196(bidirectional_shortest_path)
#        14    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:193(_reshape_dispatcher)
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(reshape)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:198(reshape)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:38(_wrapit)
#        13    0.000    0.000    0.000    0.000 IPVisibilityPRM_Roundtrip.py:41(_getNodeNamebasedOnCoordinates)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amax)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2703(amax)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2698(_amax_dispatcher)
#         7    0.001    0.000    0.001    0.000 {method 'query' of 'scipy.spatial._ckdtree.cKDTree' objects}
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1987(_shape_dispatcher)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1991(shape)
#         7    0.000    0.000    0.000    0.000 numeric.py:1878(isscalar)
#         6    0.000    0.000    0.000    0.000 <frozen _collections_abc>:859(__iter__)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 functools.py:981(__get__)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copy)
#         2    0.000    0.000    0.000    0.000 function_base.py:867(_copy_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:871(copy)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:812(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:790(items)
#         1    0.000    0.000    1.093    1.093 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.003    0.003 IPPlanerBase.py:22(_checkStartGoal)
#         1    0.006    0.006    1.043    1.043 IPVisibilityPRM_Roundtrip.py:96(_learnRoadmap)
#         1    0.001    0.001    1.093    1.093 IPVisibilityPRM_Roundtrip.py:145(planRoundPath)
#         1    0.000    0.000    1.093    1.093 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 graph.py:374(adj)
#         1    0.000    0.000    0.000    0.000 reportviews.py:185(__iter__)
#         1    0.000    0.000    0.000    0.000 function.py:677(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function.py:655(get_node_attributes)
#         1    0.000    0.000    0.000    0.000 graph.py:1519(clear)
#         1    0.000    0.000    0.000    0.000 graph.py:732(nodes)
#         1    0.000    0.000    0.000    0.000 reportviews.py:178(__init__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2829(amin)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2824(_amin_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Tue Jan  9 12:12:54 2024    visibilitystats
#
#          659032 function calls (643398 primitive calls) in 1.093 seconds
#
#    Ordered by: cumulative time
#    List reduced from 209 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.093    1.093 {built-in method builtins.exec}
#         1    0.000    0.000    1.093    1.093 <string>:1(<module>)
#   15635/1    0.050    0.000    1.093    1.093 IPPerfMonitor.py:24(__call__)
#         1    0.001    0.001    1.093    1.093 IPVisibilityPRM_Roundtrip.py:145(planRoundPath)
#         1    0.006    0.006    1.043    1.043 IPVisibilityPRM_Roundtrip.py:96(_learnRoadmap)
#       503    0.125    0.000    1.005    0.002 IPEnvironment.py:42(lineInCollision)
#       496    0.001    0.000    0.990    0.002 IPVisibilityPRM_Roundtrip.py:38(_isVisible)
#     14807    0.082    0.000    0.794    0.000 IPEnvironment.py:31(pointInCollision)
#     14807    0.059    0.000    0.359    0.000 point.py:38(__init__)
#     14807    0.026    0.000    0.243    0.000 base.py:803(intersects)
#     14807    0.164    0.000    0.212    0.000 predicates.py:11(__call__)
#     14807    0.162    0.000    0.181    0.000 point.py:244(geos_point_from_py)
#     29614    0.070    0.000    0.126    0.000 base.py:191(_empty)
#     14807    0.025    0.000    0.101    0.000 base.py:240(_set_geom)
#    118456    0.101    0.000    0.101    0.000 base.py:245(__setattr__)
#
#
# Tue Jan  9 12:12:54 2024    visibilitystats
#
#          659032 function calls (643398 primitive calls) in 1.093 seconds
#
#    Ordered by: call count
#    List reduced from 209 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    118456    0.101    0.000    0.101    0.000 base.py:245(__setattr__)
#     75224    0.013    0.000    0.013    0.000 {built-in method builtins.len}
#     59228    0.014    0.000    0.014    0.000 base.py:228(_geom)
#     31286    0.012    0.000    0.012    0.000 {built-in method builtins.isinstance}
#     31270    0.008    0.000    0.008    0.000 {built-in method time.time}
#     30139    0.009    0.000    0.009    0.000 {built-in method builtins.hasattr}
#     29614    0.025    0.000    0.037    0.000 topology.py:18(_validate)
#     29614    0.070    0.000    0.126    0.000 base.py:191(_empty)
#     16941    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#     15819    0.003    0.000    0.003    0.000 IPEnvironment.py:23(getDim)
#     15635    0.054    0.000    0.054    0.000 IPPerfMonitor.py:38(__get__)
#   15635/1    0.050    0.000    1.093    1.093 IPPerfMonitor.py:24(__call__)
#     14910    0.003    0.000    0.003    0.000 {method 'items' of 'dict' objects}
#     14807    0.162    0.000    0.181    0.000 point.py:244(geos_point_from_py)
#     14807    0.059    0.000    0.359    0.000 point.py:38(__init__)
#
#
# Tue Jan  9 12:12:54 2024    visibilitystats
#
#          659032 function calls (643398 primitive calls) in 1.093 seconds
#
#    Ordered by: internal time
#    List reduced from 209 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     14807    0.164    0.000    0.212    0.000 predicates.py:11(__call__)
#     14807    0.162    0.000    0.181    0.000 point.py:244(geos_point_from_py)
#       503    0.125    0.000    1.005    0.002 IPEnvironment.py:42(lineInCollision)
#    118456    0.101    0.000    0.101    0.000 base.py:245(__setattr__)
#     14807    0.082    0.000    0.794    0.000 IPEnvironment.py:31(pointInCollision)
#     29614    0.070    0.000    0.126    0.000 base.py:191(_empty)
#     14807    0.059    0.000    0.359    0.000 point.py:38(__init__)
#     15635    0.054    0.000    0.054    0.000 IPPerfMonitor.py:38(__get__)
#   15635/1    0.050    0.000    1.093    1.093 IPPerfMonitor.py:24(__call__)
#     14807    0.026    0.000    0.243    0.000 base.py:803(intersects)
#     29614    0.025    0.000    0.037    0.000 topology.py:18(_validate)
#     14807    0.025    0.000    0.101    0.000 base.py:240(_set_geom)
#     14807    0.016    0.000    0.099    0.000 base.py:208(__del__)
#     59228    0.014    0.000    0.014    0.000 base.py:228(_geom)
#     75224    0.013    0.000    0.013    0.000 {built-in method builtins.len}
# /home/maurice/anaconda3/lib/python3.11/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %% [markdown]
# Example using IPerfMonitor
# --------------------------

# %%
from IPPerfMonitor import IPPerfMonitor

# %%
benchList = IPTestSuite.benchList

visbilityConfig = dict()
visbilityConfig["ntry"] = 300
plannerFactory["visibilityPRM"] = [IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]

with io.capture_output() as captured:
    solution = planner.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,producer[1])


start = benchList[0].startList
goal = benchList[0].goalList

data_frame = IPPerfMonitor.dataFrame()

fig_local = plt.figure(figsize=(10,10))
ax = fig_local.add_subplot(1,1,1)

IPVISVisibilityPRM.visibilityPRMVisualize(planner, solution, ax=ax, nodeSize=100)

# %%
data_frame
# Out:
#                    name                                               args  \
# 0      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 1      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 2      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 3      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 4      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# ...                 ...                                                ...
# 54043     _learnRoadmap  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 54044     _learnRoadmap  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 54045     planRoundPath  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 54046     planRoundPath  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 54047     planRoundPath  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
#
#       kwargs                                             retVal      time
# 0         {}                                              False  0.000516
# 1         {}                                              False  0.000188
# 2         {}                                              False  0.000240
# 3         {}                                              False  0.000067
# 4         {}                                              False  0.000060
# ...      ...                                                ...       ...
# 54043     {}                                               None  1.042871
# 54044     {}                                               None  0.843423
# 54045     {}  [start, 13, 17, 0, interim3, 0, 11, interim1, ...  0.793441
# 54046     {}  [start, 1, 27, 0, interim2, 0, interim0, 0, 4,...  1.093233
# 54047     {}  [start, 14, 10, 26, interim3, 26, 2, interim1,...  0.862558
#
# [54048 rows x 5 columns]

# %%
data_frame.groupby(["name"]).sum(numeric_only=True)
# Out:
#                             time
# name
# _getRandomFreePosition  0.058113
# _learnRoadmap           2.659082
# _nearestInterim         0.006935
# lineInCollision         2.574162
# planRoundPath           2.749232
# pointInCollision        2.038633

# %%
data_frame.groupby(["name"]).count()
# Out:
#                          args  kwargs  retVal   time
# name
# _getRandomFreePosition    940     940     940    940
# _learnRoadmap               3       3       0      3
# _nearestInterim            67      67      67     67
# lineInCollision          1905    1905    1905   1905
# planRoundPath               3       3       3      3
# pointInCollision        51130   51130   51130  51130

# %%
data_frame[data_frame["name"]=="pointInCollision"][data_frame["retVal"]==True].count()
# Out:
# /tmp/ipykernel_10243/2402661994.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_frame[data_frame["name"]=="pointInCollision"][data_frame["retVal"]==True].count()
# name      1105
# args      1105
# kwargs    1105
# retVal    1105
# time      1105
# dtype: int64

# %% [markdown]
# Second Example using IPPerfMonitor
# ----------------------------------

# %%
import IPVisibilityPRM_Roundtrip
import IPVISVisibilityPRM

# %%
visbilityConfig = dict()
visbilityConfig["ntry"] = 300

vis = plannerFactory["visibilityPRM"][0](benchList[3].collisionChecker)

start = benchList[3].startList
goal = benchList[3].goalList

IPPerfMonitor.clearData()

with io.capture_output() as captured:
    solution = vis.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,visbilityConfig)

data_frame = IPPerfMonitor.dataFrame()

fig_local = plt.figure(figsize=(10,10))
ax = fig_local.add_subplot(1,1,1)
IPVISVisibilityPRM.visibilityPRMVisualize(vis, solution, ax = ax)
# Out:
# /home/maurice/anaconda3/lib/python3.11/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
data_frame
# Out:
#                    name                                               args  \
# 0      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 1      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 2      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 3      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 4      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# ...                 ...                                                ...
# 51888   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 51889   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 51890   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 51891     _learnRoadmap  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 51892     planRoundPath  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
#
#       kwargs                                             retVal       time
# 0         {}                                              False   0.001711
# 1         {}                                              False   0.000835
# 2         {}                                               True   0.000518
# 3         {}                                              False   0.000700
# 4         {}                                              False   0.000395
# ...      ...                                                ...        ...
# 51888     {}              [[3, 3], 6.519299761155275, interim1]   0.000102
# 51889     {}             [[3, 3], 3.7135915900015113, interim1]   0.000125
# 51890     {}                            [[3, 3], 0.0, interim1]   0.000083
# 51891     {}                                               None  14.384006
# 51892     {}  [start, 0, 304, interim0, 304, 0, 14, 3, inter...  14.512918
#
# [51893 rows x 5 columns]

# %%
data_frame.groupby(["name"]).count()
# Out:
#                          args  kwargs  retVal   time
# name
# _getRandomFreePosition    650     650     650    650
# _learnRoadmap               1       1       0      1
# _nearestInterim            27      27      27     27
# lineInCollision          2419    2419    2419   2419
# planRoundPath               1       1       1      1
# pointInCollision        48795   48795   48795  48795

# %%
data_frame.groupby(["name"]).sum(numeric_only=True)
# Out:
#                              time
# name
# _getRandomFreePosition   0.226519
# _learnRoadmap           14.384006
# _nearestInterim          0.002587
# lineInCollision         14.201658
# planRoundPath           14.512918
# pointInCollision        13.930054
