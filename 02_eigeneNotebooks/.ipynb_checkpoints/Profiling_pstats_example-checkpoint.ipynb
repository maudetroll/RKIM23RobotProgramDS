# %% [markdown]
# Example Profiling
# ==============================
#
#
#
# Example using cProfile/pstats
# -----------------------------
#
# Following an example how to profile the algorithm using https://docs.python.org/3/library/profile.html

# %%
import IPTestSuite
import IPLazyPRM_Roundtrip
import IPVISLazyPRM

import IPVISVisibilityPRM
import IPVisibilityPRM_Roundtrip

import IPBasicPRM_Roundtrip
import IPVISBasicPRM

import HelperClass
from IPPerfMonitor import IPPerfMonitor

import IPVISBasicPRM



from __future__ import print_function
import sys

from IPython.utils import io

from matplotlib import pylab as plt

benchList = IPTestSuite.benchList
print(benchList)


start = benchList[0].startList
goal = benchList[0].goalList

plannerFactory = dict()

basicConfig = dict()
basicConfig["radius"] = 3
basicConfig["numNodes"] = 200
plannerFactory["basePRM"] = [IPBasicPRM_Roundtrip.BasicPRM, basicConfig, IPVISBasicPRM.basicPRMVisualize]

visbilityConfig = dict()
visbilityConfig["ntry"] = 300
plannerFactory["visibilityPRM"] = [IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]

lazyConfig = dict()
lazyConfig["initialRoadmapSize"] = 50
lazyConfig["updateRoadmapSize"]  = 2
lazyConfig["kNearest"] = 10
plannerFactory["lazyPRM"] = [IPLazyPRM_Roundtrip.LazyPRM, lazyConfig, IPVISLazyPRM.lazyPRMVisualize]
# Out:
# [<IPBenchmark.Benchmark object at 0x7f18192d9650>, <IPBenchmark.Benchmark object at 0x7f18191cdfd0>, <IPBenchmark.Benchmark object at 0x7f18191cf790>, <IPBenchmark.Benchmark object at 0x7f18191cfe90>, <IPBenchmark.Benchmark object at 0x7f1818fc4b10>]

# %%
class ResultCollection (object):
    
    def __init__(self, plannerFactoryName, planner, benchmark, solution, perfDataFrame):
        self.plannerFactoryName = plannerFactoryName
        self.planner = planner
        self.benchmark = benchmark
        self.solution = solution
        self.perfDataFrame = perfDataFrame

# %%
resultList = list()
testList = benchList[:1]
i = 0
for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')
    #print(key, producer)
    print(key)
    for benchmark in testList:
        #HelperClass.HelperClass.printInColor("Planning: " + key + " - " + benchmark.name, 'yellow')
        #planner = IPBasicPRM.BasicPRM(benchmark.collisionChecker)
        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        
        print("Hallo")
        try:
            with io.capture_output() as captured:
                resultList.append(ResultCollection(key,
                                        planner, 
                                        benchmark, 
                                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                                        IPPerfMonitor.dataFrame()),)
            #a = planner.planPath(benchmark.startList,benchmark.goalList,producer[1])
            # print("")
            i = i + 1

        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            pass
# Out:
# <font color='yellow'>basePRM [<class 'IPBasicPRM_Roundtrip.BasicPRM'>, {'radius': 3, 'numNodes': 200}, <function basicPRMVisualize at 0x7f180de2ee80>]</font>
# basePRM
# Hallo
# <font color='yellow'>visibilityPRM [<class 'IPVisibilityPRM_Roundtrip.VisPRM'>, {'ntry': 300}, <function visibilityPRMVisualize at 0x7f18191db6a0>]</font>
# visibilityPRM
# Hallo
# <font color='yellow'>lazyPRM [<class 'IPLazyPRM_Roundtrip.LazyPRM'>, {'initialRoadmapSize': 50, 'updateRoadmapSize': 2, 'kNearest': 10}, <function lazyPRMVisualize at 0x7f180dc980e0>]</font>
# lazyPRM
# Hallo

# %%
# Executing the planning. 
import cProfile
from IPPRMBase import PRMBase

for i in plannerFactory:
    print("i",i)
#print(plannerFactory.)

print("plannerFactory 1", plannerFactory["basePRM"])

plannerBasic = resultList[0].planner
plannerBasicProducer = plannerFactory["basePRM"]
plannerVisibility = resultList[1].planner
plannerVisibilityProducer = plannerFactory["visibilityPRM"]
plannerLazy = resultList[2].planner
plannerLazyProducer = plannerFactory["lazyPRM"]


HelperClass.HelperClass.printInColor("BasicPRMRound", "red")
with io.capture_output() as capturedBasic:
    cProfile.run('solution =plannerBasic.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerBasicProducer)','basicstats') 

HelperClass.HelperClass.printInColor("VisibiltyPRMRound", "orange")
with io.capture_output() as capturedVisibility:
    cProfile.run('solution = plannerVisibility.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerVisibilityProducer)','visibilitystats') 
HelperClass.HelperClass.printInColor("LazyPRMRound", "green")
with io.capture_output() as capturedVisibility:
    cProfile.run('solution = plannerLazy.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerLazyProducer)','lazystats')
# Out:
# i basePRM
# i visibilityPRM
# i lazyPRM
# plannerFactory 1 [<class 'IPBasicPRM_Roundtrip.BasicPRM'>, {'radius': 3, 'numNodes': 200}, <function basicPRMVisualize at 0x7f180de2ee80>]
# <font color='red'>BasicPRMRound</font>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 21
#      19 HelperClass.HelperClass.printInColor("BasicPRMRound", "red")
#      20 with io.capture_output() as capturedBasic:
# ---> 21     cProfile.run('solution =plannerBasic.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerBasicProducer)','basicstats')
#      23 HelperClass.HelperClass.printInColor("VisibiltyPRMRound", "orange")
#      24 with io.capture_output() as capturedVisibility:
#
# File ~/anaconda3/lib/python3.11/cProfile.py:17, in run(statement, filename, sort)
#      16 def run(statement, filename=None, sort=-1):
# ---> 17     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#
# File ~/anaconda3/lib/python3.11/profile.py:54, in _Utils.run(self, statement, filename, sort)
#      52 prof = self.profiler()
#      53 try:
# ---> 54     prof.run(statement)
#      55 except SystemExit:
#      56     pass
#
# File ~/anaconda3/lib/python3.11/cProfile.py:96, in Profile.run(self, cmd)
#      94 import __main__
#      95 dict = __main__.__dict__
# ---> 96 return self.runctx(cmd, dict, dict)
#
# File ~/anaconda3/lib/python3.11/cProfile.py:101, in Profile.runctx(self, cmd, globals, locals)
#      99 self.enable()
#     100 try:
# --> 101     exec(cmd, globals, locals)
#     102 finally:
#     103     self.disable()
#
# File <string>:1
#
# File ~/Dokumente/Projekt_Roboterprogrammierung/09_01_24_NeuerStand/RKIM23RobotProgramDS/02_eigeneNotebooks/IPPerfMonitor.py:27, in IPPerfMonitor.__call__(self, *args, **kwargs)
#      24 def __call__(self, *args, **kwargs):
#      26     starttime = time.time()
# ---> 27     ret = self.__f(*args, **kwargs)
#      28     endtime = time.time()
#      29     element = {'args': args, 'kwargs': kwargs, "retVal": ret, "time": endtime-starttime}
#
# File ~/Dokumente/Projekt_Roboterprogrammierung/09_01_24_NeuerStand/RKIM23RobotProgramDS/02_eigeneNotebooks/IPBasicPRM_Roundtrip.py:169, in BasicPRM.planRoundPath(self, startList, interimGoalList, goalList, config)
#     162 checkedInterimGoalList.append(checkedGoalList[0])
#     164 #print(checkedStartList)
#     165 #print(checkedInterimGoalList)
#     166 #print(checkedGoalList)
#     167
#     168 # 2. learn Roadmap
# --> 169 self._learnRoadmapNearestNeighbour(config["radius"],config["numNodes"])
#     171 # 3. find connection of start and goal to roadmap
#     172 # find nearest, collision-free connection between node on graph and start
#     173 result = self._nearestNeighbours(checkedStartList[0], config["radius"])
#
# TypeError: list indices must be integers or slices, not str

# %%
# utility functions to read and access data in astartstats
import pstats
from pstats import SortKey

p = pstats.Stats('visibilitystats')
p.strip_dirs().sort_stats(SortKey.CALLS).print_stats()
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p.sort_stats(SortKey.CALLS).print_stats(15)
p.sort_stats(SortKey.TIME).print_stats(15)

fig_local = plt.figure(figsize=(10,10))
ax = fig_local.add_subplot(1,1,1)
  
    
# Anzeige der Benchmarks, noch nicht mit allen Vis möglich

for bench, result in zip(testList, resultList):
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    if result.benchmark.name == bench.name:
        #print result.benchmark.name  + " - " +  result.plannerFactoryName, len(result.solution)
        pathLength[result.plannerFactoryName] = len(result.solution)
        planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
        roadmapSize[result.plannerFactoryName] = result.planner.graph.size()

    IPVISVisibilityPRM.visibilityPRMVisualize(result.planner, result.solution, ax=ax, nodeSize=100)
# Out:
# Tue Jan  9 12:20:12 2024    visibilitystats
#
#          815468 function calls (796112 primitive calls) in 1.211 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    146736    0.112    0.000    0.112    0.000 base.py:245(__setattr__)
#     93289    0.015    0.000    0.015    0.000 {built-in method builtins.len}
#     73368    0.015    0.000    0.015    0.000 base.py:228(_geom)
#     38902    0.012    0.000    0.012    0.000 {built-in method builtins.isinstance}
#     38714    0.010    0.000    0.010    0.000 {built-in method time.time}
#     37249    0.011    0.000    0.011    0.000 {built-in method builtins.hasattr}
#     36684    0.027    0.000    0.040    0.000 topology.py:18(_validate)
#     36684    0.070    0.000    0.132    0.000 base.py:191(_empty)
#     20840    0.005    0.000    0.005    0.000 {method 'append' of 'list' objects}
#     19700    0.003    0.000    0.003    0.000 IPEnvironment.py:23(getDim)
#     19357    0.061    0.000    0.061    0.000 IPPerfMonitor.py:38(__get__)
#   19357/1    0.055    0.000    1.211    1.211 IPPerfMonitor.py:24(__call__)
#     18453    0.005    0.000    0.005    0.000 {method 'items' of 'dict' objects}
#     18342    0.220    0.000    0.240    0.000 point.py:244(geos_point_from_py)
#     18342    0.062    0.000    0.429    0.000 point.py:38(__init__)
#     18342    0.006    0.000    0.006    0.000 impl.py:56(__getitem__)
#     18342    0.017    0.000    0.106    0.000 base.py:208(__del__)
#     18342    0.165    0.000    0.217    0.000 predicates.py:11(__call__)
#     18342    0.027    0.000    0.249    0.000 base.py:803(intersects)
#     18342    0.005    0.000    0.005    0.000 geos.py:607(errcheck_predicate)
#     18342    0.027    0.000    0.108    0.000 base.py:240(_set_geom)
#     18342    0.090    0.000    0.887    0.000 IPEnvironment.py:31(pointInCollision)
#      3017    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      2468    0.002    0.000    0.003    0.000 {method 'update' of 'set' objects}
#      2412    0.001    0.000    0.001    0.000 traitlets.py:651(get)
#      2412    0.001    0.000    0.002    0.000 traitlets.py:689(__get__)
#      2412    0.000    0.000    0.000    0.000 inspect.py:2751(kind)
#      2350    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#      2186    0.001    0.000    0.001    0.000 coreviews.py:43(__init__)
#      2185    0.001    0.000    0.001    0.000 coreviews.py:49(__iter__)
#      2185    0.002    0.000    0.002    0.000 coreviews.py:80(__getitem__)
#      2141    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#      1550    0.000    0.000    0.000    0.000 reportviews.py:205(__call__)
#      1509    0.001    0.000    0.002    0.000 reportviews.py:188(__getitem__)
#      1354    0.003    0.000    0.003    0.000 {built-in method numpy.array}
#      1332    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#      1011    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#       918    0.000    0.000    0.000    0.000 inspect.py:2739(name)
#       864    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#       792    0.001    0.000    0.002    0.000 formatters.py:552(_in_deferred_types)
#       738    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       738    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       738    0.001    0.000    0.001    0.000 random.py:520(uniform)
#       682    0.002    0.000    0.003    0.000 graph.py:893(add_edge)
#       676    0.136    0.000    1.125    0.002 IPEnvironment.py:42(lineInCollision)
#       669    0.001    0.000    0.003    0.000 IPVisibilityPRM_Roundtrip.py:26(addVisTest)
#       669    0.002    0.000    1.117    0.002 IPVisibilityPRM_Roundtrip.py:38(_isVisible)
#       648    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#       642    0.001    0.000    0.012    0.000 connected.py:15(connected_components)
#       369    0.001    0.000    0.002    0.000 IPPRMBase.py:25(<listcomp>)
#       369    0.001    0.000    0.003    0.000 IPPRMBase.py:23(_getRandomPosition)
#       369    0.000    0.000    0.000    0.000 IPEnvironment.py:27(getEnvironmentLimits)
#       331    0.001    0.000    0.002    0.000 backends.py:129(wrapper)
#       331    0.000    0.000    0.000    0.000 graph.py:1557(is_directed)
#       329    0.001    0.000    0.001    0.000 graph.py:515(add_node)
#       327    0.004    0.000    0.010    0.000 connected.py:191(_plain_bfs)
#       315    0.001    0.000    0.001    0.000 <class 'networkx.utils.decorators.argmap'> compilation 4:1(argmap_connected_components_1)
#       315    0.000    0.000    0.000    0.000 graph.py:435(__iter__)
#       315    0.000    0.000    0.000    0.000 decorators.py:82(_not_implemented_for)
#       315    0.001    0.000    0.002    0.000 IPVisibilityPRM_Roundtrip.py:22(addNodeAtPos)
#       315    0.001    0.000    0.024    0.000 IPPRMBase.py:28(_getRandomFreePosition)
#       256    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       252    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       216    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       216    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       216    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       216    0.001    0.000    0.001    0.000 inspect.py:2839(args)
#       216    0.001    0.000    0.001    0.000 inspect.py:2892(apply_defaults)
#       216    0.002    0.000    0.003    0.000 inspect.py:3076(_bind)
#       216    0.000    0.000    0.008    0.000 formatters.py:219(catch_format_error)
#       216    0.000    0.000    0.015    0.000 decorator.py:229(fun)
#       216    0.001    0.000    0.006    0.000 decorator.py:199(fix)
#       216    0.000    0.000    0.000    0.000 pretty.py:321(_get_mro)
#       216    0.000    0.000    0.000    0.000 inspect.py:2831(__init__)
#       216    0.001    0.000    0.001    0.000 inspect.py:2862(kwargs)
#       216    0.000    0.000    0.003    0.000 inspect.py:3207(bind)
#       198    0.001    0.000    0.004    0.000 formatters.py:396(lookup_by_type)
#       198    0.000    0.000    0.000    0.000 formatters.py:273(_get_type)
#       198    0.000    0.000    0.004    0.000 formatters.py:373(lookup)
#       198    0.000    0.000    0.000    0.000 formatters.py:358(_check_return)
#       198    0.000    0.000    0.001    0.000 dir2.py:54(get_real_method)
#       198    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#       162    0.000    0.000    0.005    0.000 formatters.py:330(__call__)
#       153    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       138    0.000    0.000    0.000    0.000 distance.py:313(_validate_vector)
#       126    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#        84    0.000    0.000    0.000    0.000 reportviews.py:311(__init__)
#        84    0.000    0.000    0.000    0.000 reportviews.py:329(__iter__)
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        69    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        69    0.000    0.000    0.001    0.000 _misc.py:17(norm)
#        69    0.000    0.000    0.002    0.000 distance.py:429(minkowski)
#        69    0.000    0.000    0.002    0.000 distance.py:500(euclidean)
#        69    0.000    0.000    0.000    0.000 function_base.py:562(asarray_chkfinite)
#        67    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        54    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        54    0.000    0.000    0.000    0.000 pretty.py:495(enq)
#        54    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#        54    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#        51    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        42    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#        40    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        36    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        36    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        36    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        36    0.000    0.000    0.000    0.000 pretty.py:304(end_group)
#        36    0.000    0.000    0.000    0.000 pretty.py:512(remove)
#        36    0.000    0.000    0.000    0.000 pretty.py:184(group)
#        36    0.000    0.000    0.000    0.000 pretty.py:280(begin_group)
#        36    0.000    0.000    0.000    0.000 configurable.py:522(instance)
#        35    0.000    0.000    0.000    0.000 linalg.py:2342(norm)
#        35    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(norm)
#        35    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#        35    0.000    0.000    0.000    0.000 linalg.py:2338(_norm_dispatcher)
#        34    0.000    0.000    0.000    0.000 blas.py:384(getter)
#        34    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        32    0.000    0.000    0.000    0.000 graph.py:453(__contains__)
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        22    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        22    0.001    0.000    0.003    0.000 IPVisibilityPRM_Roundtrip.py:58(_nearestInterim)
#        18    0.000    0.000    0.000    0.000 <frozen genericpath>:16(exists)
#        18    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        18    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        18    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        18    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        18    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#        18    0.000    0.000    0.016    0.001 display_functions.py:105(display)
#        18    0.000    0.000    0.000    0.000 display.py:281(__init__)
#        18    0.000    0.000    0.000    0.000 display.py:349(reload)
#        18    0.000    0.000    0.000    0.000 pretty.py:232(text)
#        18    0.000    0.000    0.001    0.000 pretty.py:372(pretty)
#        18    0.000    0.000    0.015    0.001 formatters.py:90(format)
#        18    0.000    0.000    0.016    0.001 HelperClass.py:9(printInColor)
#        18    0.000    0.000    0.000    0.000 displaypub.py:130(publish)
#        18    0.000    0.000    0.001    0.000 formatters.py:907(__call__)
#        18    0.000    0.000    0.001    0.000 formatters.py:953(__call__)
#        18    0.000    0.000    0.000    0.000 formatters.py:944(_check_return)
#        18    0.000    0.000    0.000    0.000 display.py:342(_data_and_metadata)
#        18    0.000    0.000    0.000    0.000 display.py:418(warn)
#        18    0.000    0.000    0.000    0.000 pretty.py:201(__init__)
#        18    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#        18    0.000    0.000    0.000    0.000 display_functions.py:45(publish_display_data)
#        18    0.000    0.000    0.000    0.000 display.py:434(_repr_html_)
#        18    0.000    0.000    0.000    0.000 pretty.py:355(__init__)
#        18    0.000    0.000    0.001    0.000 pretty.py:775(_repr_pprint)
#        18    0.000    0.000    0.000    0.000 display.py:57(_safe_exists)
#        18    0.000    0.000    0.000    0.000 pretty.py:490(__init__)
#        18    0.000    0.000    0.000    0.000 display.py:405(_check_data)
#        18    0.000    0.000    0.000    0.000 pretty.py:313(flush)
#        18    0.000    0.000    0.002    0.000 formatters.py:695(__call__)
#        18    0.000    0.000    0.000    0.000 display.py:330(__repr__)
#        18    0.000    0.000    0.001    0.000 display.py:417(__init__)
#        18    0.000    0.000    0.000    0.000 configurable.py:566(initialized)
#        18    0.000    0.000    0.000    0.000 contextlib.py:287(helper)
#        18    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#        18    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#        16    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        16    0.000    0.000    0.000    0.000 unweighted.py:259(_bidirectional_pred_succ)
#        16    0.000    0.000    0.000    0.000 generic.py:41(shortest_path)
#        16    0.000    0.000    0.000    0.000 unweighted.py:196(bidirectional_shortest_path)
#        15    0.000    0.000    0.000    0.000 IPVisibilityPRM_Roundtrip.py:41(_getNodeNamebasedOnCoordinates)
#        14    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:193(_reshape_dispatcher)
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(reshape)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:198(reshape)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:38(_wrapit)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 <frozen _collections_abc>:859(__iter__)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amax)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2703(amax)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2698(_amax_dispatcher)
#         7    0.000    0.000    0.001    0.000 {method 'query' of 'scipy.spatial._ckdtree.cKDTree' objects}
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1991(shape)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1987(_shape_dispatcher)
#         7    0.000    0.000    0.000    0.000 numeric.py:1878(isscalar)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 functools.py:981(__get__)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copy)
#         2    0.000    0.000    0.000    0.000 function_base.py:867(_copy_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:871(copy)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:812(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:790(items)
#         1    0.000    0.000    1.211    1.211 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.003    0.003 IPPlanerBase.py:22(_checkStartGoal)
#         1    0.001    0.001    1.211    1.211 IPVisibilityPRM_Roundtrip.py:145(planRoundPath)
#         1    0.007    0.007    1.172    1.172 IPVisibilityPRM_Roundtrip.py:96(_learnRoadmap)
#         1    0.000    0.000    1.211    1.211 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 graph.py:374(adj)
#         1    0.000    0.000    0.000    0.000 reportviews.py:185(__iter__)
#         1    0.000    0.000    0.000    0.000 function.py:677(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function.py:655(get_node_attributes)
#         1    0.000    0.000    0.000    0.000 graph.py:1519(clear)
#         1    0.000    0.000    0.000    0.000 graph.py:732(nodes)
#         1    0.000    0.000    0.000    0.000 reportviews.py:178(__init__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2829(amin)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2824(_amin_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Tue Jan  9 12:20:12 2024    visibilitystats
#
#          815468 function calls (796112 primitive calls) in 1.211 seconds
#
#    Ordered by: cumulative time
#    List reduced from 209 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.211    1.211 {built-in method builtins.exec}
#         1    0.000    0.000    1.211    1.211 <string>:1(<module>)
#   19357/1    0.055    0.000    1.211    1.211 IPPerfMonitor.py:24(__call__)
#         1    0.001    0.001    1.211    1.211 IPVisibilityPRM_Roundtrip.py:145(planRoundPath)
#         1    0.007    0.007    1.172    1.172 IPVisibilityPRM_Roundtrip.py:96(_learnRoadmap)
#       676    0.136    0.000    1.125    0.002 IPEnvironment.py:42(lineInCollision)
#       669    0.002    0.000    1.117    0.002 IPVisibilityPRM_Roundtrip.py:38(_isVisible)
#     18342    0.090    0.000    0.887    0.000 IPEnvironment.py:31(pointInCollision)
#     18342    0.062    0.000    0.429    0.000 point.py:38(__init__)
#     18342    0.027    0.000    0.249    0.000 base.py:803(intersects)
#     18342    0.220    0.000    0.240    0.000 point.py:244(geos_point_from_py)
#     18342    0.165    0.000    0.217    0.000 predicates.py:11(__call__)
#     36684    0.070    0.000    0.132    0.000 base.py:191(_empty)
#    146736    0.112    0.000    0.112    0.000 base.py:245(__setattr__)
#     18342    0.027    0.000    0.108    0.000 base.py:240(_set_geom)
#
#
# Tue Jan  9 12:20:12 2024    visibilitystats
#
#          815468 function calls (796112 primitive calls) in 1.211 seconds
#
#    Ordered by: call count
#    List reduced from 209 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    146736    0.112    0.000    0.112    0.000 base.py:245(__setattr__)
#     93289    0.015    0.000    0.015    0.000 {built-in method builtins.len}
#     73368    0.015    0.000    0.015    0.000 base.py:228(_geom)
#     38902    0.012    0.000    0.012    0.000 {built-in method builtins.isinstance}
#     38714    0.010    0.000    0.010    0.000 {built-in method time.time}
#     37249    0.011    0.000    0.011    0.000 {built-in method builtins.hasattr}
#     36684    0.027    0.000    0.040    0.000 topology.py:18(_validate)
#     36684    0.070    0.000    0.132    0.000 base.py:191(_empty)
#     20840    0.005    0.000    0.005    0.000 {method 'append' of 'list' objects}
#     19700    0.003    0.000    0.003    0.000 IPEnvironment.py:23(getDim)
#     19357    0.061    0.000    0.061    0.000 IPPerfMonitor.py:38(__get__)
#   19357/1    0.055    0.000    1.211    1.211 IPPerfMonitor.py:24(__call__)
#     18453    0.005    0.000    0.005    0.000 {method 'items' of 'dict' objects}
#     18342    0.220    0.000    0.240    0.000 point.py:244(geos_point_from_py)
#     18342    0.062    0.000    0.429    0.000 point.py:38(__init__)
#
#
# Tue Jan  9 12:20:12 2024    visibilitystats
#
#          815468 function calls (796112 primitive calls) in 1.211 seconds
#
#    Ordered by: internal time
#    List reduced from 209 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     18342    0.220    0.000    0.240    0.000 point.py:244(geos_point_from_py)
#     18342    0.165    0.000    0.217    0.000 predicates.py:11(__call__)
#       676    0.136    0.000    1.125    0.002 IPEnvironment.py:42(lineInCollision)
#    146736    0.112    0.000    0.112    0.000 base.py:245(__setattr__)
#     18342    0.090    0.000    0.887    0.000 IPEnvironment.py:31(pointInCollision)
#     36684    0.070    0.000    0.132    0.000 base.py:191(_empty)
#     18342    0.062    0.000    0.429    0.000 point.py:38(__init__)
#     19357    0.061    0.000    0.061    0.000 IPPerfMonitor.py:38(__get__)
#   19357/1    0.055    0.000    1.211    1.211 IPPerfMonitor.py:24(__call__)
#     18342    0.027    0.000    0.108    0.000 base.py:240(_set_geom)
#     36684    0.027    0.000    0.040    0.000 topology.py:18(_validate)
#     18342    0.027    0.000    0.249    0.000 base.py:803(intersects)
#     18342    0.017    0.000    0.106    0.000 base.py:208(__del__)
#     73368    0.015    0.000    0.015    0.000 base.py:228(_geom)
#     93289    0.015    0.000    0.015    0.000 {built-in method builtins.len}
# /home/maurice/anaconda3/lib/python3.11/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %% [markdown]
# Example using IPerfMonitor
# --------------------------

# %%
from IPPerfMonitor import IPPerfMonitor

# %%
benchList = IPTestSuite.benchList

# KOnfig steht in plannerFactory
print(str(planner))
with io.capture_output() as captured:
    solution = planner.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,producer[1])


start = benchList[0].startList
goal = benchList[0].goalList

data_frame = IPPerfMonitor.dataFrame()

#fig_local = plt.figure(figsize=(10,10))
#ax = fig_local.add_subplot(1,1,1)

#IPVISVisibilityPRM.visibilityPRMVisualize(planner, solution, ax=ax, nodeSize=100)
# Out:
# <IPLazyPRM_Roundtrip.LazyPRM object at 0x7f1814c31510>

# %%
resultList = list()
testList = benchList[:1]

solution = list()
data_frame = list()
i = 0
for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')

    for benchmark in testList:

        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        
        try:
            with io.capture_output() as captured:
                #resultList.append(ResultCollection(key,
                #                        planner, 
                #                        benchmark, 
                #                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                #                        IPPerfMonitor.dataFrame()),)
                solution.append(planner.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,producer[1]))
                data_frame.append(IPPerfMonitor.dataFrame())

                i = i + 1


        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            pass

print(solution[1])
# Out:
# <font color='yellow'>basePRM [<class 'IPBasicPRM_Roundtrip.BasicPRM'>, {'radius': 3, 'numNodes': 200}, <function basicPRMVisualize at 0x7f180de2ee80>]</font>
# <font color='yellow'>visibilityPRM [<class 'IPVisibilityPRM_Roundtrip.VisPRM'>, {'ntry': 300}, <function visibilityPRMVisualize at 0x7f18191db6a0>]</font>
# <font color='yellow'>lazyPRM [<class 'IPLazyPRM_Roundtrip.LazyPRM'>, {'initialRoadmapSize': 50, 'updateRoadmapSize': 2, 'kNearest': 10}, <function lazyPRMVisualize at 0x7f180dc980e0>]</font>
# ['start', 1, 10, 2, 'interim0', 2, 'interim2', 2, 7, 'interim4', 7, 0, 'interim3', 0, 46, 'interim1']

# %%
#data_frame

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0].groupby(["name"]).sum(numeric_only=True))
print("")

HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1].groupby(["name"]).sum(numeric_only=True))
print("")

HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2].groupby(["name"]).sum(numeric_only=True))
# Out:
# <font color='red'>Basic</font>
#                                    time
# name
# _getRandomFreePosition         0.013240
# _inSameConnectedComponent      0.118184
# _learnRoadmapNearestNeighbour  0.650093
# _nearestInterim                0.009745
# _nearestNeighbours             0.207222
# lineInCollision                0.337292
# planRoundPath                  0.718240
# pointInCollision               0.258802
# <font color='yellow'>Visibility</font>
#                             time
# name
# _getRandomFreePosition  0.010804
# _learnRoadmap           0.971217
# _nearestInterim         0.001067
# lineInCollision         0.956782
# planRoundPath           0.985019
# pointInCollision        0.840097
# <font color='green'>Lazy</font>
#                                  time
# name
# _buildRoadmap                0.038492
# _checkForCollisionAndUpdate  0.061498
# _nearestInterim              0.002712
# lineInCollision              0.054938
# planRoundPath                0.138667
# pointInCollision             0.044384

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0][data_frame[0]["name"]=="pointInCollision"][data_frame[0]["retVal"]==True].count())

HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1][data_frame[1]["name"]=="pointInCollision"][data_frame[1]["retVal"]==True].count())

HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2][data_frame[2]["name"]=="pointInCollision"][data_frame[2]["retVal"]==True].count())
# Out:
# <font color='red'>Basic</font>
# name      34
# args      34
# kwargs    34
# retVal    34
# time      34
# dtype: int64
# /tmp/ipykernel_10734/102077241.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(data_frame[0][data_frame[0]["name"]=="pointInCollision"][data_frame[0]["retVal"]==True].count())
# <font color='yellow'>Visibility</font>
# name      452
# args      452
# kwargs    452
# retVal    452
# time      452
# dtype: int64
# /tmp/ipykernel_10734/102077241.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(data_frame[1][data_frame[1]["name"]=="pointInCollision"][data_frame[1]["retVal"]==True].count())
# <font color='green'>Lazy</font>
# name      32
# args      32
# kwargs    32
# retVal    32
# time      32
# dtype: int64
# /tmp/ipykernel_10734/102077241.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(data_frame[2][data_frame[2]["name"]=="pointInCollision"][data_frame[2]["retVal"]==True].count())

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0].groupby(["name"]).count())
print("")
HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1].groupby(["name"]).count())
print("")
HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2].groupby(["name"]).count())
# Out:
# <font color='red'>Basic</font>
#                                args  kwargs  retVal  time
# name
# _getRandomFreePosition          200     200     200   200
# _inSameConnectedComponent      1311    1311    1311  1311
# _learnRoadmapNearestNeighbour     1       1       0     1
# _nearestInterim                  58      58      58    58
# _nearestNeighbours              207     207     207   207
# lineInCollision                 209     209     209   209
# planRoundPath                     1       1       1     1
# pointInCollision               8515    8515    8515  8515
# <font color='yellow'>Visibility</font>
#                          args  kwargs  retVal   time
# name
# _getRandomFreePosition    346     346     346    346
# _learnRoadmap               1       1       0      1
# _nearestInterim            21      21      21     21
# lineInCollision           744     744     744    744
# planRoundPath               1       1       1      1
# pointInCollision        18923   18923   18923  18923
# <font color='green'>Lazy</font>
#                              args  kwargs  retVal  time
# name
# _buildRoadmap                  33      33       0    33
# _checkForCollisionAndUpdate    56      56      56    56
# _nearestInterim                29      29      29    29
# lineInCollision                50      50      50    50
# planRoundPath                   1       1       1     1
# pointInCollision             1398    1398    1398  1398

# %% [markdown]
# Second Example using IPPerfMonitor
# ----------------------------------

# %%
import IPVisibilityPRM_Roundtrip
import IPVISVisibilityPRM

# %%
visbilityConfig = dict()
visbilityConfig["ntry"] = 300

vis = plannerFactory["visibilityPRM"][0](benchList[3].collisionChecker)

start = benchList[3].startList
goal = benchList[3].goalList

IPPerfMonitor.clearData()

with io.capture_output() as captured:
    solution = vis.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,visbilityConfig)

data_frame = IPPerfMonitor.dataFrame()

fig_local = plt.figure(figsize=(10,10))
ax = fig_local.add_subplot(1,1,1)
IPVISVisibilityPRM.visibilityPRMVisualize(vis, solution, ax = ax)
# Out:
# /home/maurice/anaconda3/lib/python3.11/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
data_frame
# Out:
#                    name                                               args  \
# 0      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 1      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 2      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 3      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 4      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# ...                 ...                                                ...
# 53764   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 53765   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 53766   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 53767     _learnRoadmap  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 53768     planRoundPath  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
#
#       kwargs                                             retVal       time
# 0         {}                                              False   0.001817
# 1         {}                                              False   0.001055
# 2         {}                                               True   0.000747
# 3         {}                                              False   0.000682
# 4         {}                                              False   0.000671
# ...      ...                                                ...        ...
# 53764     {}           [[20, 15], 3.6636538785900576, interim2]   0.000044
# 53765     {}           [[20, 15], 2.2153375878313724, interim2]   0.000034
# 53766     {}                          [[20, 15], 0.0, interim2]   0.000041
# 53767     {}                                               None  13.581066
# 53768     {}  [start, 286, 1, 31, 30, 47, 0, 58, interim3, 5...  13.652877
#
# [53769 rows x 5 columns]

# %%
data_frame.groupby(["name"]).count()
# Out:
#                          args  kwargs  retVal   time
# name
# _getRandomFreePosition    594     594     594    594
# _learnRoadmap               1       1       0      1
# _nearestInterim            36      36      36     36
# lineInCollision          2613    2613    2613   2613
# planRoundPath               1       1       1      1
# pointInCollision        50524   50524   50524  50524

# %%
data_frame.groupby(["name"]).sum(numeric_only=True)
# Out:
#                              time
# name
# _getRandomFreePosition   0.182380
# _learnRoadmap           13.581066
# _nearestInterim          0.002372
# lineInCollision         13.396438
# planRoundPath           13.652877
# pointInCollision        13.115159
