# %% [markdown]
# Example Profiling
# ==============================
#
#
#
# Example using cProfile/pstats
# -----------------------------
#
# Following an example how to profile the algorithm using https://docs.python.org/3/library/profile.html

# %%
import IPTestSuite
import IPLazyPRM_Roundtrip
import IPVISLazyPRM

import IPVISVisibilityPRM
import IPVisibilityPRM_Roundtrip

import IPBasicPRM_Roundtrip
import IPVISBasicPRM

import HelperClass
from IPPerfMonitor import IPPerfMonitor

import IPVISBasicPRM



from __future__ import print_function
import sys

from IPython.utils import io

from matplotlib import pylab as plt

benchList = IPTestSuite.benchList
print(benchList)


start = benchList[0].startList
goal = benchList[0].goalList

plannerFactory = dict()

basicConfig = dict()
basicConfig["radius"] = 3
basicConfig["numNodes"] = 200
plannerFactory["basePRM"] = [IPBasicPRM_Roundtrip.BasicPRM, basicConfig, IPVISBasicPRM.basicPRMVisualize]

visbilityConfig = dict()
visbilityConfig["ntry"] = 300
plannerFactory["visibilityPRM"] = [IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]

lazyConfig = dict()
lazyConfig["initialRoadmapSize"] = 50
lazyConfig["updateRoadmapSize"]  = 2
lazyConfig["kNearest"] = 10
plannerFactory["lazyPRM"] = [IPLazyPRM_Roundtrip.LazyPRM, lazyConfig, IPVISLazyPRM.lazyPRMVisualize]
# Out:
# [<IPBenchmark.Benchmark object at 0x7fbcf39080d0>, <IPBenchmark.Benchmark object at 0x7fbcf394b690>, <IPBenchmark.Benchmark object at 0x7fbcf3764e50>, <IPBenchmark.Benchmark object at 0x7fbcf3765650>, <IPBenchmark.Benchmark object at 0x7fbcf37662d0>]

# %%
class ResultCollection (object):
    
    def __init__(self, plannerFactoryName, planner, benchmark, solution, perfDataFrame):
        self.plannerFactoryName = plannerFactoryName
        self.planner = planner
        self.benchmark = benchmark
        self.solution = solution
        self.perfDataFrame = perfDataFrame

# %%
resultList = list()
testList = benchList[:1]
i = 0
for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')
    #print(key, producer)
    print(key)
    for benchmark in testList:
        #HelperClass.HelperClass.printInColor("Planning: " + key + " - " + benchmark.name, 'yellow')
        #planner = IPBasicPRM.BasicPRM(benchmark.collisionChecker)
        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        
        print("Hallo")
        try:
            with io.capture_output() as captured:
                resultList.append(ResultCollection(key,
                                        planner, 
                                        benchmark, 
                                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                                        IPPerfMonitor.dataFrame()),)
            #a = planner.planPath(benchmark.startList,benchmark.goalList,producer[1])
            # print("")
            i = i + 1

        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            pass
# Out:
# <font color='yellow'>basePRM [<class 'IPBasicPRM_Roundtrip.BasicPRM'>, {'radius': 3, 'numNodes': 200}, <function basicPRMVisualize at 0x7fbcf148e2a0>]</font>
# basePRM
# Hallo
# <font color='yellow'>visibilityPRM [<class 'IPVisibilityPRM_Roundtrip.VisPRM'>, {'ntry': 300}, <function visibilityPRMVisualize at 0x7fbcf148e200>]</font>
# visibilityPRM
# Hallo
# <font color='yellow'>lazyPRM [<class 'IPLazyPRM_Roundtrip.LazyPRM'>, {'initialRoadmapSize': 50, 'updateRoadmapSize': 2, 'kNearest': 10}, <function lazyPRMVisualize at 0x7fbcf375b7e0>]</font>
# lazyPRM
# Hallo

# %%
# Executing the planning. 
import cProfile
from IPPRMBase import PRMBase

for i in plannerFactory:
    print("i",i)


plannerBasic = resultList[0].planner
plannerBasicProducer = plannerFactory["basePRM"]
plannerVisibility = resultList[1].planner
plannerVisibilityProducer = plannerFactory["visibilityPRM"]
plannerLazy = resultList[2].planner
plannerLazyProducer = plannerFactory["lazyPRM"]

print(plannerVisibilityProducer[1])


HelperClass.HelperClass.printInColor("BasicPRMRound", "red")
with io.capture_output() as capturedBasic:
    cProfile.run('solution =plannerBasic.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerBasicProducer[1])','./stats/basicstats') 


HelperClass.HelperClass.printInColor("VisibiltyPRMRound", "orange")
with io.capture_output() as capturedVisibility:
    cProfile.run('solution = plannerVisibility.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerVisibilityProducer[1])','./stats/visibilitystats') 

HelperClass.HelperClass.printInColor("LazyPRMRound", "green")
with io.capture_output() as capturedVisibility:
    cProfile.run('solution = plannerLazy.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerLazyProducer[1])','./stats/lazystats')
# Out:
# i basePRM
# i visibilityPRM
# i lazyPRM
# {'ntry': 300}
# <font color='red'>BasicPRMRound</font>
# <font color='orange'>VisibiltyPRMRound</font>
# <font color='green'>LazyPRMRound</font>

# %%
# utility functions to read and access data in astartstats
import pstats
from pstats import SortKey

p = pstats.Stats('./stats/basicstats')
p.strip_dirs().sort_stats(SortKey.CALLS).print_stats()
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p.sort_stats(SortKey.CALLS).print_stats(15)
p.sort_stats(SortKey.TIME).print_stats(15)

    
# Anzeige der Benchmarks, noch nicht mit allen Vis möglich

for bench, result in zip(testList, resultList):
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    if result.benchmark.name == bench.name:
        pathLength[result.plannerFactoryName] = len(result.solution)
        planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
        roadmapSize[result.plannerFactoryName] = result.planner.graph.size()
# Out:
# Sat Jan 13 21:09:42 2024    ./stats/basicstats
#
#          1580694 function calls (1570248 primitive calls) in 0.889 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    141163    0.012    0.000    0.012    0.000 {built-in method builtins.iter}
#    141109    0.047    0.000    0.089    0.000 {method 'update' of 'set' objects}
#    138441    0.031    0.000    0.042    0.000 coreviews.py:49(__iter__)
#    138441    0.049    0.000    0.065    0.000 coreviews.py:80(__getitem__)
#    138441    0.016    0.000    0.016    0.000 coreviews.py:43(__init__)
#    137536    0.013    0.000    0.013    0.000 {method 'add' of 'set' objects}
#     68176    0.035    0.000    0.035    0.000 base.py:245(__setattr__)
#     65114    0.027    0.000    0.027    0.000 {built-in method numpy.asarray}
#     43896    0.005    0.000    0.005    0.000 {built-in method builtins.len}
#     43372    0.015    0.000    0.039    0.000 distance.py:313(_validate_vector)
#     34088    0.005    0.000    0.005    0.000 base.py:228(_geom)
#     21880    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#     21686    0.030    0.000    0.118    0.000 _misc.py:17(norm)
#     21686    0.035    0.000    0.191    0.000 distance.py:429(minkowski)
#     21686    0.010    0.000    0.201    0.000 distance.py:500(euclidean)
#     21686    0.026    0.000    0.075    0.000 function_base.py:562(asarray_chkfinite)
#     21630    0.009    0.000    0.013    0.000 blas.py:384(getter)
#     21630    0.008    0.000    0.045    0.000 {method 'all' of 'numpy.ndarray' objects}
#     21630    0.031    0.000    0.031    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     21630    0.006    0.000    0.037    0.000 _methods.py:61(_all)
#     20894    0.003    0.000    0.003    0.000 {built-in method time.time}
#     18911    0.004    0.000    0.004    0.000 {built-in method builtins.hasattr}
#     18848    0.004    0.000    0.004    0.000 {built-in method builtins.isinstance}
#     17044    0.010    0.000    0.014    0.000 topology.py:18(_validate)
#     17044    0.023    0.000    0.043    0.000 base.py:191(_empty)
#     16892    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#     10447    0.021    0.000    0.021    0.000 IPPerfMonitor.py:38(__get__)
#   10447/1    0.020    0.000    0.889    0.889 IPPerfMonitor.py:24(__call__)
#      8979    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      8958    0.001    0.000    0.001    0.000 IPEnvironment.py:23(getDim)
#      8522    0.054    0.000    0.061    0.000 point.py:244(geos_point_from_py)
#      8522    0.020    0.000    0.122    0.000 point.py:38(__init__)
#      8522    0.009    0.000    0.077    0.000 base.py:803(intersects)
#      8522    0.002    0.000    0.002    0.000 geos.py:607(errcheck_predicate)
#      8522    0.006    0.000    0.034    0.000 base.py:208(__del__)
#      8522    0.002    0.000    0.002    0.000 impl.py:56(__getitem__)
#      8522    0.048    0.000    0.066    0.000 predicates.py:11(__call__)
#      8522    0.009    0.000    0.035    0.000 base.py:240(_set_geom)
#      8522    0.029    0.000    0.266    0.000 IPEnvironment.py:31(pointInCollision)
#      5896    0.001    0.000    0.001    0.000 traitlets.py:651(get)
#      5896    0.002    0.000    0.003    0.000 traitlets.py:689(__get__)
#      5896    0.001    0.000    0.001    0.000 inspect.py:2751(kind)
#      5676    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      4826    0.005    0.000    0.267    0.000 connected.py:15(connected_components)
#      3573    0.095    0.000    0.259    0.000 connected.py:191(_plain_bfs)
#      3256    0.001    0.000    0.001    0.000 {built-in method builtins.next}
#      2244    0.000    0.000    0.000    0.000 inspect.py:2739(name)
#      2112    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#      1936    0.001    0.000    0.003    0.000 formatters.py:552(_in_deferred_types)
#      1584    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#      1295    0.001    0.000    0.006    0.000 backends.py:129(wrapper)
#      1295    0.000    0.000    0.000    0.000 graph.py:1557(is_directed)
#      1253    0.004    0.000    0.274    0.000 IPBasicPRM_Roundtrip.py:29(_inSameConnectedComponent)
#      1253    0.001    0.000    0.001    0.000 graph.py:435(__iter__)
#      1253    0.001    0.000    0.001    0.000 decorators.py:82(_not_implemented_for)
#      1253    0.001    0.000    0.002    0.000 <class 'networkx.utils.decorators.argmap'> compilation 4:1(argmap_connected_components_1)
#       616    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       528    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       528    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       528    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       528    0.002    0.000    0.002    0.000 inspect.py:2839(args)
#       528    0.001    0.000    0.001    0.000 inspect.py:2892(apply_defaults)
#       528    0.004    0.000    0.005    0.000 inspect.py:3076(_bind)
#       528    0.001    0.000    0.015    0.000 formatters.py:219(catch_format_error)
#       528    0.001    0.000    0.027    0.000 decorator.py:229(fun)
#       528    0.001    0.000    0.011    0.000 decorator.py:199(fix)
#       528    0.000    0.000    0.000    0.000 pretty.py:321(_get_mro)
#       528    0.001    0.000    0.001    0.000 inspect.py:2862(kwargs)
#       528    0.000    0.000    0.006    0.000 inspect.py:3207(bind)
#       528    0.000    0.000    0.000    0.000 inspect.py:2831(__init__)
#       484    0.002    0.000    0.007    0.000 formatters.py:396(lookup_by_type)
#       484    0.001    0.000    0.008    0.000 formatters.py:373(lookup)
#       484    0.000    0.000    0.000    0.000 formatters.py:273(_get_type)
#       484    0.000    0.000    0.000    0.000 formatters.py:358(_check_return)
#       484    0.001    0.000    0.001    0.000 dir2.py:54(get_real_method)
#       484    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#       470    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       470    0.000    0.000    0.000    0.000 random.py:520(uniform)
#       430    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       413    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       413    0.000    0.000    0.000    0.000 reportviews.py:311(__init__)
#       413    0.000    0.000    0.001    0.000 reportviews.py:205(__call__)
#       413    0.000    0.000    0.001    0.000 reportviews.py:329(__iter__)
#       396    0.001    0.000    0.008    0.000 formatters.py:330(__call__)
#       308    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#       235    0.000    0.000    0.001    0.000 IPPRMBase.py:25(<listcomp>)
#       235    0.000    0.000    0.001    0.000 IPPRMBase.py:23(_getRandomPosition)
#       235    0.000    0.000    0.000    0.000 IPEnvironment.py:27(getEnvironmentLimits)
#       215    0.041    0.000    0.331    0.002 IPEnvironment.py:42(lineInCollision)
#       207    0.012    0.000    0.211    0.001 IPBasicPRM_Roundtrip.py:41(_nearestNeighbours)
#       207    0.000    0.000    0.000    0.000 graph.py:515(add_node)
#       206    0.001    0.000    0.001    0.000 graph.py:893(add_edge)
#       200    0.001    0.000    0.014    0.000 IPPRMBase.py:28(_getRandomFreePosition)
#       173    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       132    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#       132    0.001    0.000    0.001    0.000 pretty.py:495(enq)
#       132    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#       132    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#       112    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        92    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        88    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        88    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        88    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        88    0.000    0.000    0.000    0.000 reportviews.py:188(__getitem__)
#        88    0.000    0.000    0.000    0.000 pretty.py:304(end_group)
#        88    0.000    0.000    0.000    0.000 pretty.py:512(remove)
#        88    0.000    0.000    0.001    0.000 pretty.py:184(group)
#        88    0.000    0.000    0.001    0.000 pretty.py:280(begin_group)
#        88    0.000    0.000    0.000    0.000 configurable.py:522(instance)
#        84    0.000    0.000    0.000    0.000 graph.py:453(__contains__)
#        56    0.000    0.000    0.000    0.000 linalg.py:2342(norm)
#        56    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        56    0.000    0.000    0.000    0.000 linalg.py:2338(_norm_dispatcher)
#        56    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(norm)
#        56    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        48    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        48    0.007    0.000    0.011    0.000 IPBasicPRM_Roundtrip.py:73(_nearestInterim)
#        44    0.000    0.000    0.001    0.000 <frozen genericpath>:16(exists)
#        44    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        44    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        44    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        44    0.001    0.000    0.001    0.000 {built-in method posix.stat}
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        44    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        44    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#        44    0.000    0.000    0.029    0.001 display_functions.py:105(display)
#        44    0.000    0.000    0.001    0.000 display.py:281(__init__)
#        44    0.000    0.000    0.000    0.000 display.py:349(reload)
#        44    0.000    0.000    0.000    0.000 pretty.py:232(text)
#        44    0.000    0.000    0.002    0.000 pretty.py:372(pretty)
#        44    0.001    0.000    0.028    0.001 formatters.py:90(format)
#        44    0.000    0.000    0.030    0.001 HelperClass.py:9(printInColor)
#        44    0.000    0.000    0.001    0.000 formatters.py:907(__call__)
#        44    0.000    0.000    0.001    0.000 formatters.py:953(__call__)
#        44    0.000    0.000    0.000    0.000 formatters.py:944(_check_return)
#        44    0.000    0.000    0.000    0.000 displaypub.py:130(publish)
#        44    0.000    0.000    0.003    0.000 formatters.py:695(__call__)
#        44    0.000    0.000    0.000    0.000 display.py:342(_data_and_metadata)
#        44    0.000    0.000    0.000    0.000 display.py:418(warn)
#        44    0.000    0.000    0.000    0.000 pretty.py:201(__init__)
#        44    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#        44    0.000    0.000    0.000    0.000 display_functions.py:45(publish_display_data)
#        44    0.000    0.000    0.000    0.000 display.py:434(_repr_html_)
#        44    0.000    0.000    0.000    0.000 pretty.py:355(__init__)
#        44    0.000    0.000    0.001    0.000 pretty.py:775(_repr_pprint)
#        44    0.000    0.000    0.001    0.000 display.py:57(_safe_exists)
#        44    0.000    0.000    0.000    0.000 pretty.py:490(__init__)
#        44    0.000    0.000    0.000    0.000 display.py:405(_check_data)
#        44    0.000    0.000    0.000    0.000 pretty.py:313(flush)
#        44    0.000    0.000    0.000    0.000 display.py:330(__repr__)
#        44    0.000    0.000    0.001    0.000 display.py:417(__init__)
#        44    0.000    0.000    0.000    0.000 configurable.py:566(initialized)
#        44    0.000    0.000    0.000    0.000 contextlib.py:287(helper)
#        44    0.000    0.000    0.001    0.000 contextlib.py:132(__enter__)
#        44    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#        42    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        42    0.001    0.000    0.002    0.000 unweighted.py:259(_bidirectional_pred_succ)
#        42    0.000    0.000    0.003    0.000 generic.py:41(shortest_path)
#        42    0.000    0.000    0.003    0.000 unweighted.py:196(bidirectional_shortest_path)
#        41    0.000    0.000    0.001    0.000 IPBasicPRM_Roundtrip.py:55(_getNodeNamebasedOnCoordinates)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.889    0.889 {built-in method builtins.exec}
#         1    0.000    0.000    0.001    0.001 IPPlanerBase.py:22(_checkStartGoal)
#         1    0.001    0.001    0.889    0.889 IPBasicPRM_Roundtrip.py:135(planRoundPath)
#         1    0.003    0.003    0.816    0.816 IPBasicPRM_Roundtrip.py:111(_learnRoadmapNearestNeighbour)
#         1    0.000    0.000    0.889    0.889 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 graph.py:1519(clear)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Sat Jan 13 21:09:42 2024    ./stats/basicstats
#
#          1580694 function calls (1570248 primitive calls) in 0.889 seconds
#
#    Ordered by: cumulative time
#    List reduced from 172 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.889    0.889 {built-in method builtins.exec}
#         1    0.000    0.000    0.889    0.889 <string>:1(<module>)
#   10447/1    0.020    0.000    0.889    0.889 IPPerfMonitor.py:24(__call__)
#         1    0.001    0.001    0.889    0.889 IPBasicPRM_Roundtrip.py:135(planRoundPath)
#         1    0.003    0.003    0.816    0.816 IPBasicPRM_Roundtrip.py:111(_learnRoadmapNearestNeighbour)
#       215    0.041    0.000    0.331    0.002 IPEnvironment.py:42(lineInCollision)
#      1253    0.004    0.000    0.274    0.000 IPBasicPRM_Roundtrip.py:29(_inSameConnectedComponent)
#      4826    0.005    0.000    0.267    0.000 connected.py:15(connected_components)
#      8522    0.029    0.000    0.266    0.000 IPEnvironment.py:31(pointInCollision)
#      3573    0.095    0.000    0.259    0.000 connected.py:191(_plain_bfs)
#       207    0.012    0.000    0.211    0.001 IPBasicPRM_Roundtrip.py:41(_nearestNeighbours)
#     21686    0.010    0.000    0.201    0.000 distance.py:500(euclidean)
#     21686    0.035    0.000    0.191    0.000 distance.py:429(minkowski)
#      8522    0.020    0.000    0.122    0.000 point.py:38(__init__)
#     21686    0.030    0.000    0.118    0.000 _misc.py:17(norm)
#
#
# Sat Jan 13 21:09:42 2024    ./stats/basicstats
#
#          1580694 function calls (1570248 primitive calls) in 0.889 seconds
#
#    Ordered by: call count
#    List reduced from 172 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    141163    0.012    0.000    0.012    0.000 {built-in method builtins.iter}
#    141109    0.047    0.000    0.089    0.000 {method 'update' of 'set' objects}
#    138441    0.031    0.000    0.042    0.000 coreviews.py:49(__iter__)
#    138441    0.049    0.000    0.065    0.000 coreviews.py:80(__getitem__)
#    138441    0.016    0.000    0.016    0.000 coreviews.py:43(__init__)
#    137536    0.013    0.000    0.013    0.000 {method 'add' of 'set' objects}
#     68176    0.035    0.000    0.035    0.000 base.py:245(__setattr__)
#     65114    0.027    0.000    0.027    0.000 {built-in method numpy.asarray}
#     43896    0.005    0.000    0.005    0.000 {built-in method builtins.len}
#     43372    0.015    0.000    0.039    0.000 distance.py:313(_validate_vector)
#     34088    0.005    0.000    0.005    0.000 base.py:228(_geom)
#     21880    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#     21686    0.030    0.000    0.118    0.000 _misc.py:17(norm)
#     21686    0.035    0.000    0.191    0.000 distance.py:429(minkowski)
#     21686    0.010    0.000    0.201    0.000 distance.py:500(euclidean)
#
#
# Sat Jan 13 21:09:42 2024    ./stats/basicstats
#
#          1580694 function calls (1570248 primitive calls) in 0.889 seconds
#
#    Ordered by: internal time
#    List reduced from 172 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3573    0.095    0.000    0.259    0.000 connected.py:191(_plain_bfs)
#      8522    0.054    0.000    0.061    0.000 point.py:244(geos_point_from_py)
#    138441    0.049    0.000    0.065    0.000 coreviews.py:80(__getitem__)
#      8522    0.048    0.000    0.066    0.000 predicates.py:11(__call__)
#    141109    0.047    0.000    0.089    0.000 {method 'update' of 'set' objects}
#       215    0.041    0.000    0.331    0.002 IPEnvironment.py:42(lineInCollision)
#     68176    0.035    0.000    0.035    0.000 base.py:245(__setattr__)
#     21686    0.035    0.000    0.191    0.000 distance.py:429(minkowski)
#     21630    0.031    0.000    0.031    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    138441    0.031    0.000    0.042    0.000 coreviews.py:49(__iter__)
#     21686    0.030    0.000    0.118    0.000 _misc.py:17(norm)
#      8522    0.029    0.000    0.266    0.000 IPEnvironment.py:31(pointInCollision)
#     65114    0.027    0.000    0.027    0.000 {built-in method numpy.asarray}
#     21686    0.026    0.000    0.075    0.000 function_base.py:562(asarray_chkfinite)
#     17044    0.023    0.000    0.043    0.000 base.py:191(_empty)

# %%
# utility functions to read and access data in astartstats
import pstats
from pstats import SortKey

p = pstats.Stats('./stats/visibilitystats')
p.strip_dirs().sort_stats(SortKey.CALLS).print_stats()
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p.sort_stats(SortKey.CALLS).print_stats(15)
p.sort_stats(SortKey.TIME).print_stats(15)

    
# Anzeige der Benchmarks, noch nicht mit allen Vis möglich

for bench, result in zip(testList, resultList):
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    if result.benchmark.name == bench.name:
        pathLength[result.plannerFactoryName] = len(result.solution)
        planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
        roadmapSize[result.plannerFactoryName] = result.planner.graph.size()
# Out:
# Sat Jan 13 21:09:43 2024    ./stats/visibilitystats
#
#          742723 function calls (725119 primitive calls) in 0.762 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    133184    0.068    0.000    0.068    0.000 base.py:245(__setattr__)
#     84688    0.009    0.000    0.009    0.000 {built-in method builtins.len}
#     66592    0.009    0.000    0.009    0.000 base.py:228(_geom)
#     35241    0.008    0.000    0.008    0.000 {built-in method builtins.isinstance}
#     35210    0.006    0.000    0.006    0.000 {built-in method time.time}
#     33846    0.006    0.000    0.006    0.000 {built-in method builtins.hasattr}
#     33296    0.019    0.000    0.027    0.000 topology.py:18(_validate)
#     33296    0.045    0.000    0.082    0.000 base.py:191(_empty)
#     19007    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#     17894    0.002    0.000    0.002    0.000 IPEnvironment.py:23(getDim)
#     17605    0.034    0.000    0.034    0.000 IPPerfMonitor.py:38(__get__)
#   17605/1    0.031    0.000    0.762    0.762 IPPerfMonitor.py:24(__call__)
#     16756    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#     16648    0.171    0.000    0.183    0.000 point.py:244(geos_point_from_py)
#     16648    0.038    0.000    0.300    0.000 point.py:38(__init__)
#     16648    0.017    0.000    0.143    0.000 base.py:803(intersects)
#     16648    0.004    0.000    0.004    0.000 geos.py:607(errcheck_predicate)
#     16648    0.011    0.000    0.067    0.000 base.py:208(__del__)
#     16648    0.004    0.000    0.004    0.000 impl.py:56(__getitem__)
#     16648    0.087    0.000    0.122    0.000 predicates.py:11(__call__)
#     16648    0.017    0.000    0.067    0.000 base.py:240(_set_geom)
#     16648    0.055    0.000    0.571    0.000 IPEnvironment.py:31(pointInCollision)
#      2964    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#      2454    0.001    0.000    0.002    0.000 {method 'update' of 'set' objects}
#      2278    0.001    0.000    0.001    0.000 traitlets.py:651(get)
#      2278    0.001    0.000    0.001    0.000 traitlets.py:689(__get__)
#      2278    0.000    0.000    0.000    0.000 inspect.py:2751(kind)
#      2221    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#      2159    0.001    0.000    0.001    0.000 coreviews.py:49(__iter__)
#      2159    0.001    0.000    0.002    0.000 coreviews.py:80(__getitem__)
#      2159    0.000    0.000    0.000    0.000 coreviews.py:43(__init__)
#      2121    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#      1316    0.000    0.000    0.000    0.000 reportviews.py:205(__call__)
#      1275    0.001    0.000    0.001    0.000 reportviews.py:188(__getitem__)
#      1258    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#      1242    0.002    0.000    0.002    0.000 {built-in method numpy.array}
#       954    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       867    0.000    0.000    0.000    0.000 inspect.py:2739(name)
#       816    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#       748    0.001    0.000    0.001    0.000 formatters.py:552(_in_deferred_types)
#       696    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       696    0.000    0.000    0.001    0.000 random.py:520(uniform)
#       676    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       647    0.001    0.000    0.008    0.000 connected.py:15(connected_components)
#       626    0.001    0.000    0.002    0.000 graph.py:893(add_edge)
#       620    0.080    0.000    0.710    0.001 IPEnvironment.py:42(lineInCollision)
#       613    0.000    0.000    0.002    0.000 IPVisibilityPRM_Roundtrip.py:26(addVisTest)
#       613    0.001    0.000    0.703    0.001 IPVisibilityPRM_Roundtrip.py:38(_isVisible)
#       612    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#       348    0.001    0.000    0.001    0.000 IPPRMBase.py:25(<listcomp>)
#       348    0.000    0.000    0.002    0.000 IPPRMBase.py:23(_getRandomPosition)
#       348    0.000    0.000    0.000    0.000 IPEnvironment.py:27(getEnvironmentLimits)
#       333    0.003    0.000    0.007    0.000 connected.py:191(_plain_bfs)
#       329    0.000    0.000    0.001    0.000 backends.py:129(wrapper)
#       329    0.000    0.000    0.000    0.000 graph.py:1557(is_directed)
#       328    0.000    0.000    0.001    0.000 graph.py:515(add_node)
#       314    0.000    0.000    0.001    0.000 IPVisibilityPRM_Roundtrip.py:22(addNodeAtPos)
#       314    0.000    0.000    0.000    0.000 graph.py:435(__iter__)
#       314    0.000    0.000    0.000    0.000 decorators.py:82(_not_implemented_for)
#       314    0.001    0.000    0.015    0.000 IPPRMBase.py:28(_getRandomFreePosition)
#       314    0.000    0.000    0.001    0.000 <class 'networkx.utils.decorators.argmap'> compilation 4:1(argmap_connected_components_1)
#       253    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       238    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       204    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       204    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       204    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       204    0.001    0.000    0.001    0.000 inspect.py:2839(args)
#       204    0.000    0.000    0.001    0.000 inspect.py:2892(apply_defaults)
#       204    0.001    0.000    0.002    0.000 inspect.py:3076(_bind)
#       204    0.000    0.000    0.005    0.000 formatters.py:219(catch_format_error)
#       204    0.000    0.000    0.010    0.000 decorator.py:229(fun)
#       204    0.000    0.000    0.004    0.000 decorator.py:199(fix)
#       204    0.000    0.000    0.000    0.000 pretty.py:321(_get_mro)
#       204    0.000    0.000    0.000    0.000 inspect.py:2862(kwargs)
#       204    0.000    0.000    0.002    0.000 inspect.py:3207(bind)
#       204    0.000    0.000    0.000    0.000 inspect.py:2831(__init__)
#       187    0.001    0.000    0.002    0.000 formatters.py:396(lookup_by_type)
#       187    0.000    0.000    0.003    0.000 formatters.py:373(lookup)
#       187    0.000    0.000    0.000    0.000 formatters.py:273(_get_type)
#       187    0.000    0.000    0.000    0.000 formatters.py:358(_check_return)
#       187    0.000    0.000    0.000    0.000 dir2.py:54(get_real_method)
#       187    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#       153    0.000    0.000    0.003    0.000 formatters.py:330(__call__)
#       144    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       136    0.000    0.000    0.000    0.000 distance.py:313(_validate_vector)
#       119    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#        82    0.000    0.000    0.000    0.000 reportviews.py:311(__init__)
#        82    0.000    0.000    0.000    0.000 reportviews.py:329(__iter__)
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        68    0.000    0.000    0.001    0.000 _misc.py:17(norm)
#        68    0.000    0.000    0.001    0.000 distance.py:429(minkowski)
#        68    0.000    0.000    0.001    0.000 distance.py:500(euclidean)
#        68    0.000    0.000    0.000    0.000 function_base.py:562(asarray_chkfinite)
#        67    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        65    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        51    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        51    0.000    0.000    0.000    0.000 pretty.py:495(enq)
#        51    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#        51    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#        50    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        41    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#        38    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        35    0.000    0.000    0.000    0.000 linalg.py:2342(norm)
#        35    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 linalg.py:2338(_norm_dispatcher)
#        35    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(norm)
#        35    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#        34    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        34    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        34    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        34    0.000    0.000    0.000    0.000 pretty.py:304(end_group)
#        34    0.000    0.000    0.000    0.000 pretty.py:512(remove)
#        34    0.000    0.000    0.000    0.000 pretty.py:184(group)
#        34    0.000    0.000    0.000    0.000 pretty.py:280(begin_group)
#        34    0.000    0.000    0.000    0.000 configurable.py:522(instance)
#        33    0.000    0.000    0.000    0.000 blas.py:384(getter)
#        33    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 graph.py:453(__contains__)
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        21    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        21    0.000    0.000    0.002    0.000 IPVisibilityPRM_Roundtrip.py:58(_nearestInterim)
#        17    0.000    0.000    0.000    0.000 <frozen genericpath>:16(exists)
#        17    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        17    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        17    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        17    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        17    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#        17    0.000    0.000    0.011    0.001 display_functions.py:105(display)
#        17    0.000    0.000    0.000    0.000 display.py:281(__init__)
#        17    0.000    0.000    0.000    0.000 display.py:349(reload)
#        17    0.000    0.000    0.000    0.000 pretty.py:232(text)
#        17    0.000    0.000    0.001    0.000 pretty.py:372(pretty)
#        17    0.000    0.000    0.010    0.001 formatters.py:90(format)
#        17    0.000    0.000    0.011    0.001 HelperClass.py:9(printInColor)
#        17    0.000    0.000    0.000    0.000 formatters.py:907(__call__)
#        17    0.000    0.000    0.000    0.000 formatters.py:953(__call__)
#        17    0.000    0.000    0.000    0.000 formatters.py:944(_check_return)
#        17    0.000    0.000    0.000    0.000 displaypub.py:130(publish)
#        17    0.000    0.000    0.001    0.000 formatters.py:695(__call__)
#        17    0.000    0.000    0.000    0.000 display.py:342(_data_and_metadata)
#        17    0.000    0.000    0.000    0.000 display.py:418(warn)
#        17    0.000    0.000    0.000    0.000 pretty.py:201(__init__)
#        17    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#        17    0.000    0.000    0.000    0.000 display_functions.py:45(publish_display_data)
#        17    0.000    0.000    0.000    0.000 display.py:434(_repr_html_)
#        17    0.000    0.000    0.000    0.000 pretty.py:355(__init__)
#        17    0.000    0.000    0.000    0.000 pretty.py:775(_repr_pprint)
#        17    0.000    0.000    0.000    0.000 display.py:57(_safe_exists)
#        17    0.000    0.000    0.000    0.000 pretty.py:490(__init__)
#        17    0.000    0.000    0.000    0.000 display.py:405(_check_data)
#        17    0.000    0.000    0.000    0.000 pretty.py:313(flush)
#        17    0.000    0.000    0.000    0.000 display.py:330(__repr__)
#        17    0.000    0.000    0.000    0.000 display.py:417(__init__)
#        17    0.000    0.000    0.000    0.000 configurable.py:566(initialized)
#        17    0.000    0.000    0.000    0.000 contextlib.py:287(helper)
#        17    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#        17    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#        15    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        15    0.000    0.000    0.000    0.000 unweighted.py:259(_bidirectional_pred_succ)
#        15    0.000    0.000    0.000    0.000 generic.py:41(shortest_path)
#        15    0.000    0.000    0.000    0.000 unweighted.py:196(bidirectional_shortest_path)
#        14    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 IPVisibilityPRM_Roundtrip.py:41(_getNodeNamebasedOnCoordinates)
#        14    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:193(_reshape_dispatcher)
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(reshape)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:198(reshape)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:38(_wrapit)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 <frozen _collections_abc>:859(__iter__)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2698(_amax_dispatcher)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amax)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2703(amax)
#         7    0.000    0.000    0.001    0.000 {method 'query' of 'scipy.spatial._ckdtree.cKDTree' objects}
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1991(shape)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1987(_shape_dispatcher)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#         7    0.000    0.000    0.000    0.000 numeric.py:1878(isscalar)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 function_base.py:867(_copy_dispatcher)
#         2    0.000    0.000    0.000    0.000 function_base.py:871(copy)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copy)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:812(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:790(items)
#         1    0.000    0.000    0.762    0.762 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 IPPlanerBase.py:22(_checkStartGoal)
#         1    0.004    0.004    0.737    0.737 IPVisibilityPRM_Roundtrip.py:96(_learnRoadmap)
#         1    0.000    0.000    0.762    0.762 IPVisibilityPRM_Roundtrip.py:145(planRoundPath)
#         1    0.000    0.000    0.762    0.762 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 reportviews.py:185(__iter__)
#         1    0.000    0.000    0.000    0.000 function.py:677(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function.py:655(get_node_attributes)
#         1    0.000    0.000    0.000    0.000 graph.py:1519(clear)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2824(_amin_dispatcher)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2829(amin)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Sat Jan 13 21:09:43 2024    ./stats/visibilitystats
#
#          742723 function calls (725119 primitive calls) in 0.762 seconds
#
#    Ordered by: cumulative time
#    List reduced from 204 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.762    0.762 {built-in method builtins.exec}
#         1    0.000    0.000    0.762    0.762 <string>:1(<module>)
#   17605/1    0.031    0.000    0.762    0.762 IPPerfMonitor.py:24(__call__)
#         1    0.000    0.000    0.762    0.762 IPVisibilityPRM_Roundtrip.py:145(planRoundPath)
#         1    0.004    0.004    0.737    0.737 IPVisibilityPRM_Roundtrip.py:96(_learnRoadmap)
#       620    0.080    0.000    0.710    0.001 IPEnvironment.py:42(lineInCollision)
#       613    0.001    0.000    0.703    0.001 IPVisibilityPRM_Roundtrip.py:38(_isVisible)
#     16648    0.055    0.000    0.571    0.000 IPEnvironment.py:31(pointInCollision)
#     16648    0.038    0.000    0.300    0.000 point.py:38(__init__)
#     16648    0.171    0.000    0.183    0.000 point.py:244(geos_point_from_py)
#     16648    0.017    0.000    0.143    0.000 base.py:803(intersects)
#     16648    0.087    0.000    0.122    0.000 predicates.py:11(__call__)
#     33296    0.045    0.000    0.082    0.000 base.py:191(_empty)
#    133184    0.068    0.000    0.068    0.000 base.py:245(__setattr__)
#     16648    0.017    0.000    0.067    0.000 base.py:240(_set_geom)
#
#
# Sat Jan 13 21:09:43 2024    ./stats/visibilitystats
#
#          742723 function calls (725119 primitive calls) in 0.762 seconds
#
#    Ordered by: call count
#    List reduced from 204 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    133184    0.068    0.000    0.068    0.000 base.py:245(__setattr__)
#     84688    0.009    0.000    0.009    0.000 {built-in method builtins.len}
#     66592    0.009    0.000    0.009    0.000 base.py:228(_geom)
#     35241    0.008    0.000    0.008    0.000 {built-in method builtins.isinstance}
#     35210    0.006    0.000    0.006    0.000 {built-in method time.time}
#     33846    0.006    0.000    0.006    0.000 {built-in method builtins.hasattr}
#     33296    0.019    0.000    0.027    0.000 topology.py:18(_validate)
#     33296    0.045    0.000    0.082    0.000 base.py:191(_empty)
#     19007    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#     17894    0.002    0.000    0.002    0.000 IPEnvironment.py:23(getDim)
#     17605    0.034    0.000    0.034    0.000 IPPerfMonitor.py:38(__get__)
#   17605/1    0.031    0.000    0.762    0.762 IPPerfMonitor.py:24(__call__)
#     16756    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#     16648    0.171    0.000    0.183    0.000 point.py:244(geos_point_from_py)
#     16648    0.038    0.000    0.300    0.000 point.py:38(__init__)
#
#
# Sat Jan 13 21:09:43 2024    ./stats/visibilitystats
#
#          742723 function calls (725119 primitive calls) in 0.762 seconds
#
#    Ordered by: internal time
#    List reduced from 204 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     16648    0.171    0.000    0.183    0.000 point.py:244(geos_point_from_py)
#     16648    0.087    0.000    0.122    0.000 predicates.py:11(__call__)
#       620    0.080    0.000    0.710    0.001 IPEnvironment.py:42(lineInCollision)
#    133184    0.068    0.000    0.068    0.000 base.py:245(__setattr__)
#     16648    0.055    0.000    0.571    0.000 IPEnvironment.py:31(pointInCollision)
#     33296    0.045    0.000    0.082    0.000 base.py:191(_empty)
#     16648    0.038    0.000    0.300    0.000 point.py:38(__init__)
#     17605    0.034    0.000    0.034    0.000 IPPerfMonitor.py:38(__get__)
#   17605/1    0.031    0.000    0.762    0.762 IPPerfMonitor.py:24(__call__)
#     33296    0.019    0.000    0.027    0.000 topology.py:18(_validate)
#     16648    0.017    0.000    0.067    0.000 base.py:240(_set_geom)
#     16648    0.017    0.000    0.143    0.000 base.py:803(intersects)
#     16648    0.011    0.000    0.067    0.000 base.py:208(__del__)
#     84688    0.009    0.000    0.009    0.000 {built-in method builtins.len}
#     66592    0.009    0.000    0.009    0.000 base.py:228(_geom)

# %%
# utility functions to read and access data in astartstats
import pstats
from pstats import SortKey

p = pstats.Stats('./stats/lazystats')
p.strip_dirs().sort_stats(SortKey.CALLS).print_stats()
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p.sort_stats(SortKey.CALLS).print_stats(15)
p.sort_stats(SortKey.TIME).print_stats(15)

    
# Anzeige der Benchmarks, noch nicht mit allen Vis möglich

for bench, result in zip(testList, resultList):
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    if result.benchmark.name == bench.name:
        pathLength[result.plannerFactoryName] = len(result.solution)
        planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
        roadmapSize[result.plannerFactoryName] = result.planner.graph.size()
# Out:
# Sat Jan 13 21:09:43 2024    ./stats/lazystats
#
#          151490 function calls (150266 primitive calls) in 0.119 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      8784    0.004    0.000    0.004    0.000 base.py:245(__setattr__)
#      8745    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      8710    0.002    0.000    0.002    0.000 traitlets.py:651(get)
#      8710    0.003    0.000    0.005    0.000 traitlets.py:689(__get__)
#      8710    0.001    0.000    0.001    0.000 inspect.py:2751(kind)
#      6804    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      6650    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#      6256    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#      4810    0.001    0.000    0.001    0.000 {built-in method builtins.next}
#      4392    0.001    0.000    0.001    0.000 base.py:228(_geom)
#      3315    0.000    0.000    0.000    0.000 inspect.py:2739(name)
#      3120    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#      3066    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      2945    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#      2860    0.002    0.000    0.004    0.000 formatters.py:552(_in_deferred_types)
#      2450    0.000    0.000    0.000    0.000 {built-in method time.time}
#      2360    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      2340    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#      2196    0.001    0.000    0.002    0.000 topology.py:18(_validate)
#      2196    0.003    0.000    0.005    0.000 base.py:191(_empty)
#      1829    0.001    0.000    0.001    0.000 reportviews.py:188(__getitem__)
#      1594    0.001    0.000    0.001    0.000 <frozen _collections_abc>:859(__iter__)
#      1225    0.002    0.000    0.002    0.000 IPPerfMonitor.py:38(__get__)
#    1225/1    0.002    0.000    0.118    0.118 IPPerfMonitor.py:24(__call__)
#      1176    0.000    0.000    0.000    0.000 IPEnvironment.py:23(getDim)
#      1163    0.001    0.000    0.001    0.000 reportviews.py:205(__call__)
#      1098    0.007    0.000    0.008    0.000 point.py:244(geos_point_from_py)
#      1098    0.003    0.000    0.016    0.000 point.py:38(__init__)
#      1098    0.001    0.000    0.010    0.000 base.py:803(intersects)
#      1098    0.000    0.000    0.000    0.000 geos.py:607(errcheck_predicate)
#      1098    0.001    0.000    0.004    0.000 base.py:208(__del__)
#      1098    0.000    0.000    0.000    0.000 impl.py:56(__getitem__)
#      1098    0.007    0.000    0.009    0.000 predicates.py:11(__call__)
#      1098    0.001    0.000    0.004    0.000 base.py:240(_set_geom)
#      1098    0.004    0.000    0.035    0.000 IPEnvironment.py:31(pointInCollision)
#      1065    0.000    0.000    0.000    0.000 reportviews.py:311(__init__)
#      1065    0.001    0.000    0.001    0.000 reportviews.py:329(__iter__)
#       922    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       910    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       907    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       900    0.008    0.000    0.008    0.000 IPLazyPRM_Roundtrip.py:107(<listcomp>)
#       810    0.001    0.000    0.001    0.000 graph.py:893(add_edge)
#       780    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       780    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#       780    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       780    0.002    0.000    0.003    0.000 inspect.py:2839(args)
#       780    0.002    0.000    0.002    0.000 inspect.py:2892(apply_defaults)
#       780    0.005    0.000    0.008    0.000 inspect.py:3076(_bind)
#       780    0.001    0.000    0.021    0.000 formatters.py:219(catch_format_error)
#       780    0.001    0.000    0.039    0.000 decorator.py:229(fun)
#       780    0.002    0.000    0.017    0.000 decorator.py:199(fix)
#       780    0.000    0.000    0.000    0.000 pretty.py:321(_get_mro)
#       780    0.001    0.000    0.002    0.000 inspect.py:2862(kwargs)
#       780    0.000    0.000    0.008    0.000 inspect.py:3207(bind)
#       780    0.000    0.000    0.000    0.000 inspect.py:2831(__init__)
#       715    0.003    0.000    0.010    0.000 formatters.py:396(lookup_by_type)
#       715    0.001    0.000    0.012    0.000 formatters.py:373(lookup)
#       715    0.000    0.000    0.000    0.000 formatters.py:273(_get_type)
#       715    0.000    0.000    0.000    0.000 formatters.py:358(_check_return)
#       715    0.001    0.000    0.002    0.000 dir2.py:54(get_real_method)
#       715    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#       585    0.001    0.000    0.012    0.000 formatters.py:330(__call__)
#       474    0.000    0.000    0.003    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       455    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#       441    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       398    0.001    0.000    0.001    0.000 {built-in method builtins.print}
#       299    0.000    0.000    0.000    0.000 coreviews.py:49(__iter__)
#       299    0.000    0.000    0.000    0.000 coreviews.py:80(__getitem__)
#       299    0.000    0.000    0.000    0.000 coreviews.py:43(__init__)
#       290    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       219    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       195    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#       195    0.000    0.000    0.000    0.000 pretty.py:495(enq)
#       195    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#       195    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#       180    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       180    0.000    0.000    0.000    0.000 fromnumeric.py:193(_reshape_dispatcher)
#       180    0.000    0.000    0.002    0.000 <__array_function__ internals>:177(reshape)
#       180    0.000    0.000    0.001    0.000 fromnumeric.py:198(reshape)
#       180    0.000    0.000    0.001    0.000 fromnumeric.py:51(_wrapfunc)
#       180    0.000    0.000    0.001    0.000 fromnumeric.py:38(_wrapit)
#       180    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       180    0.000    0.000    0.000    0.000 random.py:520(uniform)
#       158    0.000    0.000    0.001    0.000 _methods.py:61(_all)
#       154    0.000    0.000    0.000    0.000 distance.py:313(_validate_vector)
#       135    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       132    0.000    0.000    0.001    0.000 fromnumeric.py:69(_wrapreduction)
#       132    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#       130    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       130    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       130    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       130    0.000    0.000    0.000    0.000 pretty.py:304(end_group)
#       130    0.000    0.000    0.000    0.000 pretty.py:512(remove)
#       130    0.000    0.000    0.001    0.000 pretty.py:184(group)
#       130    0.000    0.000    0.001    0.000 pretty.py:280(begin_group)
#       130    0.000    0.000    0.000    0.000 configurable.py:522(instance)
#       114    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#       111    0.000    0.000    0.000    0.000 fromnumeric.py:2698(_amax_dispatcher)
#       111    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(amax)
#       111    0.000    0.000    0.001    0.000 fromnumeric.py:2703(amax)
#        97    0.000    0.000    0.000    0.000 graph.py:515(add_node)
#        90    0.002    0.000    0.005    0.000 {method 'query' of 'scipy.spatial._ckdtree.cKDTree' objects}
#        90    0.000    0.000    0.000    0.000 IPPRMBase.py:25(<listcomp>)
#        90    0.000    0.000    0.000    0.000 IPPRMBase.py:23(_getRandomPosition)
#        90    0.000    0.000    0.000    0.000 fromnumeric.py:1991(shape)
#        90    0.000    0.000    0.000    0.000 fromnumeric.py:1987(_shape_dispatcher)
#        90    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#        90    0.000    0.000    0.000    0.000 IPEnvironment.py:27(getEnvironmentLimits)
#        90    0.000    0.000    0.000    0.000 numeric.py:1878(isscalar)
#        88    0.001    0.000    0.001    0.000 IPLazyPRM_Roundtrip.py:29(_getNodeNamebasedOnCoordinates)
#        77    0.000    0.000    0.001    0.000 _misc.py:17(norm)
#        77    0.000    0.000    0.002    0.000 distance.py:429(minkowski)
#        77    0.000    0.000    0.002    0.000 distance.py:500(euclidean)
#        77    0.000    0.000    0.000    0.000 function_base.py:562(asarray_chkfinite)
#        65    0.000    0.000    0.001    0.000 <frozen genericpath>:16(exists)
#        65    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        65    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        65    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        65    0.001    0.000    0.001    0.000 {built-in method posix.stat}
#        65    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        65    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        65    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#        65    0.001    0.000    0.041    0.001 display_functions.py:105(display)
#        65    0.000    0.000    0.001    0.000 display.py:281(__init__)
#        65    0.000    0.000    0.000    0.000 display.py:349(reload)
#        65    0.000    0.000    0.000    0.000 pretty.py:232(text)
#        65    0.001    0.000    0.003    0.000 pretty.py:372(pretty)
#        65    0.001    0.000    0.040    0.001 formatters.py:90(format)
#        65    0.000    0.000    0.043    0.001 HelperClass.py:9(printInColor)
#        65    0.000    0.000    0.002    0.000 formatters.py:907(__call__)
#        65    0.000    0.000    0.002    0.000 formatters.py:953(__call__)
#        65    0.000    0.000    0.000    0.000 formatters.py:944(_check_return)
#        65    0.000    0.000    0.000    0.000 displaypub.py:130(publish)
#        65    0.000    0.000    0.004    0.000 formatters.py:695(__call__)
#        65    0.000    0.000    0.000    0.000 display.py:342(_data_and_metadata)
#        65    0.000    0.000    0.000    0.000 display.py:418(warn)
#        65    0.000    0.000    0.000    0.000 pretty.py:201(__init__)
#        65    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#        65    0.000    0.000    0.001    0.000 display_functions.py:45(publish_display_data)
#        65    0.000    0.000    0.000    0.000 display.py:434(_repr_html_)
#        65    0.000    0.000    0.001    0.000 pretty.py:355(__init__)
#        65    0.000    0.000    0.001    0.000 pretty.py:775(_repr_pprint)
#        65    0.000    0.000    0.001    0.000 display.py:57(_safe_exists)
#        65    0.000    0.000    0.000    0.000 pretty.py:490(__init__)
#        65    0.000    0.000    0.000    0.000 display.py:405(_check_data)
#        65    0.000    0.000    0.000    0.000 pretty.py:313(flush)
#        65    0.000    0.000    0.000    0.000 display.py:330(__repr__)
#        65    0.000    0.000    0.001    0.000 display.py:417(__init__)
#        65    0.000    0.000    0.000    0.000 configurable.py:566(initialized)
#        65    0.000    0.000    0.000    0.000 contextlib.py:287(helper)
#        65    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#        65    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#        60    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        50    0.000    0.000    0.000    0.000 graph.py:453(__contains__)
#        47    0.000    0.000    0.000    0.000 blas.py:384(getter)
#        47    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        42    0.000    0.000    0.046    0.001 IPLazyPRM_Roundtrip.py:114(_checkForCollisionAndUpdate)
#        42    0.000    0.000    0.000    0.000 function_base.py:867(_copy_dispatcher)
#        42    0.000    0.000    0.000    0.000 function_base.py:871(copy)
#        42    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copy)
#        38    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        36    0.005    0.000    0.042    0.001 IPEnvironment.py:42(lineInCollision)
#        30    0.000    0.000    0.000    0.000 linalg.py:2342(norm)
#        30    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 linalg.py:2338(_norm_dispatcher)
#        30    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(norm)
#        30    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#        27    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        27    0.000    0.000    0.002    0.000 IPLazyPRM_Roundtrip.py:46(_nearestInterim)
#        25    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        25    0.000    0.000    0.002    0.000 backends.py:129(wrapper)
#        25    0.001    0.000    0.001    0.000 unweighted.py:259(_bidirectional_pred_succ)
#        25    0.000    0.000    0.002    0.000 generic.py:41(shortest_path)
#        25    0.000    0.000    0.001    0.000 unweighted.py:196(bidirectional_shortest_path)
#        25    0.000    0.000    0.000    0.000 graph.py:1557(is_directed)
#        21    0.000    0.000    0.000    0.000 <frozen _collections_abc>:812(__init__)
#        21    0.000    0.000    0.000    0.000 <frozen _collections_abc>:790(items)
#        21    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        21    0.004    0.000    0.023    0.001 IPLazyPRM_Roundtrip.py:83(_buildRoadmap)
#        21    0.000    0.000    0.000    0.000 reportviews.py:185(__iter__)
#        21    0.000    0.000    0.002    0.000 function.py:677(<dictcomp>)
#        21    0.000    0.000    0.002    0.000 function.py:655(get_node_attributes)
#        21    0.000    0.000    0.000    0.000 fromnumeric.py:2824(_amin_dispatcher)
#        21    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#        21    0.000    0.000    0.000    0.000 fromnumeric.py:2829(amin)
#        14    0.000    0.000    0.000    0.000 graph.py:1091(remove_edge)
#         7    0.000    0.000    0.000    0.000 IPLazyPRM_Roundtrip.py:159(_findDuplicate)
#         6    0.000    0.000    0.000    0.000 graph.py:640(remove_node)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    0.119    0.119 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 IPPlanerBase.py:22(_checkStartGoal)
#         1    0.001    0.001    0.118    0.118 IPLazyPRM_Roundtrip.py:191(planRoundPath)
#         1    0.000    0.000    0.118    0.118 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 graph.py:1519(clear)
#         1    0.000    0.000    0.000    0.000 IPLazyPRM_Roundtrip.py:180(<listcomp>)
#         1    0.000    0.000    0.000    0.000 IPLazyPRM_Roundtrip.py:177(_removeDuplicate)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Sat Jan 13 21:09:43 2024    ./stats/lazystats
#
#          151490 function calls (150266 primitive calls) in 0.119 seconds
#
#    Ordered by: cumulative time
#    List reduced from 199 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.119    0.119 {built-in method builtins.exec}
#         1    0.000    0.000    0.118    0.118 <string>:1(<module>)
#    1225/1    0.002    0.000    0.118    0.118 IPPerfMonitor.py:24(__call__)
#         1    0.001    0.001    0.118    0.118 IPLazyPRM_Roundtrip.py:191(planRoundPath)
#        42    0.000    0.000    0.046    0.001 IPLazyPRM_Roundtrip.py:114(_checkForCollisionAndUpdate)
#        65    0.000    0.000    0.043    0.001 HelperClass.py:9(printInColor)
#        36    0.005    0.000    0.042    0.001 IPEnvironment.py:42(lineInCollision)
#        65    0.001    0.000    0.041    0.001 display_functions.py:105(display)
#        65    0.001    0.000    0.040    0.001 formatters.py:90(format)
#       780    0.001    0.000    0.039    0.000 decorator.py:229(fun)
#      1098    0.004    0.000    0.035    0.000 IPEnvironment.py:31(pointInCollision)
#        21    0.004    0.000    0.023    0.001 IPLazyPRM_Roundtrip.py:83(_buildRoadmap)
#       780    0.001    0.000    0.021    0.000 formatters.py:219(catch_format_error)
#       780    0.002    0.000    0.017    0.000 decorator.py:199(fix)
#      1098    0.003    0.000    0.016    0.000 point.py:38(__init__)
#
#
# Sat Jan 13 21:09:43 2024    ./stats/lazystats
#
#          151490 function calls (150266 primitive calls) in 0.119 seconds
#
#    Ordered by: call count
#    List reduced from 199 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      8784    0.004    0.000    0.004    0.000 base.py:245(__setattr__)
#      8745    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      8710    0.002    0.000    0.002    0.000 traitlets.py:651(get)
#      8710    0.003    0.000    0.005    0.000 traitlets.py:689(__get__)
#      8710    0.001    0.000    0.001    0.000 inspect.py:2751(kind)
#      6804    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      6650    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#      6256    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#      4810    0.001    0.000    0.001    0.000 {built-in method builtins.next}
#      4392    0.001    0.000    0.001    0.000 base.py:228(_geom)
#      3315    0.000    0.000    0.000    0.000 inspect.py:2739(name)
#      3120    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#      3066    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      2945    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#      2860    0.002    0.000    0.004    0.000 formatters.py:552(_in_deferred_types)
#
#
# Sat Jan 13 21:09:43 2024    ./stats/lazystats
#
#          151490 function calls (150266 primitive calls) in 0.119 seconds
#
#    Ordered by: internal time
#    List reduced from 199 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       900    0.008    0.000    0.008    0.000 IPLazyPRM_Roundtrip.py:107(<listcomp>)
#      1098    0.007    0.000    0.008    0.000 point.py:244(geos_point_from_py)
#      1098    0.007    0.000    0.009    0.000 predicates.py:11(__call__)
#        36    0.005    0.000    0.042    0.001 IPEnvironment.py:42(lineInCollision)
#       780    0.005    0.000    0.008    0.000 inspect.py:3076(_bind)
#      8784    0.004    0.000    0.004    0.000 base.py:245(__setattr__)
#      1098    0.004    0.000    0.035    0.000 IPEnvironment.py:31(pointInCollision)
#        21    0.004    0.000    0.023    0.001 IPLazyPRM_Roundtrip.py:83(_buildRoadmap)
#      2196    0.003    0.000    0.005    0.000 base.py:191(_empty)
#       715    0.003    0.000    0.010    0.000 formatters.py:396(lookup_by_type)
#      8710    0.003    0.000    0.005    0.000 traitlets.py:689(__get__)
#      1098    0.003    0.000    0.016    0.000 point.py:38(__init__)
#    1225/1    0.002    0.000    0.118    0.118 IPPerfMonitor.py:24(__call__)
#      1225    0.002    0.000    0.002    0.000 IPPerfMonitor.py:38(__get__)
#        90    0.002    0.000    0.005    0.000 {method 'query' of 'scipy.spatial._ckdtree.cKDTree' objects}

# %% [markdown]
# Example using IPerfMonitor
# --------------------------

# %%
from IPPerfMonitor import IPPerfMonitor

# %%
benchList = IPTestSuite.benchList

# KOnfig steht in plannerFactory
print(str(planner))
with io.capture_output() as captured:
    solution = planner.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,producer[1])


start = benchList[0].startList
goal = benchList[0].goalList

data_frame = IPPerfMonitor.dataFrame()

#fig_local = plt.figure(figsize=(10,10))
#ax = fig_local.add_subplot(1,1,1)

#IPVISVisibilityPRM.visibilityPRMVisualize(planner, solution, ax=ax, nodeSize=100)
# Out:
# <IPLazyPRM_Roundtrip.LazyPRM object at 0x7fbcf3a2c490>

# %%
resultList = list()
testList = benchList[:1]

solution = list()
data_frame = list()
i = 0
for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')

    for benchmark in testList:

        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        
        try:
            with io.capture_output() as captured:
                #resultList.append(ResultCollection(key,
                #                        planner, 
                #                        benchmark, 
                #                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                #                        IPPerfMonitor.dataFrame()),)
                solution.append(planner.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,producer[1]))
                data_frame.append(IPPerfMonitor.dataFrame())

                i = i + 1


        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            pass

print(solution[1])
# Out:
# <font color='yellow'>basePRM [<class 'IPBasicPRM_Roundtrip.BasicPRM'>, {'radius': 3, 'numNodes': 200}, <function basicPRMVisualize at 0x7fbcf148e2a0>]</font>
# <font color='yellow'>visibilityPRM [<class 'IPVisibilityPRM_Roundtrip.VisPRM'>, {'ntry': 300}, <function visibilityPRMVisualize at 0x7fbcf148e200>]</font>
# <font color='yellow'>lazyPRM [<class 'IPLazyPRM_Roundtrip.LazyPRM'>, {'initialRoadmapSize': 50, 'updateRoadmapSize': 2, 'kNearest': 10}, <function lazyPRMVisualize at 0x7fbcf375b7e0>]</font>
# ['start', 258, 6, 15, 0, 'interim1', 0, 'interim3', 0, 5, 1, 'interim4', 1, 30, 'interim2', 30, 17, 'interim0']

# %%
#data_frame

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0].groupby(["name"]).sum(numeric_only=True))
print("")

HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1].groupby(["name"]).sum(numeric_only=True))
print("")

HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2].groupby(["name"]).sum(numeric_only=True))
# Out:
# <font color='red'>Basic</font>
#                                    time
# name
# _getRandomFreePosition         0.008096
# _inSameConnectedComponent      0.089045
# _learnRoadmapNearestNeighbour  0.464064
# _nearestInterim                0.005758
# _nearestNeighbours             0.124292
# lineInCollision                0.252229
# planRoundPath                  0.497652
# pointInCollision               0.207741
# <font color='yellow'>Visibility</font>
#                             time
# name
# _getRandomFreePosition  0.013915
# _learnRoadmap           0.789268
# _nearestInterim         0.001041
# lineInCollision         0.767085
# planRoundPath           0.802417
# pointInCollision        0.595970
# <font color='green'>Lazy</font>
#                                  time
# name
# _buildRoadmap                0.022149
# _checkForCollisionAndUpdate  0.039331
# _nearestInterim              0.001504
# lineInCollision              0.036150
# planRoundPath                0.082970
# pointInCollision             0.028891

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0][data_frame[0]["name"]=="pointInCollision"][data_frame[0]["retVal"]==True].count())

HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1][data_frame[1]["name"]=="pointInCollision"][data_frame[1]["retVal"]==True].count())

HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2][data_frame[2]["name"]=="pointInCollision"][data_frame[2]["retVal"]==True].count())
# Out:
# <font color='red'>Basic</font>
# name      32
# args      32
# kwargs    32
# retVal    32
# time      32
# dtype: int64
# /tmp/ipykernel_99551/102077241.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(data_frame[0][data_frame[0]["name"]=="pointInCollision"][data_frame[0]["retVal"]==True].count())
# <font color='yellow'>Visibility</font>
# name      665
# args      665
# kwargs    665
# retVal    665
# time      665
# dtype: int64
# /tmp/ipykernel_99551/102077241.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(data_frame[1][data_frame[1]["name"]=="pointInCollision"][data_frame[1]["retVal"]==True].count())
# <font color='green'>Lazy</font>
# name      31
# args      31
# kwargs    31
# retVal    31
# time      31
# dtype: int64
# /tmp/ipykernel_99551/102077241.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(data_frame[2][data_frame[2]["name"]=="pointInCollision"][data_frame[2]["retVal"]==True].count())

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0].groupby(["name"]).count())
print("")
HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1].groupby(["name"]).count())
print("")
HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2].groupby(["name"]).count())
# Out:
# <font color='red'>Basic</font>
#                                args  kwargs  retVal  time
# name
# _getRandomFreePosition          200     200     200   200
# _inSameConnectedComponent      1216    1216    1216  1216
# _learnRoadmapNearestNeighbour     1       1       0     1
# _nearestInterim                  52      52      52    52
# _nearestNeighbours              207     207     207   207
# lineInCollision                 208     208     208   208
# planRoundPath                     1       1       1     1
# pointInCollision               8482    8482    8482  8482
# <font color='yellow'>Visibility</font>
#                          args  kwargs  retVal   time
# name
# _getRandomFreePosition    553     553     553    553
# _learnRoadmap               1       1       0      1
# _nearestInterim            23      23      23     23
# lineInCollision          1140    1140    1140   1140
# planRoundPath               1       1       1      1
# pointInCollision        31460   31460   31460  31460
# <font color='green'>Lazy</font>
#                              args  kwargs  retVal  time
# name
# _buildRoadmap                  32      32       0    32
# _checkForCollisionAndUpdate    51      51      51    51
# _nearestInterim                25      25      25    25
# lineInCollision                47      47      47    47
# planRoundPath                   1       1       1     1
# pointInCollision             1310    1310    1310  1310

# %% [markdown]
# Second Example using IPPerfMonitor
# ----------------------------------

# %%
import IPVisibilityPRM_Roundtrip
import IPVISVisibilityPRM

# %%
visbilityConfig = dict()
visbilityConfig["ntry"] = 300

vis = plannerFactory["visibilityPRM"][0](benchList[3].collisionChecker)

start = benchList[3].startList
goal = benchList[3].goalList

IPPerfMonitor.clearData()

with io.capture_output() as captured:
    solution = vis.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,visbilityConfig)

data_frame = IPPerfMonitor.dataFrame()

fig_local = plt.figure(figsize=(10,10))
ax = fig_local.add_subplot(1,1,1)
IPVISVisibilityPRM.visibilityPRMVisualize(vis, solution, ax = ax)
# Out:
# /home/maurice/anaconda3/lib/python3.11/site-packages/descartes/patch.py:62: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   vertices = concatenate([

# %%
data_frame
# Out:
#                    name                                               args  \
# 0      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 1      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 2      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 3      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# 4      pointInCollision  (<IPEnvironment.CollisionChecker object at 0x7...
# ...                 ...                                                ...
# 77407   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 77408   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 77409   _nearestInterim  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 77410     _learnRoadmap  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
# 77411     planRoundPath  (<IPVisibilityPRM_Roundtrip.VisPRM object at 0...
#
#       kwargs                                             retVal       time
# 0         {}                                              False   0.001807
# 1         {}                                              False   0.000695
# 2         {}                                               True   0.000715
# 3         {}                                              False   0.000489
# 4         {}                                              False   0.000513
# ...      ...                                                ...        ...
# 77407     {}           [[20, 15], 2.5698489209379964, interim2]   0.000028
# 77408     {}           [[20, 15], 0.3870585147280931, interim2]   0.000028
# 77409     {}                          [[20, 15], 0.0, interim2]   0.000029
# 77410     {}                                               None  14.432364
# 77411     {}  [start, 0, 40, 23, 177, 175, interim0, 175, 17...  14.507508
#
# [77412 rows x 5 columns]

# %%
data_frame.groupby(["name"]).count()
# Out:
#                          args  kwargs  retVal   time
# name
# _getRandomFreePosition   1229    1229    1229   1229
# _learnRoadmap               1       1       0      1
# _nearestInterim            32      32      32     32
# lineInCollision          3487    3487    3487   3487
# planRoundPath               1       1       1      1
# pointInCollision        72662   72662   72662  72662

# %%
data_frame.groupby(["name"]).sum(numeric_only=True)
# Out:
#                              time
# name
# _getRandomFreePosition   0.354506
# _learnRoadmap           14.432364
# _nearestInterim          0.001390
# lineInCollision         14.008358
# planRoundPath           14.507508
# pointInCollision        13.892788
