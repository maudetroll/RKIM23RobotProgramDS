# %% [markdown]
# Example Profiling
# ==============================
#
#
#
# Example using cProfile/pstats
# -----------------------------
#
# Following an example how to profile the algorithm using https://docs.python.org/3/library/profile.html

# %%
import IPTestSuite
import IPLazyPRM_Roundtrip
import IPVISLazyPRM

import IPVISVisibilityPRM
import IPVisibilityPRM_Roundtrip

import IPBasicPRM_Roundtrip
import IPVISBasicPRM

import HelperClass
from IPPerfMonitor import IPPerfMonitor

import IPVISBasicPRM



from __future__ import print_function
import sys

from IPython.utils import io

from matplotlib import pylab as plt

benchList = IPTestSuite.benchList
print(benchList)


start = benchList[0].startList
goal = benchList[0].goalList

plannerFactory = dict()

basicConfig = dict()
basicConfig["radius"] = 3
basicConfig["numNodes"] = 200
plannerFactory["basePRM"] = [IPBasicPRM_Roundtrip.BasicPRM, basicConfig, IPVISBasicPRM.basicPRMVisualize]

visbilityConfig = dict()
visbilityConfig["ntry"] = 300
plannerFactory["visibilityPRM"] = [IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]

lazyConfig = dict()
lazyConfig["initialRoadmapSize"] = 50
lazyConfig["updateRoadmapSize"]  = 2
lazyConfig["kNearest"] = 10
plannerFactory["lazyPRM"] = [IPLazyPRM_Roundtrip.LazyPRM, lazyConfig, IPVISLazyPRM.lazyPRMVisualize]
# Out:
# [<IPBenchmark.Benchmark object at 0x7f4b56cd3210>, <IPBenchmark.Benchmark object at 0x7f4b56b1c310>, <IPBenchmark.Benchmark object at 0x7f4b56b1c6d0>, <IPBenchmark.Benchmark object at 0x7f4b56b1ced0>, <IPBenchmark.Benchmark object at 0x7f4b56b1db50>]

# %%
class ResultCollection (object):
    
    def __init__(self, plannerFactoryName, planner, benchmark, solution, perfDataFrame):
        self.plannerFactoryName = plannerFactoryName
        self.planner = planner
        self.benchmark = benchmark
        self.solution = solution
        self.perfDataFrame = perfDataFrame

# %%
resultList = list()
testList = benchList[:1]
i = 0
for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')
    #print(key, producer)
    print(key)
    for benchmark in testList:
        #HelperClass.HelperClass.printInColor("Planning: " + key + " - " + benchmark.name, 'yellow')
        #planner = IPBasicPRM.BasicPRM(benchmark.collisionChecker)
        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        
        print("Hallo")
        try:
            with io.capture_output() as captured:
                resultList.append(ResultCollection(key,
                                        planner, 
                                        benchmark, 
                                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                                        IPPerfMonitor.dataFrame()),)
            #a = planner.planPath(benchmark.startList,benchmark.goalList,producer[1])
            # print("")
            i = i + 1

        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            pass
# Out:
# <font color='yellow'>basePRM [<class 'IPBasicPRM_Roundtrip.BasicPRM'>, {'radius': 3, 'numNodes': 200}, <function basicPRMVisualize at 0x7f4b548822a0>]</font>
# basePRM
# Hallo
# <font color='yellow'>visibilityPRM [<class 'IPVisibilityPRM_Roundtrip.VisPRM'>, {'ntry': 300}, <function visibilityPRMVisualize at 0x7f4b54882200>]</font>
# visibilityPRM
# Hallo
# <font color='yellow'>lazyPRM [<class 'IPLazyPRM_Roundtrip.LazyPRM'>, {'initialRoadmapSize': 50, 'updateRoadmapSize': 2, 'kNearest': 10}, <function lazyPRMVisualize at 0x7f4b56d3f7e0>]</font>
# lazyPRM
# Hallo

# %%
# Executing the planning. 
import cProfile
from IPPRMBase import PRMBase

for i in plannerFactory:
    print("i",i)


plannerBasic = resultList[0].planner
plannerBasicProducer = plannerFactory["basePRM"]
plannerVisibility = resultList[1].planner
plannerVisibilityProducer = plannerFactory["visibilityPRM"]
plannerLazy = resultList[2].planner
plannerLazyProducer = plannerFactory["lazyPRM"]

print(plannerVisibilityProducer[1])


HelperClass.HelperClass.printInColor("BasicPRMRound", "red")
with io.capture_output() as capturedBasic:
    cProfile.run('solution =plannerBasic.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerBasicProducer[1])','./stats/basicstats') 


HelperClass.HelperClass.printInColor("VisibiltyPRMRound", "orange")
with io.capture_output() as capturedVisibility:
    cProfile.run('solution = plannerVisibility.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerVisibilityProducer[1])','./stats/visibilitystats') 

HelperClass.HelperClass.printInColor("LazyPRMRound", "green")
with io.capture_output() as capturedVisibility:
    cProfile.run('solution = plannerLazy.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,plannerLazyProducer[1])','./stats/lazystats')
# Out:
# i basePRM
# i visibilityPRM
# i lazyPRM
# {'ntry': 300}
# <font color='red'>BasicPRMRound</font>
# <font color='orange'>VisibiltyPRMRound</font>
# <font color='green'>LazyPRMRound</font>

# %%
# utility functions to read and access data in astartstats
import pstats
from pstats import SortKey

p = pstats.Stats('./stats/basicstats')
p.strip_dirs().sort_stats(SortKey.CALLS).print_stats()
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p.sort_stats(SortKey.CALLS).print_stats(15)
p.sort_stats(SortKey.TIME).print_stats(15)

    
# Anzeige der Benchmarks, noch nicht mit allen Vis möglich

for bench, result in zip(testList, resultList):
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    if result.benchmark.name == bench.name:
        pathLength[result.plannerFactoryName] = len(result.solution)
        planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
        roadmapSize[result.plannerFactoryName] = result.planner.graph.size()
# Out:
# Sat Jan 13 21:05:26 2024    ./stats/basicstats
#
#          1612575 function calls (1602163 primitive calls) in 1.111 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    146621    0.013    0.000    0.013    0.000 {built-in method builtins.iter}
#    145687    0.056    0.000    0.104    0.000 {method 'update' of 'set' objects}
#    143935    0.036    0.000    0.048    0.000 coreviews.py:49(__iter__)
#    143935    0.060    0.000    0.079    0.000 coreviews.py:80(__getitem__)
#    143935    0.019    0.000    0.019    0.000 coreviews.py:43(__init__)
#    142921    0.015    0.000    0.015    0.000 {method 'add' of 'set' objects}
#     68400    0.041    0.000    0.041    0.000 base.py:245(__setattr__)
#     65111    0.033    0.000    0.033    0.000 {built-in method numpy.asarray}
#     44124    0.006    0.000    0.006    0.000 {built-in method builtins.len}
#     43370    0.018    0.000    0.047    0.000 distance.py:313(_validate_vector)
#     34200    0.006    0.000    0.006    0.000 base.py:228(_geom)
#     21880    0.005    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#     21685    0.037    0.000    0.151    0.000 _misc.py:17(norm)
#     21685    0.041    0.000    0.240    0.000 distance.py:429(minkowski)
#     21685    0.011    0.000    0.251    0.000 distance.py:500(euclidean)
#     21685    0.032    0.000    0.096    0.000 function_base.py:562(asarray_chkfinite)
#     21629    0.012    0.000    0.017    0.000 blas.py:384(getter)
#     21629    0.011    0.000    0.060    0.000 {method 'all' of 'numpy.ndarray' objects}
#     21629    0.042    0.000    0.042    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     21629    0.008    0.000    0.049    0.000 _methods.py:61(_all)
#     20826    0.004    0.000    0.004    0.000 {built-in method time.time}
#     18945    0.005    0.000    0.005    0.000 {built-in method builtins.isinstance}
#     18921    0.004    0.000    0.004    0.000 {built-in method builtins.hasattr}
#     17100    0.011    0.000    0.016    0.000 topology.py:18(_validate)
#     17100    0.026    0.000    0.049    0.000 base.py:191(_empty)
#     16931    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#     10413    0.025    0.000    0.025    0.000 IPPerfMonitor.py:38(__get__)
#   10413/1    0.024    0.000    1.111    1.111 IPPerfMonitor.py:24(__call__)
#      9008    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      8980    0.001    0.000    0.001    0.000 IPEnvironment.py:23(getDim)
#      8550    0.129    0.000    0.136    0.000 point.py:244(geos_point_from_py)
#      8550    0.024    0.000    0.207    0.000 point.py:38(__init__)
#      8550    0.007    0.000    0.039    0.000 base.py:208(__del__)
#      8550    0.002    0.000    0.002    0.000 impl.py:56(__getitem__)
#      8550    0.049    0.000    0.069    0.000 predicates.py:11(__call__)
#      8550    0.011    0.000    0.081    0.000 base.py:803(intersects)
#      8550    0.002    0.000    0.002    0.000 geos.py:607(errcheck_predicate)
#      8550    0.010    0.000    0.040    0.000 base.py:240(_set_geom)
#      8550    0.033    0.000    0.365    0.000 IPEnvironment.py:31(pointInCollision)
#      6030    0.001    0.000    0.001    0.000 traitlets.py:651(get)
#      6030    0.002    0.000    0.003    0.000 traitlets.py:689(__get__)
#      6030    0.001    0.000    0.001    0.000 inspect.py:2751(kind)
#      5805    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      3959    0.005    0.000    0.321    0.000 connected.py:15(connected_components)
#      3330    0.001    0.000    0.001    0.000 {built-in method builtins.next}
#      2766    0.117    0.000    0.313    0.000 connected.py:191(_plain_bfs)
#      2295    0.000    0.000    0.000    0.000 inspect.py:2739(name)
#      2160    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#      1980    0.001    0.000    0.003    0.000 formatters.py:552(_in_deferred_types)
#      1620    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#      1236    0.002    0.000    0.007    0.000 backends.py:129(wrapper)
#      1236    0.000    0.000    0.000    0.000 graph.py:1557(is_directed)
#      1193    0.004    0.000    0.330    0.000 IPBasicPRM_Roundtrip.py:29(_inSameConnectedComponent)
#      1193    0.001    0.000    0.001    0.000 graph.py:435(__iter__)
#      1193    0.001    0.000    0.001    0.000 decorators.py:82(_not_implemented_for)
#      1193    0.001    0.000    0.003    0.000 <class 'networkx.utils.decorators.argmap'> compilation 4:1(argmap_connected_components_1)
#       630    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       540    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       540    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       540    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       540    0.002    0.000    0.002    0.000 inspect.py:2839(args)
#       540    0.001    0.000    0.001    0.000 inspect.py:2892(apply_defaults)
#       540    0.003    0.000    0.005    0.000 inspect.py:3076(_bind)
#       540    0.001    0.000    0.014    0.000 formatters.py:219(catch_format_error)
#       540    0.001    0.000    0.025    0.000 decorator.py:229(fun)
#       540    0.001    0.000    0.011    0.000 decorator.py:199(fix)
#       540    0.000    0.000    0.000    0.000 pretty.py:321(_get_mro)
#       540    0.001    0.000    0.001    0.000 inspect.py:2862(kwargs)
#       540    0.000    0.000    0.005    0.000 inspect.py:3207(bind)
#       540    0.000    0.000    0.000    0.000 inspect.py:2831(__init__)
#       495    0.002    0.000    0.006    0.000 formatters.py:396(lookup_by_type)
#       495    0.000    0.000    0.000    0.000 formatters.py:273(_get_type)
#       495    0.001    0.000    0.008    0.000 formatters.py:373(lookup)
#       495    0.000    0.000    0.000    0.000 formatters.py:358(_check_return)
#       495    0.001    0.000    0.001    0.000 dir2.py:54(get_real_method)
#       495    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#       448    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       448    0.000    0.000    0.001    0.000 random.py:520(uniform)
#       424    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#       413    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       413    0.000    0.000    0.000    0.000 reportviews.py:311(__init__)
#       413    0.001    0.000    0.001    0.000 reportviews.py:205(__call__)
#       413    0.000    0.000    0.001    0.000 reportviews.py:329(__iter__)
#       405    0.001    0.000    0.008    0.000 formatters.py:330(__call__)
#       315    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#       224    0.001    0.000    0.001    0.000 IPPRMBase.py:25(<listcomp>)
#       224    0.001    0.000    0.002    0.000 IPPRMBase.py:23(_getRandomPosition)
#       224    0.000    0.000    0.000    0.000 IPEnvironment.py:27(getEnvironmentLimits)
#       212    0.045    0.000    0.440    0.002 IPEnvironment.py:42(lineInCollision)
#       207    0.016    0.000    0.266    0.001 IPBasicPRM_Roundtrip.py:41(_nearestNeighbours)
#       207    0.001    0.000    0.001    0.000 graph.py:515(add_node)
#       206    0.001    0.000    0.001    0.000 graph.py:893(add_edge)
#       200    0.001    0.000    0.016    0.000 IPPRMBase.py:28(_getRandomFreePosition)
#       177    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       135    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#       135    0.000    0.000    0.000    0.000 pretty.py:495(enq)
#       135    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#       135    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#       112    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        94    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        90    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        90    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        90    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        90    0.000    0.000    0.000    0.000 reportviews.py:188(__getitem__)
#        90    0.000    0.000    0.000    0.000 pretty.py:304(end_group)
#        90    0.000    0.000    0.000    0.000 pretty.py:512(remove)
#        90    0.000    0.000    0.000    0.000 pretty.py:184(group)
#        90    0.000    0.000    0.000    0.000 pretty.py:280(begin_group)
#        90    0.000    0.000    0.000    0.000 configurable.py:522(instance)
#        86    0.000    0.000    0.000    0.000 graph.py:453(__contains__)
#        56    0.000    0.000    0.000    0.000 linalg.py:2342(norm)
#        56    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        56    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(norm)
#        56    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#        56    0.000    0.000    0.000    0.000 linalg.py:2338(_norm_dispatcher)
#        49    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        49    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        49    0.006    0.000    0.009    0.000 IPBasicPRM_Roundtrip.py:73(_nearestInterim)
#        45    0.000    0.000    0.000    0.000 <frozen genericpath>:16(exists)
#        45    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        45    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        45    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        45    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#        45    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        45    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        45    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#        45    0.000    0.000    0.027    0.001 display_functions.py:105(display)
#        45    0.000    0.000    0.001    0.000 display.py:281(__init__)
#        45    0.000    0.000    0.000    0.000 display.py:349(reload)
#        45    0.000    0.000    0.000    0.000 pretty.py:232(text)
#        45    0.000    0.000    0.002    0.000 pretty.py:372(pretty)
#        45    0.001    0.000    0.026    0.001 formatters.py:90(format)
#        45    0.000    0.000    0.028    0.001 HelperClass.py:9(printInColor)
#        45    0.000    0.000    0.000    0.000 displaypub.py:130(publish)
#        45    0.000    0.000    0.001    0.000 formatters.py:907(__call__)
#        45    0.000    0.000    0.001    0.000 formatters.py:953(__call__)
#        45    0.000    0.000    0.000    0.000 formatters.py:944(_check_return)
#        45    0.000    0.000    0.000    0.000 display.py:342(_data_and_metadata)
#        45    0.000    0.000    0.000    0.000 display.py:418(warn)
#        45    0.000    0.000    0.000    0.000 pretty.py:201(__init__)
#        45    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#        45    0.000    0.000    0.000    0.000 display_functions.py:45(publish_display_data)
#        45    0.000    0.000    0.000    0.000 display.py:434(_repr_html_)
#        45    0.000    0.000    0.000    0.000 pretty.py:355(__init__)
#        45    0.000    0.000    0.001    0.000 pretty.py:775(_repr_pprint)
#        45    0.000    0.000    0.001    0.000 display.py:57(_safe_exists)
#        45    0.000    0.000    0.000    0.000 pretty.py:490(__init__)
#        45    0.000    0.000    0.000    0.000 display.py:405(_check_data)
#        45    0.000    0.000    0.000    0.000 pretty.py:313(flush)
#        45    0.000    0.000    0.003    0.000 formatters.py:695(__call__)
#        45    0.000    0.000    0.000    0.000 display.py:330(__repr__)
#        45    0.000    0.000    0.001    0.000 display.py:417(__init__)
#        45    0.000    0.000    0.000    0.000 configurable.py:566(initialized)
#        45    0.000    0.000    0.000    0.000 contextlib.py:287(helper)
#        45    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#        45    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#        43    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        43    0.001    0.000    0.002    0.000 unweighted.py:259(_bidirectional_pred_succ)
#        43    0.000    0.000    0.003    0.000 generic.py:41(shortest_path)
#        43    0.000    0.000    0.003    0.000 unweighted.py:196(bidirectional_shortest_path)
#        42    0.000    0.000    0.000    0.000 IPBasicPRM_Roundtrip.py:55(_getNodeNamebasedOnCoordinates)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         1    0.000    0.000    1.111    1.111 {built-in method builtins.exec}
#         1    0.000    0.000    0.001    0.001 IPPlanerBase.py:22(_checkStartGoal)
#         1    0.001    0.001    1.111    1.111 IPBasicPRM_Roundtrip.py:135(planRoundPath)
#         1    0.004    0.004    1.042    1.042 IPBasicPRM_Roundtrip.py:111(_learnRoadmapNearestNeighbour)
#         1    0.000    0.000    1.111    1.111 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 graph.py:1519(clear)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Sat Jan 13 21:05:26 2024    ./stats/basicstats
#
#          1612575 function calls (1602163 primitive calls) in 1.111 seconds
#
#    Ordered by: cumulative time
#    List reduced from 172 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    1.111    1.111 {built-in method builtins.exec}
#         1    0.000    0.000    1.111    1.111 <string>:1(<module>)
#   10413/1    0.024    0.000    1.111    1.111 IPPerfMonitor.py:24(__call__)
#         1    0.001    0.001    1.111    1.111 IPBasicPRM_Roundtrip.py:135(planRoundPath)
#         1    0.004    0.004    1.042    1.042 IPBasicPRM_Roundtrip.py:111(_learnRoadmapNearestNeighbour)
#       212    0.045    0.000    0.440    0.002 IPEnvironment.py:42(lineInCollision)
#      8550    0.033    0.000    0.365    0.000 IPEnvironment.py:31(pointInCollision)
#      1193    0.004    0.000    0.330    0.000 IPBasicPRM_Roundtrip.py:29(_inSameConnectedComponent)
#      3959    0.005    0.000    0.321    0.000 connected.py:15(connected_components)
#      2766    0.117    0.000    0.313    0.000 connected.py:191(_plain_bfs)
#       207    0.016    0.000    0.266    0.001 IPBasicPRM_Roundtrip.py:41(_nearestNeighbours)
#     21685    0.011    0.000    0.251    0.000 distance.py:500(euclidean)
#     21685    0.041    0.000    0.240    0.000 distance.py:429(minkowski)
#      8550    0.024    0.000    0.207    0.000 point.py:38(__init__)
#     21685    0.037    0.000    0.151    0.000 _misc.py:17(norm)
#
#
# Sat Jan 13 21:05:26 2024    ./stats/basicstats
#
#          1612575 function calls (1602163 primitive calls) in 1.111 seconds
#
#    Ordered by: call count
#    List reduced from 172 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    146621    0.013    0.000    0.013    0.000 {built-in method builtins.iter}
#    145687    0.056    0.000    0.104    0.000 {method 'update' of 'set' objects}
#    143935    0.036    0.000    0.048    0.000 coreviews.py:49(__iter__)
#    143935    0.060    0.000    0.079    0.000 coreviews.py:80(__getitem__)
#    143935    0.019    0.000    0.019    0.000 coreviews.py:43(__init__)
#    142921    0.015    0.000    0.015    0.000 {method 'add' of 'set' objects}
#     68400    0.041    0.000    0.041    0.000 base.py:245(__setattr__)
#     65111    0.033    0.000    0.033    0.000 {built-in method numpy.asarray}
#     44124    0.006    0.000    0.006    0.000 {built-in method builtins.len}
#     43370    0.018    0.000    0.047    0.000 distance.py:313(_validate_vector)
#     34200    0.006    0.000    0.006    0.000 base.py:228(_geom)
#     21880    0.005    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#     21685    0.037    0.000    0.151    0.000 _misc.py:17(norm)
#     21685    0.041    0.000    0.240    0.000 distance.py:429(minkowski)
#     21685    0.011    0.000    0.251    0.000 distance.py:500(euclidean)
#
#
# Sat Jan 13 21:05:26 2024    ./stats/basicstats
#
#          1612575 function calls (1602163 primitive calls) in 1.111 seconds
#
#    Ordered by: internal time
#    List reduced from 172 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      8550    0.129    0.000    0.136    0.000 point.py:244(geos_point_from_py)
#      2766    0.117    0.000    0.313    0.000 connected.py:191(_plain_bfs)
#    143935    0.060    0.000    0.079    0.000 coreviews.py:80(__getitem__)
#    145687    0.056    0.000    0.104    0.000 {method 'update' of 'set' objects}
#      8550    0.049    0.000    0.069    0.000 predicates.py:11(__call__)
#       212    0.045    0.000    0.440    0.002 IPEnvironment.py:42(lineInCollision)
#     21629    0.042    0.000    0.042    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     21685    0.041    0.000    0.240    0.000 distance.py:429(minkowski)
#     68400    0.041    0.000    0.041    0.000 base.py:245(__setattr__)
#     21685    0.037    0.000    0.151    0.000 _misc.py:17(norm)
#    143935    0.036    0.000    0.048    0.000 coreviews.py:49(__iter__)
#      8550    0.033    0.000    0.365    0.000 IPEnvironment.py:31(pointInCollision)
#     65111    0.033    0.000    0.033    0.000 {built-in method numpy.asarray}
#     21685    0.032    0.000    0.096    0.000 function_base.py:562(asarray_chkfinite)
#     17100    0.026    0.000    0.049    0.000 base.py:191(_empty)

# %%
# utility functions to read and access data in astartstats
import pstats
from pstats import SortKey

p = pstats.Stats('./stats/visibilitystats')
p.strip_dirs().sort_stats(SortKey.CALLS).print_stats()
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p.sort_stats(SortKey.CALLS).print_stats(15)
p.sort_stats(SortKey.TIME).print_stats(15)

    
# Anzeige der Benchmarks, noch nicht mit allen Vis möglich

for bench, result in zip(testList, resultList):
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    if result.benchmark.name == bench.name:
        pathLength[result.plannerFactoryName] = len(result.solution)
        planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
        roadmapSize[result.plannerFactoryName] = result.planner.graph.size()
# Out:
# Sat Jan 13 21:05:27 2024    ./stats/visibilitystats
#
#          818884 function calls (799489 primitive calls) in 0.841 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    146568    0.082    0.000    0.082    0.000 base.py:245(__setattr__)
#     93338    0.011    0.000    0.011    0.000 {built-in method builtins.len}
#     73284    0.011    0.000    0.011    0.000 base.py:228(_geom)
#     39025    0.009    0.000    0.009    0.000 {built-in method builtins.isinstance}
#     38792    0.007    0.000    0.007    0.000 {built-in method time.time}
#     37235    0.008    0.000    0.008    0.000 {built-in method builtins.hasattr}
#     36642    0.021    0.000    0.030    0.000 topology.py:18(_validate)
#     36642    0.052    0.000    0.097    0.000 base.py:191(_empty)
#     21079    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#     19795    0.003    0.000    0.003    0.000 IPEnvironment.py:23(getDim)
#     19396    0.042    0.000    0.042    0.000 IPPerfMonitor.py:38(__get__)
#   19396/1    0.039    0.000    0.840    0.840 IPPerfMonitor.py:24(__call__)
#     18449    0.003    0.000    0.003    0.000 {method 'items' of 'dict' objects}
#     18321    0.124    0.000    0.138    0.000 point.py:244(geos_point_from_py)
#     18321    0.046    0.000    0.278    0.000 point.py:38(__init__)
#     18321    0.013    0.000    0.079    0.000 base.py:208(__del__)
#     18321    0.004    0.000    0.004    0.000 impl.py:56(__getitem__)
#     18321    0.115    0.000    0.155    0.000 predicates.py:11(__call__)
#     18321    0.021    0.000    0.180    0.000 base.py:803(intersects)
#     18321    0.004    0.000    0.004    0.000 geos.py:607(errcheck_predicate)
#     18321    0.020    0.000    0.079    0.000 base.py:240(_set_geom)
#     18321    0.065    0.000    0.610    0.000 IPEnvironment.py:31(pointInCollision)
#      3108    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#      2680    0.001    0.000    0.001    0.000 traitlets.py:651(get)
#      2680    0.001    0.000    0.001    0.000 traitlets.py:689(__get__)
#      2680    0.000    0.000    0.000    0.000 inspect.py:2751(kind)
#      2608    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#      2478    0.001    0.000    0.002    0.000 {method 'update' of 'set' objects}
#      2213    0.001    0.000    0.001    0.000 coreviews.py:49(__iter__)
#      2213    0.001    0.000    0.002    0.000 coreviews.py:80(__getitem__)
#      2213    0.000    0.000    0.000    0.000 coreviews.py:43(__init__)
#      2150    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#      1648    0.000    0.000    0.000    0.000 reportviews.py:205(__call__)
#      1596    0.001    0.000    0.001    0.000 reportviews.py:188(__getitem__)
#      1480    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#      1470    0.002    0.000    0.002    0.000 {built-in method numpy.array}
#      1067    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#      1020    0.000    0.000    0.000    0.000 inspect.py:2739(name)
#       960    0.000    0.000    0.000    0.000 inspect.py:3032(parameters)
#       880    0.001    0.000    0.001    0.000 formatters.py:552(_in_deferred_types)
#       805    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       738    0.002    0.000    0.002    0.000 graph.py:893(add_edge)
#       738    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#       738    0.001    0.000    0.001    0.000 random.py:520(uniform)
#       734    0.094    0.000    0.776    0.001 IPEnvironment.py:42(lineInCollision)
#       725    0.001    0.000    0.003    0.000 IPVisibilityPRM_Roundtrip.py:26(addVisTest)
#       725    0.001    0.000    0.770    0.001 IPVisibilityPRM_Roundtrip.py:38(_isVisible)
#       720    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#       643    0.001    0.000    0.009    0.000 connected.py:15(connected_components)
#       369    0.001    0.000    0.002    0.000 IPPRMBase.py:25(<listcomp>)
#       369    0.001    0.000    0.002    0.000 IPPRMBase.py:23(_getRandomPosition)
#       369    0.000    0.000    0.000    0.000 IPEnvironment.py:27(getEnvironmentLimits)
#       333    0.000    0.000    0.002    0.000 backends.py:129(wrapper)
#       333    0.000    0.000    0.000    0.000 graph.py:1557(is_directed)
#       329    0.001    0.000    0.001    0.000 graph.py:515(add_node)
#       328    0.003    0.000    0.008    0.000 connected.py:191(_plain_bfs)
#       315    0.001    0.000    0.001    0.000 IPVisibilityPRM_Roundtrip.py:22(addNodeAtPos)
#       315    0.000    0.000    0.000    0.000 graph.py:435(__iter__)
#       315    0.000    0.000    0.000    0.000 decorators.py:82(_not_implemented_for)
#       315    0.001    0.000    0.019    0.000 IPPRMBase.py:28(_getRandomFreePosition)
#       315    0.000    0.000    0.001    0.000 <class 'networkx.utils.decorators.argmap'> compilation 4:1(argmap_connected_components_1)
#       295    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       280    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       240    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#       240    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       240    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#       240    0.001    0.000    0.001    0.000 inspect.py:2839(args)
#       240    0.000    0.000    0.001    0.000 inspect.py:2892(apply_defaults)
#       240    0.002    0.000    0.002    0.000 inspect.py:3076(_bind)
#       240    0.000    0.000    0.006    0.000 formatters.py:219(catch_format_error)
#       240    0.000    0.000    0.011    0.000 decorator.py:229(fun)
#       240    0.000    0.000    0.005    0.000 decorator.py:199(fix)
#       240    0.000    0.000    0.000    0.000 pretty.py:321(_get_mro)
#       240    0.000    0.000    0.001    0.000 inspect.py:2862(kwargs)
#       240    0.000    0.000    0.002    0.000 inspect.py:3207(bind)
#       240    0.000    0.000    0.000    0.000 inspect.py:2831(__init__)
#       220    0.001    0.000    0.003    0.000 formatters.py:396(lookup_by_type)
#       220    0.000    0.000    0.000    0.000 formatters.py:273(_get_type)
#       220    0.000    0.000    0.003    0.000 formatters.py:373(lookup)
#       220    0.000    0.000    0.000    0.000 formatters.py:358(_check_return)
#       220    0.000    0.000    0.000    0.000 dir2.py:54(get_real_method)
#       220    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#       180    0.000    0.000    0.004    0.000 formatters.py:330(__call__)
#       171    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       164    0.000    0.000    0.000    0.000 distance.py:313(_validate_vector)
#       140    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#        99    0.000    0.000    0.000    0.000 reportviews.py:311(__init__)
#        99    0.000    0.000    0.000    0.000 reportviews.py:329(__iter__)
#        82    0.000    0.000    0.001    0.000 _misc.py:17(norm)
#        82    0.000    0.000    0.001    0.000 distance.py:429(minkowski)
#        82    0.000    0.000    0.001    0.000 distance.py:500(euclidean)
#        82    0.000    0.000    0.000    0.000 function_base.py:562(asarray_chkfinite)
#        77    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        67    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        64    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        60    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        60    0.000    0.000    0.000    0.000 pretty.py:495(enq)
#        60    0.000    0.000    0.000    0.000 pretty.py:482(__init__)
#        60    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#        55    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#        47    0.000    0.000    0.000    0.000 blas.py:384(getter)
#        47    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        44    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        40    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        40    0.000    0.000    0.000    0.000 pretty.py:304(end_group)
#        40    0.000    0.000    0.000    0.000 pretty.py:512(remove)
#        40    0.000    0.000    0.000    0.000 pretty.py:184(group)
#        40    0.000    0.000    0.000    0.000 pretty.py:280(begin_group)
#        40    0.000    0.000    0.000    0.000 configurable.py:522(instance)
#        36    0.000    0.000    0.000    0.000 graph.py:453(__contains__)
#        35    0.000    0.000    0.000    0.000 linalg.py:2342(norm)
#        35    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        35    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(norm)
#        35    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#        35    0.000    0.000    0.000    0.000 linalg.py:2338(_norm_dispatcher)
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        24    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        24    0.000    0.000    0.002    0.000 IPVisibilityPRM_Roundtrip.py:58(_nearestInterim)
#        20    0.000    0.000    0.000    0.000 <frozen genericpath>:16(exists)
#        20    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        20    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        20    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        20    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#        20    0.000    0.000    0.012    0.001 display_functions.py:105(display)
#        20    0.000    0.000    0.000    0.000 display.py:281(__init__)
#        20    0.000    0.000    0.000    0.000 display.py:349(reload)
#        20    0.000    0.000    0.000    0.000 pretty.py:232(text)
#        20    0.000    0.000    0.001    0.000 pretty.py:372(pretty)
#        20    0.000    0.000    0.012    0.001 formatters.py:90(format)
#        20    0.000    0.000    0.013    0.001 HelperClass.py:9(printInColor)
#        20    0.000    0.000    0.000    0.000 displaypub.py:130(publish)
#        20    0.000    0.000    0.001    0.000 formatters.py:907(__call__)
#        20    0.000    0.000    0.000    0.000 formatters.py:953(__call__)
#        20    0.000    0.000    0.000    0.000 formatters.py:944(_check_return)
#        20    0.000    0.000    0.000    0.000 display.py:342(_data_and_metadata)
#        20    0.000    0.000    0.000    0.000 display.py:418(warn)
#        20    0.000    0.000    0.000    0.000 pretty.py:201(__init__)
#        20    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#        20    0.000    0.000    0.000    0.000 display_functions.py:45(publish_display_data)
#        20    0.000    0.000    0.000    0.000 display.py:434(_repr_html_)
#        20    0.000    0.000    0.000    0.000 pretty.py:355(__init__)
#        20    0.000    0.000    0.000    0.000 pretty.py:775(_repr_pprint)
#        20    0.000    0.000    0.000    0.000 display.py:57(_safe_exists)
#        20    0.000    0.000    0.000    0.000 pretty.py:490(__init__)
#        20    0.000    0.000    0.000    0.000 display.py:405(_check_data)
#        20    0.000    0.000    0.000    0.000 pretty.py:313(flush)
#        20    0.000    0.000    0.001    0.000 formatters.py:695(__call__)
#        20    0.000    0.000    0.000    0.000 display.py:330(__repr__)
#        20    0.000    0.000    0.000    0.000 display.py:417(__init__)
#        20    0.000    0.000    0.000    0.000 configurable.py:566(initialized)
#        20    0.000    0.000    0.000    0.000 contextlib.py:287(helper)
#        20    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#        20    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#        18    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        18    0.000    0.000    0.000    0.000 unweighted.py:259(_bidirectional_pred_succ)
#        18    0.000    0.000    0.000    0.000 generic.py:41(shortest_path)
#        18    0.000    0.000    0.000    0.000 unweighted.py:196(bidirectional_shortest_path)
#        17    0.000    0.000    0.000    0.000 IPVisibilityPRM_Roundtrip.py:41(_getNodeNamebasedOnCoordinates)
#        16    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        14    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(reshape)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:198(reshape)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:193(_reshape_dispatcher)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:38(_wrapit)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 <frozen _collections_abc>:859(__iter__)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2698(_amax_dispatcher)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amax)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:2703(amax)
#         7    0.000    0.000    0.001    0.000 {method 'query' of 'scipy.spatial._ckdtree.cKDTree' objects}
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1991(shape)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1987(_shape_dispatcher)
#         7    0.000    0.000    0.000    0.000 numeric.py:1878(isscalar)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 function_base.py:871(copy)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copy)
#         2    0.000    0.000    0.000    0.000 function_base.py:867(_copy_dispatcher)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:812(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:790(items)
#         1    0.000    0.000    0.841    0.841 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 IPPlanerBase.py:22(_checkStartGoal)
#         1    0.005    0.005    0.811    0.811 IPVisibilityPRM_Roundtrip.py:96(_learnRoadmap)
#         1    0.000    0.000    0.840    0.840 IPVisibilityPRM_Roundtrip.py:145(planRoundPath)
#         1    0.000    0.000    0.840    0.840 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 reportviews.py:185(__iter__)
#         1    0.000    0.000    0.000    0.000 function.py:677(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 function.py:655(get_node_attributes)
#         1    0.000    0.000    0.000    0.000 graph.py:1519(clear)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2824(_amin_dispatcher)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2829(amin)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#
#
# Sat Jan 13 21:05:27 2024    ./stats/visibilitystats
#
#          818884 function calls (799489 primitive calls) in 0.841 seconds
#
#    Ordered by: cumulative time
#    List reduced from 204 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.841    0.841 {built-in method builtins.exec}
#         1    0.000    0.000    0.840    0.840 <string>:1(<module>)
#   19396/1    0.039    0.000    0.840    0.840 IPPerfMonitor.py:24(__call__)
#         1    0.000    0.000    0.840    0.840 IPVisibilityPRM_Roundtrip.py:145(planRoundPath)
#         1    0.005    0.005    0.811    0.811 IPVisibilityPRM_Roundtrip.py:96(_learnRoadmap)
#       734    0.094    0.000    0.776    0.001 IPEnvironment.py:42(lineInCollision)
#       725    0.001    0.000    0.770    0.001 IPVisibilityPRM_Roundtrip.py:38(_isVisible)
#     18321    0.065    0.000    0.610    0.000 IPEnvironment.py:31(pointInCollision)
#     18321    0.046    0.000    0.278    0.000 point.py:38(__init__)
#     18321    0.021    0.000    0.180    0.000 base.py:803(intersects)
#     18321    0.115    0.000    0.155    0.000 predicates.py:11(__call__)
#     18321    0.124    0.000    0.138    0.000 point.py:244(geos_point_from_py)
#     36642    0.052    0.000    0.097    0.000 base.py:191(_empty)
#    146568    0.082    0.000    0.082    0.000 base.py:245(__setattr__)
#     18321    0.013    0.000    0.079    0.000 base.py:208(__del__)
#
#
# Sat Jan 13 21:05:27 2024    ./stats/visibilitystats
#
#          818884 function calls (799489 primitive calls) in 0.841 seconds
#
#    Ordered by: call count
#    List reduced from 204 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    146568    0.082    0.000    0.082    0.000 base.py:245(__setattr__)
#     93338    0.011    0.000    0.011    0.000 {built-in method builtins.len}
#     73284    0.011    0.000    0.011    0.000 base.py:228(_geom)
#     39025    0.009    0.000    0.009    0.000 {built-in method builtins.isinstance}
#     38792    0.007    0.000    0.007    0.000 {built-in method time.time}
#     37235    0.008    0.000    0.008    0.000 {built-in method builtins.hasattr}
#     36642    0.021    0.000    0.030    0.000 topology.py:18(_validate)
#     36642    0.052    0.000    0.097    0.000 base.py:191(_empty)
#     21079    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#     19795    0.003    0.000    0.003    0.000 IPEnvironment.py:23(getDim)
#     19396    0.042    0.000    0.042    0.000 IPPerfMonitor.py:38(__get__)
#   19396/1    0.039    0.000    0.840    0.840 IPPerfMonitor.py:24(__call__)
#     18449    0.003    0.000    0.003    0.000 {method 'items' of 'dict' objects}
#     18321    0.124    0.000    0.138    0.000 point.py:244(geos_point_from_py)
#     18321    0.046    0.000    0.278    0.000 point.py:38(__init__)
#
#
# Sat Jan 13 21:05:27 2024    ./stats/visibilitystats
#
#          818884 function calls (799489 primitive calls) in 0.841 seconds
#
#    Ordered by: internal time
#    List reduced from 204 to 15 due to restriction <15>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     18321    0.124    0.000    0.138    0.000 point.py:244(geos_point_from_py)
#     18321    0.115    0.000    0.155    0.000 predicates.py:11(__call__)
#       734    0.094    0.000    0.776    0.001 IPEnvironment.py:42(lineInCollision)
#    146568    0.082    0.000    0.082    0.000 base.py:245(__setattr__)
#     18321    0.065    0.000    0.610    0.000 IPEnvironment.py:31(pointInCollision)
#     36642    0.052    0.000    0.097    0.000 base.py:191(_empty)
#     18321    0.046    0.000    0.278    0.000 point.py:38(__init__)
#     19396    0.042    0.000    0.042    0.000 IPPerfMonitor.py:38(__get__)
#   19396/1    0.039    0.000    0.840    0.840 IPPerfMonitor.py:24(__call__)
#     36642    0.021    0.000    0.030    0.000 topology.py:18(_validate)
#     18321    0.021    0.000    0.180    0.000 base.py:803(intersects)
#     18321    0.020    0.000    0.079    0.000 base.py:240(_set_geom)
#     18321    0.013    0.000    0.079    0.000 base.py:208(__del__)
#     73284    0.011    0.000    0.011    0.000 base.py:228(_geom)
#     93338    0.011    0.000    0.011    0.000 {built-in method builtins.len}

# %%
# utility functions to read and access data in astartstats
import pstats
from pstats import SortKey

p = pstats.Stats('./stats/lazystats')
p.strip_dirs().sort_stats(SortKey.CALLS).print_stats()
p.sort_stats(SortKey.CUMULATIVE).print_stats(15)
p.sort_stats(SortKey.CALLS).print_stats(15)
p.sort_stats(SortKey.TIME).print_stats(15)

    
# Anzeige der Benchmarks, noch nicht mit allen Vis möglich

for bench, result in zip(testList, resultList):
    title = bench.name
    pathLength = dict()
    planningTime = dict()
    roadmapSize  = dict()
    if result.benchmark.name == bench.name:
        pathLength[result.plannerFactoryName] = len(result.solution)
        planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
        roadmapSize[result.plannerFactoryName] = result.planner.graph.size()
# Out:
#   Cell In[7], line 5
#     p = pstats.Stats('./stats/lazystats'')
#                                         ^
# SyntaxError: unterminated string literal (detected at line 5)

# %% [markdown]
# Example using IPerfMonitor
# --------------------------

# %%
from IPPerfMonitor import IPPerfMonitor

# %%
benchList = IPTestSuite.benchList

# KOnfig steht in plannerFactory
print(str(planner))
with io.capture_output() as captured:
    solution = planner.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,producer[1])


start = benchList[0].startList
goal = benchList[0].goalList

data_frame = IPPerfMonitor.dataFrame()

#fig_local = plt.figure(figsize=(10,10))
#ax = fig_local.add_subplot(1,1,1)

#IPVISVisibilityPRM.visibilityPRMVisualize(planner, solution, ax=ax, nodeSize=100)

# %%
resultList = list()
testList = benchList[:1]

solution = list()
data_frame = list()
i = 0
for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')

    for benchmark in testList:

        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        
        try:
            with io.capture_output() as captured:
                #resultList.append(ResultCollection(key,
                #                        planner, 
                #                        benchmark, 
                #                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                #                        IPPerfMonitor.dataFrame()),)
                solution.append(planner.planRoundPath(benchList[0].startList,benchList[0].interimGoalList,benchList[0].goalList,producer[1]))
                data_frame.append(IPPerfMonitor.dataFrame())

                i = i + 1


        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            pass

print(solution[1])

# %%
#data_frame

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0].groupby(["name"]).sum(numeric_only=True))
print("")

HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1].groupby(["name"]).sum(numeric_only=True))
print("")

HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2].groupby(["name"]).sum(numeric_only=True))

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0][data_frame[0]["name"]=="pointInCollision"][data_frame[0]["retVal"]==True].count())

HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1][data_frame[1]["name"]=="pointInCollision"][data_frame[1]["retVal"]==True].count())

HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2][data_frame[2]["name"]=="pointInCollision"][data_frame[2]["retVal"]==True].count())

# %%
HelperClass.HelperClass.printInColor("Basic", "red")
print(data_frame[0].groupby(["name"]).count())
print("")
HelperClass.HelperClass.printInColor("Visibility", "yellow")
print(data_frame[1].groupby(["name"]).count())
print("")
HelperClass.HelperClass.printInColor("Lazy", "green")
print(data_frame[2].groupby(["name"]).count())

# %% [markdown]
# Second Example using IPPerfMonitor
# ----------------------------------

# %%
import IPVisibilityPRM_Roundtrip
import IPVISVisibilityPRM

# %%
visbilityConfig = dict()
visbilityConfig["ntry"] = 300

vis = plannerFactory["visibilityPRM"][0](benchList[3].collisionChecker)

start = benchList[3].startList
goal = benchList[3].goalList

IPPerfMonitor.clearData()

with io.capture_output() as captured:
    solution = vis.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,visbilityConfig)

data_frame = IPPerfMonitor.dataFrame()

fig_local = plt.figure(figsize=(10,10))
ax = fig_local.add_subplot(1,1,1)
IPVISVisibilityPRM.visibilityPRMVisualize(vis, solution, ax = ax)

# %%
data_frame

# %%
data_frame.groupby(["name"]).count()

# %%
data_frame.groupby(["name"]).sum(numeric_only=True)
