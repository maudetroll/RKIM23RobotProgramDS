# %% [markdown]
# Introduction
# ============
#
# This is interactive notebook regarding "Introduction to path planning". (Author: Björn Hein)
#
# License is based on Creative Commons: Attribution-NonCommercial 4.0 International (CC BY-NC 4.0) (pls. check: http://creativecommons.org/licenses/by-nc/4.0/)
#
# This notebook imports all discussed algorithms and does a comparison
#
# **Attention**: This worksheet has external dependencies
#
# * to the files "InnoKonz2dEnv.py" or "InnoKonzShapelyEnv.py". These files contain simple 2D environments based on numpy arrays or the shapely library with an interface for the use as collision checking in the algorithms.
# * to all modules like "**Algorithm**.py", which contains the corresponding algorithms
#
# Important links are:
#
# * General Info: http://www.python.org
# * Python tutorial http://www.python.org/doc/tut/
# * NetworkX http://networkx.github.io/
# * NumPy and SciPy Guide http://docs.scipy.org/
# * Matplotlib gallery http://matplotlib.sourceforge.net/gallery.html
#
#
# Remember that:
#
# * you have to press ctrl-return or shift-return, to execute the code in the code sections, only then the variables are "generated" and can be used
# * you can execute the whole notebook by Cell->runAll

# %% [markdown]
# Adding all planners
# ===========

# %%
import sys
import HelperClass
sys.path.append("templates")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from IPPerfMonitor import IPPerfMonitor

from BasicPRM import IPVISBasicPRM 
from BasicPRM import IPBasicPRM_Roundtrip

from VisibilityPRM import IPVisibilityPRM_Roundtrip
from VisibilityPRM import IPVISVisibilityPRM

from VisibilityPRM import CC_IPVisibilityPRM_Roundtrip

from LazyPRM import IPLazyPRM_Roundtrip
from LazyPRM import IPVISLazyPRM

# %% [markdown]
# Set-up of the test scenario and the configuration for all planner
# ===================================
#
# Following a procedure to compare all discussed planners are shown:
#
# 1. Configuration for every planner is defined
# 2. The configuration and the planner is stored in the variable setup, a Python dict()
# 3. the variable setup is then used to uniformly call the planning calls

# %%
plannerFactory = dict()

# basicConfig = dict()
# basicConfig["radius"] = 3
# basicConfig["numNodes"] = 200
# plannerFactory["basePRM"] = [IPBasicPRM_Roundtrip.BasicPRM, basicConfig, IPVISBasicPRM.basicPRMVisualize]


visbilityConfig = dict()
visbilityConfig["ntry"] = 300
plannerFactory["visibilityPRM"] = [IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]


# visbilityConfig = dict()
# visbilityConfig["ntry"] = 300
# plannerFactory["visibilityPRM"] = [CC_IPVisibilityPRM_Roundtrip.VisPRM, visbilityConfig, IPVISVisibilityPRM.visibilityPRMVisualize ]

# lazyConfig = dict()
# lazyConfig["initialRoadmapSize"] = 10
# lazyConfig["updateRoadmapSize"]  = 5
# lazyConfig["kNearest"] = 8
# plannerFactory["lazyPRM"] = [IPLazyPRM_Roundtrip.LazyPRM, lazyConfig, IPVISLazyPRM.lazyPRMVisualize]

# %%
class ResultCollection (object):
    
    def __init__(self, plannerFactoryName, planner, benchmark, solution, perfDataFrame):
        self.plannerFactoryName = plannerFactoryName
        self.planner = planner
        self.benchmark = benchmark
        self.solution = solution
        self.perfDataFrame = perfDataFrame

# %%
import IPTestSuite
import importlib

# %%
importlib.reload(IPTestSuite)
# Out:
# <module 'IPTestSuite' from 'c:\\Users\\andre\\OneDrive - Hochschule Karlsruhe\\HS Karlsruhe\\1. Semester\\Roboterprogrammierung\\Projekt\\Git\\RKIM23RobotProgramDS\\02_eigeneNotebooks\\IPTestSuite.py'>

# %%
fullBenchList = IPTestSuite.benchList

for benchmark in fullBenchList:
    print(benchmark.name)
# Out:
# Trap
# Bottleneck
# Fat bottleneck
# B_rush
# circle od death

# %%
resultList = list()
testList = fullBenchList[:1]

for key,producer in list(plannerFactory.items()):
    HelperClass.HelperClass.printInColor(str(key)+" "+ str(producer), 'yellow')

    for benchmark in testList:
        HelperClass.HelperClass.printInColor("Planning: " + key + " - " + benchmark.name, 'yellow')
        planner = producer[0](benchmark.collisionChecker)
        IPPerfMonitor.clearData()
        

        try:
            resultList.append(ResultCollection(key,
                                        planner, 
                                        benchmark, 
                                        planner.planRoundPath(benchmark.startList,benchmark.interimGoalList,benchmark.goalList,producer[1]),
                                        IPPerfMonitor.dataFrame()),)



        except Exception as e:
            HelperClass.HelperClass.printInColor("PLANNING ERROR ! PLANNING ERROR ! PLANNING ERROR", 'red')
            HelperClass.HelperClass.printInColor(e, 'red')
            import traceback
            HelperClass.HelperClass.printInColor(traceback.print_exc(), 'red')

            pass
# Out:
# <font color='yellow'>visibilityPRM [<class 'VisibilityPRM.IPVisibilityPRM_Roundtrip.VisPRM'>, {'ntry': 300}, <function visibilityPRMVisualize at 0x000001F7482062A0>]</font>
# <font color='yellow'>Planning: visibilityPRM - Trap</font>
# Nodenumber:  1
# Nodenumber:  2
# Nodenumber:  3
# Nodenumber:  4
# Nodenumber:  5
# Nodenumber:  6
# Nodenumber:  7
# Nodenumber:  8
# Nodenumber:  9
# Nodenumber:  10
# Nodenumber:  11
# Nodenumber:  12
# Nodenumber:  13
# Nodenumber:  14
# Nodenumber:  15
# Nodenumber:  16
# Nodenumber:  17
# Nodenumber:  18
# Nodenumber:  19
# Nodenumber:  20
# Nodenumber:  21
# Nodenumber:  22
# Nodenumber:  23
# Nodenumber:  24
# Nodenumber:  25
# Nodenumber:  26
# Nodenumber:  27
# Nodenumber:  28
# Nodenumber:  29
# Nodenumber:  30
# Nodenumber:  31
# Nodenumber:  32
# Nodenumber:  33
# Nodenumber:  34
# Nodenumber:  35
# Nodenumber:  36
# Nodenumber:  37
# Nodenumber:  38
# Nodenumber:  39
# Nodenumber:  40
# Nodenumber:  41
# Nodenumber:  42
# Nodenumber:  43
# Nodenumber:  44
# Nodenumber:  45
# Nodenumber:  46
# Nodenumber:  47
# Nodenumber:  48
# Nodenumber:  49
# Nodenumber:  50
# Nodenumber:  51
# Nodenumber:  52
# Nodenumber:  53
# Nodenumber:  54
# Nodenumber:  55
# Nodenumber:  56
# Nodenumber:  57
# Nodenumber:  58
# Nodenumber:  59
# Nodenumber:  60
# Nodenumber:  61
# Nodenumber:  62
# Nodenumber:  63
# Nodenumber:  64
# Nodenumber:  65
# Nodenumber:  66
# Nodenumber:  67
# Nodenumber:  68
# Nodenumber:  69
# Nodenumber:  70
# Nodenumber:  71
# Nodenumber:  72
# Nodenumber:  73
# Nodenumber:  74
# Nodenumber:  75
# Nodenumber:  76
# Nodenumber:  77
# Nodenumber:  78
# Nodenumber:  79
# Nodenumber:  80
# Nodenumber:  81
# Nodenumber:  82
# Nodenumber:  83
# Nodenumber:  84
# Nodenumber:  85
# Nodenumber:  86
# Nodenumber:  87
# Nodenumber:  88
# Nodenumber:  89
# Nodenumber:  90
# Nodenumber:  91
# Nodenumber:  92
# Nodenumber:  93
# Nodenumber:  94
# Nodenumber:  95
# Nodenumber:  96
# Nodenumber:  97
# Nodenumber:  98
# Nodenumber:  99
# Nodenumber:  100
# Nodenumber:  101
# Nodenumber:  102
# Nodenumber:  103
# Nodenumber:  104
# Nodenumber:  105
# Nodenumber:  106
# Nodenumber:  107
# Nodenumber:  108
# Nodenumber:  109
# Nodenumber:  110
# Nodenumber:  111
# Nodenumber:  112
# Nodenumber:  113
# Nodenumber:  114
# Nodenumber:  115
# Nodenumber:  116
# Nodenumber:  117
# Nodenumber:  118
# Nodenumber:  119
# Nodenumber:  120
# Nodenumber:  121
# Nodenumber:  122
# Nodenumber:  123
# Nodenumber:  124
# Nodenumber:  125
# Nodenumber:  126
# Nodenumber:  127
# Nodenumber:  128
# Nodenumber:  129
# Nodenumber:  130
# Nodenumber:  131
# Nodenumber:  132
# Nodenumber:  133
# Nodenumber:  134
# Nodenumber:  135
# Nodenumber:  136
# Nodenumber:  137
# Nodenumber:  138
# Nodenumber:  139
# Nodenumber:  140
# Nodenumber:  141
# Nodenumber:  142
# Nodenumber:  143
# Nodenumber:  144
# Nodenumber:  145
# Nodenumber:  146
# Nodenumber:  147
# Nodenumber:  148
# Nodenumber:  149
# Nodenumber:  150
# Nodenumber:  151
# Nodenumber:  152
# Nodenumber:  153
# Nodenumber:  154
# Nodenumber:  155
# Nodenumber:  156
# Nodenumber:  157
# Nodenumber:  158
# Nodenumber:  159
# Nodenumber:  160
# Nodenumber:  161
# Nodenumber:  162
# Nodenumber:  163
# Nodenumber:  164
# Nodenumber:  165
# Nodenumber:  166
# Nodenumber:  167
# Nodenumber:  168
# Nodenumber:  169
# Nodenumber:  170
# Nodenumber:  171
# Nodenumber:  172
# Nodenumber:  173
# Nodenumber:  174
# Nodenumber:  175
# Nodenumber:  176
# Nodenumber:  177
# Nodenumber:  178
# Nodenumber:  179
# Nodenumber:  180
# Nodenumber:  181
# Nodenumber:  182
# Nodenumber:  183
# Nodenumber:  184
# Nodenumber:  185
# Nodenumber:  186
# Nodenumber:  187
# Nodenumber:  188
# Nodenumber:  189
# Nodenumber:  190
# Nodenumber:  191
# Nodenumber:  192
# Nodenumber:  193
# Nodenumber:  194
# Nodenumber:  195
# Nodenumber:  196
# Nodenumber:  197
# Nodenumber:  198
# Nodenumber:  199
# Nodenumber:  200
# Nodenumber:  201
# Nodenumber:  202
# Nodenumber:  203
# Nodenumber:  204
# Nodenumber:  205
# Nodenumber:  206
# Nodenumber:  207
# Nodenumber:  208
# Nodenumber:  209
# Nodenumber:  210
# Nodenumber:  211
# Nodenumber:  212
# Nodenumber:  213
# Nodenumber:  214
# Nodenumber:  215
# Nodenumber:  216
# Nodenumber:  217
# Nodenumber:  218
# Nodenumber:  219
# Nodenumber:  220
# Nodenumber:  221
# Nodenumber:  222
# Nodenumber:  223
# Nodenumber:  224
# Nodenumber:  225
# Nodenumber:  226
# Nodenumber:  227
# Nodenumber:  228
# Nodenumber:  229
# Nodenumber:  230
# Nodenumber:  231
# Nodenumber:  232
# Nodenumber:  233
# Nodenumber:  234
# Nodenumber:  235
# Nodenumber:  236
# Nodenumber:  237
# Nodenumber:  238
# Nodenumber:  239
# Nodenumber:  240
# Nodenumber:  241
# Nodenumber:  242
# Nodenumber:  243
# Nodenumber:  244
# Nodenumber:  245
# Nodenumber:  246
# Nodenumber:  247
# Nodenumber:  248
# Nodenumber:  249
# Nodenumber:  250
# Nodenumber:  251
# Nodenumber:  252
# Nodenumber:  253
# Nodenumber:  254
# Nodenumber:  255
# Nodenumber:  256
# Nodenumber:  257
# Nodenumber:  258
# Nodenumber:  259
# Nodenumber:  260
# Nodenumber:  261
# Nodenumber:  262
# Nodenumber:  263
# Nodenumber:  264
# Nodenumber:  265
# Nodenumber:  266
# Nodenumber:  267
# Nodenumber:  268
# Nodenumber:  269
# Nodenumber:  270
# Nodenumber:  271
# Nodenumber:  272
# Nodenumber:  273
# Nodenumber:  274
# Nodenumber:  275
# Nodenumber:  276
# Nodenumber:  277
# Nodenumber:  278
# Nodenumber:  279
# Nodenumber:  280
# Nodenumber:  281
# Nodenumber:  282
# Nodenumber:  283
# Nodenumber:  284
# Nodenumber:  285
# Nodenumber:  286
# Nodenumber:  287
# Nodenumber:  288
# Nodenumber:  289
# Nodenumber:  290
# Nodenumber:  291
# Nodenumber:  292
# Nodenumber:  293
# Nodenumber:  294
# Nodenumber:  295
# Nodenumber:  296
# Nodenumber:  297
# Nodenumber:  298
# Nodenumber:  299
# Nodenumber:  300
# <font color='Dodgerblue'>Aktueller Pfad: ['start']</font>
# <font color='Dodgerblue'>Aktueller Pfad: ['start', 72]</font>
# <font color='Dodgerblue'>Aktueller Pfad: ['start', 72, 'interim1']</font>
# <font color='Dodgerblue'>Aktueller Pfad: ['start', 72, 'interim1', 'interim3']</font>
# <font color='Dodgerblue'>Aktueller Pfad: ['start', 72, 'interim1', 'interim3', 'interim1']</font>
# <font color='Dodgerblue'>Aktueller Pfad: ['start', 72, 'interim1', 'interim3', 'interim1', 'interim4']</font>
# <font color='Dodgerblue'>Aktueller Pfad: ['start', 72, 'interim1', 'interim3', 'interim1', 'interim4', 'interim0']</font>
# <font color='Dodgerblue'>Aktueller Pfad: ['start', 72, 'interim1', 'interim3', 'interim1', 'interim4', 'interim0', 'interim2']</font>
# <font color='lawngreen'>Solution =  ['start', 72, 'interim1', 'interim3', 'interim1', 'interim4', 'interim0', 'interim2']</font>

# %%
import matplotlib.pyplot as plt

for result in resultList:
    fig_local = plt.figure(figsize=(10,10))
    ax = fig_local.add_subplot(1,1,1)
    title = result.plannerFactoryName + " - " + result.benchmark.name
    if result.solution == []:
        title += " (No path found!)"
    title += "\n Assumed complexity level " + str(result.benchmark.level)
    ax.set_title(title)

    try:
        #IPVISBasicsPRM.basicPRMVisualize(result.planner, result.solution, ax=ax, nodeSize=100))
        plannerFactory[result.plannerFactoryName][2](result.planner, result.solution, ax=ax, nodeSize=100)


    except Exception as e:
        print ("Error")
        print(e)
        pass

# %%
# import numpy as np
# for bench in testList:
#     title = bench.name
#     pathLength = dict()
#     planningTime = dict()
#     roadmapSize  = dict()
    
#     try:
#         for result in resultList:
#             if result.benchmark.name == bench.name:
#                 #print result.benchmark.name  + " - " +  result.plannerFactoryName, len(result.solution)
#                 pathLength[result.plannerFactoryName] = len(result.solution)
#                 planningTime[result.plannerFactoryName] = result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)["time"]["planRoundPath"]
#                 roadmapSize[result.plannerFactoryName] = result.planner.graph.size()


#         fig, ax = plt.subplots()

#         width = 0.2

#         ax.bar(np.arange(len(pathLength.keys())), pathLength.values(),width, color="blue")
#         ax.set_ylabel(title + " Path length (number of nodes!)", color="blue")
#         ax.set_xticks(np.arange(len(pathLength.keys())) + width)
#         ax.set_xticklabels(pathLength.keys())

#         ax2 = ax.twinx()
#         bar = ax2.bar(np.arange(len(pathLength.keys()))+width, planningTime.values(),width, color="red")
#         ax2.set_ylabel(title + " Planning time", color="y")

#         # Add coloring and patterns on axis two
#         hatches = ['x' if length==0 else '' for length in pathLength.values()]
#         color   = ['red' if length==0 else 'yellow' for length in pathLength.values()]
#         for i,thisbar in enumerate(bar.patches):
#             thisbar.set_facecolor(color[i])
#             thisbar.set_hatch(hatches[i])

#         # Multiple axes 
#         ax3 = ax.twinx()
#         ax3.bar(np.arange(len(pathLength.keys()))+2*width, roadmapSize.values(),width, color="purple")
#         ax3.set_ylabel(title + " Roadmap size",  color="purple")
#         ax3.spines['right'].set_position(('axes', 1.15))
#         ax3.spines['right'].set_color("purple")
#     except:
#         pass

# %% [markdown]
# result.perfDataFrame.groupby(["name"]).sum()

# %%
# result.perfDataFrame.groupby(["name"]).sum(numeric_only=True)

# %%
# resultBasic = resultList[:5]
# resultVisibility = resultList[5:10]
# resultLazy = resultList[10:]

# %%
'''
import pandas as pd

result_frames = []

for i in range(len(resultBasic)):
    sum_time_Basic = resultBasic[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum()["time"]
    sum_time_Visibilty = resultVisibility[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum()["time"]
    sum_time_Lazy = resultLazy[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum()["time"]

    
    # DataFrame erstellen
    data = {
        "Zeit Basic": [sum_time_Basic],
        "Zeit Visibility": [sum_time_Visibilty],
        "Zeit LazyPRM" : [sum_time_Lazy]
    }

    df = pd.DataFrame(data)

    # DataFrame zur Liste hinzufügen
    result_frames.append(df)

final_df = pd.concat(result_frames, ignore_index=True)

# DataFrame in eine Excel-Datei schreiben
final_df.to_excel("Auswertung_alle_3PRMs_.xlsx", index=False)

'''
# Out:
# '\nimport pandas as pd\n\nresult_frames = []\n\nfor i in range(len(resultBasic)):\n    sum_time_Basic = resultBasic[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum()["time"]\n    sum_time_Visibilty = resultVisibility[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum()["time"]\n    sum_time_Lazy = resultLazy[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum()["time"]\n\n    \n    # DataFrame erstellen\n    data = {\n        "Zeit Basic": [sum_time_Basic],\n        "Zeit Visibility": [sum_time_Visibilty],\n        "Zeit LazyPRM" : [sum_time_Lazy]\n    }\n\n    df = pd.DataFrame(data)\n\n    # DataFrame zur Liste hinzufügen\n    result_frames.append(df)\n\nfinal_df = pd.concat(result_frames, ignore_index=True)\n\n# DataFrame in eine Excel-Datei schreiben\nfinal_df.to_excel("Auswertung_alle_3PRMs_.xlsx", index=False)\n\n'

# %%
# for i in range(len(resultBasic)):
#     print(resultBasic[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum()["time"])

# %%
# for i in range(len(resultVisibility)):

#     print(resultVisibility[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum())

# %%
# for i in range(len(resultLazy)):

#     print(resultLazy[i].perfDataFrame.groupby(["name"]).sum(numeric_only=True).sum())

# %%
#result.perfDataFrame[result.perfDataFrame["name"]=="planRoundPath"][result.perfDataFrame["retVal"]==False]["time"].sum(numeric_only=True)

# %%
#result.perfDataFrame[result.perfDataFrame["name"]=="planRoundPath"]["time"]

# %%
#result.perfDataFrame[result.perfDataFrame["name"]=="planRoundPath"][result.perfDataFrame["retVal"]==False]["time"].sum(numeric_only=True)
